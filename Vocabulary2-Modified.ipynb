# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback, ModelCheckpoint, EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, LSTM, Bidirectional
import numpy as np
import sys
import io
import os
import codecs
import operator

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# []

# %%
text_in_words=[]
MIN_WORD_FREQUENCY = 12
vocabulary = "vocabulary.txt"

# %%
def get_corpus(corpus_filename,isJoke,Tag=""):
    with open(corpus_filename) as myfile:
        head = [next(myfile) for x in range(2000)]
    size= len(head)
    totalline =[""]*size
    for i in range(size):
        if isJoke == True:
            x = head[i].split(',',1)
        else:
            x = head[i].split('\t')
            
        myline = x[1].replace(".", " .")
        myline = x[1].replace("\n", "  \n")
        totalline[i]= Tag + myline
    return totalline

def get_text_in_words(tline):
    get_this_text_in_words=[]
    for line in tline:
        word = line.split(' ')
        for eachword in word:
            if eachword !='':
                get_this_text_in_words.append(eachword)
    return get_this_text_in_words
                
def print_vocabulary(words_file_path, words_set):
    words_file = codecs.open(words_file_path, 'w', encoding='utf8')
    for w in words_set:
        if w != "\n":
            words_file.write(w+"\n")
        else:
            words_file.write(w)
    words_file.close()

# %%
#get all dataset 
quotedataset= get_corpus("author-quote.txt",False)
jokedataset= get_corpus("shortjokes.csv",True)
 
#text_in_words = quotedataset + jokedataset

# %%
quotedataset[:5]
# Out:
# ['If you live to be a hundred, I want to live to be a hundred minus one day so I never have to live without you.  \n',
#  "Promise me you'll always remember: You're braver than you believe, and stronger than you seem, and smarter than you think.  \n",
#  'Did you ever stop to think, and forget to start again?  \n',
#  'Organizing is what you do before you do something, so that when you do it, it is not all mixed up.  \n',
#  'Weeds are flowers too, once you get to know them.  \n']

# %%
jokedataset[:5]
# Out:
# ['"Joke"  \n',
#  '"[me narrating a documentary about narrators] ""I can\'t hear what they\'re saying cuz I\'m talking"""  \n',
#  '"Telling my daughter garlic is good for you. Good immune system and keeps pests away.Ticks, mosquitos, vampires... men."  \n',
#  '"I\'ve been going through a really rough period at work this week It\'s my own fault for swapping my tampax for sand paper."  \n',
#  '"If I could have dinner with anyone, dead or alive... ...I would choose alive. -B.J. Novak-"  \n']

# %%
#fill up the text_in_words with all dataset
quote_text_in_words= get_text_in_words(quotedataset)
joke_text_in_words= get_text_in_words(jokedataset)
text_in_words = quote_text_in_words+ joke_text_in_words +quote_text_in_words+ joke_text_in_words

# %%
quote_text_in_words[:10]
# Out:
# ['If', 'you', 'live', 'to', 'be', 'a', 'hundred,', 'I', 'want', 'to']

# %%
joke_text_in_words[:10]
# Out:
# ['"Joke"',
#  '\n',
#  '"[me',
#  'narrating',
#  'a',
#  'documentary',
#  'about',
#  'narrators]',
#  '""I',
#  "can't"]

# %%
 # Calculate word frequency
word_freq = {}
for word in text_in_words:
    word_freq[word] = word_freq.get(word, 0) + 1

# %%
# to check the freq count 
sorted_x = sorted(word_freq.items(), key=operator.itemgetter(1))
sorted_x.reverse()

# to print out the freq only. 
#sorted_x

# %%
# TODO: remove \n
sorted_x
# Out:
# [('\n', 8000),
#  ('the', 6168),
#  ('a', 5150),
#  ('to', 4470),
#  ('I', 3824),
#  ('and', 3396),
#  ('of', 3358),
#  ('is', 2590),
#  ('in', 2434),
#  ('you', 1964),
#  ('that', 1600),
#  ('my', 1274),
#  ('have', 1216),
#  ('for', 1128),
#  ('it', 1124),
#  ('with', 1016),
#  ('do', 1016),
#  ('be', 1016),
#  ('are', 970),
#  ('was', 930),
#  ('on', 846),
#  ('not', 840),
#  ('The', 708),
#  ('but', 690),
#  ('like', 642),
#  ('they', 634),
#  ('as', 614),
#  ('your', 602),
#  ('we', 586),
#  ('"What', 564),
#  ('can', 558),
#  ('an', 556),
#  ("I'm", 554),
#  ('who', 552),
#  ('at', 544),
#  ('when', 532),
#  ('me', 532),
#  ("don't", 528),
#  ('just', 528),
#  ('people', 518),
#  ('all', 506),
#  ('or', 500),
#  ('about', 488),
#  ('so', 484),
#  ('one', 480),
#  ('what', 444),
#  ('get', 432),
#  ('"I', 424),
#  ('from', 404),
#  ('think', 394),
#  ('this', 390),
#  ('more', 388),
#  ('by', 384),
#  ('has', 366),
#  ('if', 364),
#  ('than', 358),
#  ('up', 356),
#  ('out', 354),
#  ('will', 354),
#  ('his', 346),
#  ('know', 342),
#  ('A', 340),
#  ("it's", 330),
#  ('-', 328),
#  ('because', 326),
#  ('he', 326),
#  ('It', 320),
#  ('their', 314),
#  ('into', 308),
#  ('always', 308),
#  ('no', 304),
#  ('only', 302),
#  ('make', 294),
#  ('really', 294),
#  ('want', 294),
#  ('did', 292),
#  ('very', 292),
#  ('been', 288),
#  ('You', 282),
#  ('"Why', 276),
#  ('would', 272),
#  ('call', 270),
#  ('had', 268),
#  ('which', 262),
#  ('never', 262),
#  ('say', 256),
#  ('our', 250),
#  ("It's", 240),
#  ('other', 234),
#  ('there', 232),
#  ('We', 230),
#  ('does', 224),
#  ('love', 222),
#  ('her', 212),
#  ('were', 208),
#  ('go', 208),
#  ('see', 206),
#  ('them', 204),
#  ('many', 202),
#  ('life', 202),
#  ('good', 202),
#  ("I've", 200),
#  ('man', 198),
#  ('take', 192),
#  ('am', 192),
#  ('got', 190),
#  ('how', 190),
#  ('it.', 188),
#  ('any', 188),
#  ('much', 188),
#  ('going', 186),
#  ('Because', 186),
#  ('When', 186),
#  ('He', 186),
#  ('If', 186),
#  ('two', 184),
#  ('"How', 182),
#  ('"My', 180),
#  ('some', 180),
#  ('But', 180),
#  ('And', 178),
#  ('could', 176),
#  ('They', 174),
#  ('between', 172),
#  ('then', 168),
#  ('In', 168),
#  ('every', 168),
#  ('time', 166),
#  ('"What\'s', 164),
#  ('world', 164),
#  ('must', 162),
#  ("can't", 162),
#  ('things', 160),
#  ('where', 160),
#  ('should', 160),
#  ('those', 160),
#  ('she', 158),
#  ('most', 158),
#  ('first', 154),
#  ('thing', 150),
#  ('look', 150),
#  ('work', 150),
#  ('great', 148),
#  ('There', 146),
#  ('"A', 144),
#  ('lot', 144),
#  ('feel', 142),
#  ('too', 142),
#  ('something', 140),
#  ('being', 138),
#  ('way', 136),
#  ("you're", 136),
#  ('own', 134),
#  ('put', 132),
#  ('little', 132),
#  ('even', 128),
#  ('My', 128),
#  ('over', 126),
#  ("that's", 126),
#  ('new', 124),
#  ('said', 124),
#  ('us', 124),
#  ('through', 122),
#  ('after', 122),
#  ('still', 120),
#  ('difference', 118),
#  ('without', 118),
#  ('believe', 116),
#  ('come', 114),
#  ('ever', 114),
#  ('part', 112),
#  ('men', 112),
#  ('him', 112),
#  ('back', 110),
#  ('best', 110),
#  ('What', 110),
#  ('tell', 108),
#  ('kind', 106),
#  ("didn't", 104),
#  ('live', 104),
#  ('"If', 102),
#  ('hear', 102),
#  ('down', 102),
#  ('its', 102),
#  ('made', 102),
#  ('need', 100),
#  ('Me:', 98),
#  ('says', 98),
#  ("doesn't", 98),
#  ('same', 96),
#  ('someone', 94),
#  ('person', 94),
#  ('give', 94),
#  ('around', 94),
#  ('right', 92),
#  ('me.', 90),
#  ('One', 90),
#  ('To', 90),
#  ('"The', 88),
#  ('find', 88),
#  ('walks', 86),
#  ('wife', 86),
#  ('why', 86),
#  ('also', 86),
#  ('No', 86),
#  ('music', 84),
#  ('used', 84),
#  ('having', 84),
#  ('old', 84),
#  ('myself', 84),
#  ('human', 84),
#  ('before', 84),
#  ('guy', 82),
#  ('off', 82),
#  ('play', 82),
#  ('important', 82),
#  ('So', 82),
#  ("I'd", 82),
#  ('while', 80),
#  ('change', 80),
#  ('makes', 80),
#  ('women', 80),
#  ('often', 80),
#  ('better', 80),
#  ('me,', 80),
#  ('day', 80),
#  ('told', 78),
#  ('wanted', 78),
#  ('comes', 78),
#  ('called', 78),
#  ('thought', 78),
#  ('both', 76),
#  ('hard', 76),
#  ('long', 76),
#  ('anything', 76),
#  ('may', 76),
#  ('making', 76),
#  ('them.', 76),
#  ('bad', 74),
#  ('black', 74),
#  ('big', 74),
#  ('pretty', 74),
#  ('woman', 72),
#  ('last', 72),
#  ('try', 72),
#  ("That's", 70),
#  ('different', 70),
#  ('now', 70),
#  ('it,', 70),
#  ('girl', 68),
#  ('years', 68),
#  ('sure', 68),
#  ('getting', 68),
#  ('life.', 68),
#  ('happy', 68),
#  ('She', 66),
#  ("they're", 66),
#  ('God', 66),
#  ('these', 66),
#  ('next', 64),
#  ('such', 64),
#  ('let', 64),
#  ('went', 64),
#  ('doing', 64),
#  ('This', 64),
#  ('joke', 62),
#  ('light', 62),
#  ('real', 62),
#  ('cannot', 62),
#  ('everything', 62),
#  ('looking', 62),
#  ('place', 62),
#  ('job', 62),
#  ('gets', 60),
#  ('For', 60),
#  ('home', 60),
#  ('use', 60),
#  ('each', 60),
#  ("I'll", 60),
#  ('working', 60),
#  ('That', 60),
#  ('that.', 60),
#  ('actually', 58),
#  ('life,', 58),
#  ('came', 58),
#  ('public', 58),
#  ('become', 58),
#  ('whole', 58),
#  ('well', 58),
#  ('?', 56),
#  ('...', 56),
#  ('"Did', 56),
#  ('found', 56),
#  ('hate', 56),
#  ('high', 56),
#  ('asked', 56),
#  ("there's", 56),
#  ('keep', 56),
#  ('you.', 56),
#  ('i', 54),
#  ('help', 54),
#  ('few', 54),
#  ('understand', 54),
#  ('family', 54),
#  ('film', 54),
#  ('done', 54),
#  ('nothing', 54),
#  ('saw', 54),
#  ('friend', 54),
#  ('three', 54),
#  ('favorite', 52),
#  ('walk', 52),
#  ('less', 52),
#  ('mind', 52),
#  ('once', 52),
#  ('.', 50),
#  ('it."', 50),
#  ('able', 50),
#  ('American', 50),
#  ('New', 50),
#  ('All', 50),
#  ('today', 50),
#  ('"I\'m', 48),
#  ('dog', 48),
#  ('end', 48),
#  ("couldn't", 48),
#  ('sense', 48),
#  ('reason', 48),
#  ('show', 48),
#  ('might', 48),
#  ('leave', 48),
#  ('read', 48),
#  ('gay', 46),
#  ('feeling', 46),
#  ('baby', 46),
#  ("Don't", 46),
#  ("wasn't", 46),
#  ('mean', 46),
#  ('means', 46),
#  ("we're", 46),
#  ('time,', 46),
#  ('idea', 46),
#  ('eat', 46),
#  ('others', 46),
#  ('"When', 44),
#  ('year', 44),
#  ('pay', 44),
#  ('until', 44),
#  ('&', 44),
#  ('friends', 44),
#  ('goes', 44),
#  ('Every', 44),
#  ('People', 44),
#  ('As', 44),
#  ('everyone', 44),
#  ('true', 44),
#  ('people.', 44),
#  ('times', 44),
#  ('greatest', 44),
#  ('wrong', 44),
#  ('start', 44),
#  ('girlfriend', 42),
#  ('sex', 42),
#  ("he's", 42),
#  ('yourself', 42),
#  ('learn', 42),
#  ('left', 42),
#  ('hold', 42),
#  ('Why', 42),
#  ('At', 42),
#  ('people,', 42),
#  ('school', 42),
#  ('do.', 42),
#  ('run', 42),
#  ('bring', 42),
#  ('Most', 42),
#  ('country', 42),
#  ('anyone', 42),
#  ('cross', 40),
#  ('How', 40),
#  ('buy', 40),
#  ('saying', 40),
#  ("isn't", 40),
#  ('another', 40),
#  ('gonna', 40),
#  ('gave', 40),
#  ('guess', 40),
#  ("won't", 40),
#  ('young', 40),
#  ('body', 40),
#  ('whether', 40),
#  ('"You', 38),
#  ('mom', 38),
#  ('hand', 38),
#  ("They're", 38),
#  ('under', 38),
#  ('you,', 38),
#  ('far', 38),
#  ('rather', 38),
#  ('heart', 38),
#  ("wouldn't", 38),
#  ('living', 38),
#  ('is,', 38),
#  ('here', 38),
#  ('certain', 38),
#  ('problem', 38),
#  ('win', 38),
#  ('half', 38),
#  ("There's", 38),
#  ('lost', 38),
#  ('money', 38),
#  ('stop', 38),
#  ('!"', 36),
#  ('""I', 36),
#  ('cut', 36),
#  ('write', 36),
#  ('least', 36),
#  ('trying', 36),
#  ('probably', 36),
#  ('world.', 36),
#  ('number', 36),
#  ('matter', 36),
#  ('care', 36),
#  ('enough', 36),
#  ('guys', 36),
#  ('days', 36),
#  ('took', 36),
#  ('hope', 36),
#  ('dance', 36),
#  ('talk', 36),
#  ('kids', 36),
#  ('full', 36),
#  ('enjoy', 36),
#  ('power', 36),
#  ('learned', 36),
#  ('loved', 36),
#  ('wants', 36),
#  ('watch', 36),
#  ('boy', 34),
#  ('asks', 34),
#  ('3', 34),
#  ('ME:', 34),
#  ('dead', 34),
#  ("you've", 34),
#  ('An', 34),
#  ('wear', 34),
#  ('using', 34),
#  ('control', 34),
#  ('truth', 34),
#  ('spend', 34),
#  ('fight', 34),
#  ('word', 34),
#  ('second', 34),
#  ('face', 34),
#  ('deal', 34),
#  ('quite', 34),
#  ('way.', 34),
#  ('bit', 34),
#  ('talking', 34),
#  ('children', 34),
#  ('behind', 34),
#  ('name', 34),
#  ('sort', 34),
#  ('"Two', 32),
#  ('already', 32),
#  ('realize', 32),
#  ('Now', 32),
#  ('started', 32),
#  ('girls', 32),
#  ('say,', 32),
#  ('worse', 32),
#  ('house', 32),
#  ('room', 32),
#  ('lose', 32),
#  ('played', 32),
#  ('felt', 32),
#  ('Do', 32),
#  ('Not', 32),
#  ('movie', 32),
#  ('away', 32),
#  ('Sometimes', 32),
#  ('five', 32),
#  ('know,', 32),
#  ('remember', 32),
#  ('free', 32),
#  ('tried', 32),
#  ('game', 32),
#  ('simply', 32),
#  ('"Just', 30),
#  ('art', 30),
#  ('marriage', 30),
#  ('car', 30),
#  ('heard', 30),
#  ('create', 30),
#  ('small', 30),
#  ('said,', 30),
#  ("she's", 30),
#  ('completely', 30),
#  ('together', 30),
#  ('easy', 30),
#  ('else', 30),
#  ('blind', 30),
#  ('easier', 30),
#  ('greater', 30),
#  ('doctor', 30),
#  ('Just', 30),
#  ('upon', 30),
#  ('past', 30),
#  ('kill', 30),
#  ('now.', 30),
#  ('almost', 30),
#  ('certainly', 30),
#  ('war', 30),
#  ('America', 30),
#  ('fun', 30),
#  ('out.', 30),
#  ('acting', 30),
#  ('ask', 30),
#  ('like,', 30),
#  ('sitting', 30),
#  ('knew', 30),
#  ('eating', 28),
#  ('white', 28),
#  ('Turkey', 28),
#  ('hit', 28),
#  ('necessarily', 28),
#  ('sometimes', 28),
#  ('themselves', 28),
#  ('die', 28),
#  ('hair', 28),
#  ('natural', 28),
#  ('story', 28),
#  ('ones', 28),
#  ('since', 28),
#  ('shall', 28),
#  ('government', 28),
#  ('please', 28),
#  ('stand', 28),
#  ('bar', 28),
#  ('love,', 28),
#  ('happens', 28),
#  ("what's", 28),
#  ('day.', 28),
#  ('playing', 28),
#  ('walking', 28),
#  ('person.', 28),
#  ('us.', 28),
#  ('whatever', 28),
#  ('world,', 28),
#  ('forget', 28),
#  ('2', 26),
#  ('drink', 26),
#  ('A:', 26),
#  ('common?', 26),
#  ('jokes', 26),
#  ('group', 26),
#  ('night', 26),
#  ('knock', 26),
#  ('looks', 26),
#  ('wonder', 26),
#  ("He's", 26),
#  ('favourite', 26),
#  ('listen', 26),
#  ('music.', 26),
#  ('open', 26),
#  ('fall', 26),
#  ('seen', 26),
#  ('meet', 26),
#  ('fell', 26),
#  ('phone', 26),
#  ('act', 26),
#  ('stuff', 26),
#  ('save', 26),
#  ('turn', 26),
#  ('four', 26),
#  ("one's", 26),
#  ('form', 26),
#  ('faith', 26),
#  ('worst', 26),
#  ('definitely', 26),
#  ('early', 26),
#  ('piece', 26),
#  ("haven't", 26),
#  ('quality', 26),
#  ('becomes', 26),
#  ('good,', 26),
#  ('history', 26),
#  ('interested', 26),
#  ('actor', 26),
#  ('nobody', 26),
#  ('seems', 26),
#  ('thing.', 26),
#  ('hands', 26),
#  ('build', 26),
#  ('experience', 26),
#  ('problems', 26),
#  ('dream', 26),
#  ('do,', 26),
#  ('her.', 26),
#  ('respect', 26),
#  ('mean,', 26),
#  ('thinking', 26),
#  ('stay', 26),
#  ("you'll", 26),
#  ('bulb?', 24),
#  ("What's", 24),
#  ('Trump', 24),
#  ('dad', 24),
#  ('type', 24),
#  ('head', 24),
#  ('worth', 24),
#  ('terrible', 24),
#  ('possible', 24),
#  ('point', 24),
#  ('front', 24),
#  ('TV', 24),
#  ('From', 24),
#  ('kid', 24),
#  ('during', 24),
#  ('lead', 24),
#  ('sleep', 24),
#  ('Is', 24),
#  ('death', 24),
#  ('them,', 24),
#  ('learning', 24),
#  ('Michael', 24),
#  ('nature', 24),
#  ('given', 24),
#  ('political', 24),
#  ('Some', 24),
#  ('gives', 24),
#  ('drive', 24),
#  ('words', 24),
#  ('happiness', 24),
#  ('Man', 24),
#  ('God,', 24),
#  ('work.', 24),
#  ('move', 24),
#  ('one.', 24),
#  ('business', 24),
#  ('up.', 24),
#  ('says,', 22),
#  ('police', 22),
#  ('me."', 22),
#  ('"Me:', 22),
#  ('"Q:', 22),
#  ('road?', 22),
#  ('son', 22),
#  ('Mexican', 22),
#  ('door', 22),
#  ('fat', 22),
#  ('5', 22),
#  ('Your', 22),
#  ('himself', 22),
#  ('8', 22),
#  ('Those', 22),
#  ('child', 22),
#  ('red', 22),
#  ('watching', 22),
#  ('tells', 22),
#  ('huge', 22),
#  ('finally', 22),
#  ('ways', 22),
#  ('Americans', 22),
#  ('works', 22),
#  ('Our', 22),
#  ('eyes', 22),
#  ('career', 22),
#  ('Everyone', 22),
#  ('personal', 22),
#  ('him,', 22),
#  ('grew', 22),
#  ('yourself.', 22),
#  ('taken', 22),
#  ('is.', 22),
#  ('set', 22),
#  ('United', 22),
#  ('keeps', 22),
#  ('there.', 22),
#  ('coming', 22),
#  ('time.', 22),
#  ('Unless', 22),
#  ('needs', 22),
#  ('difficult', 22),
#  ('all.', 22),
#  ('mother', 22),
#  ('beautiful', 22),
#  ('takes', 22),
#  ('future', 22),
#  ('state', 22),
#  ('that,', 22),
#  ("You're", 22),
#  ('u', 20),
#  ('screw', 20),
#  ('fucking', 20),
#  ('bar...', 20),
#  ('"There', 20),
#  ('"This', 20),
#  ('cow', 20),
#  ('shit', 20),
#  ('walked', 20),
#  ('cat', 20),
#  ('turns', 20),
#  ('water', 20),
#  ('leaving', 20),
#  ('named', 20),
#  ('decided', 20),
#  ('dies', 20),
#  ("you'd", 20),
#  ('players', 20),
#  ('funny', 20),
#  ('age', 20),
#  ('nice', 20),
#  ('running', 20),
#  ('trust', 20),
#  ('everybody', 20),
#  ('caught', 20),
#  ('bought', 20),
#  ('War', 20),
#  ('others.', 20),
#  ('writing', 20),
#  ('sit', 20),
#  ('know.', 20),
#  ('though', 20),
#  ('sick', 20),
#  ('Christmas', 20),
#  ('date', 20),
#  ('Like', 20),
#  ('step', 20),
#  ('months', 20),
#  ('smaller', 20),
#  ('written', 20),
#  ('along', 20),
#  ('against', 20),
#  ('large', 20),
#  ('hours', 20),
#  ('years.', 20),
#  ('laugh', 20),
#  ('grow', 20),
#  ('forward', 20),
#  ('anything.', 20),
#  ('films', 20),
#  ('taking', 20),
#  ('seem', 20),
#  ('Many', 20),
#  ('fan', 20),
#  ('born', 20),
#  ('answer', 20),
#  ('biggest', 20),
#  ('knowledge', 20),
#  ('national', 20),
#  ('be.', 20),
#  ('movies', 20),
#  ('needed', 20),
#  ('fans', 20),
#  ('involved', 20),
#  ('album', 20),
#  ('liked', 20),
#  ('sad', 20),
#  ('chance', 20),
#  ('Life', 20),
#  ('students', 20),
#  ('education', 20),
#  ('success', 20),
#  ('helps', 20),
#  ('within', 20),
#  ('Great', 20),
#  ('figure', 20),
#  ('much.', 20),
#  ('key', 20),
#  ('instead', 20),
#  ('you."', 18),
#  ('bed', 18),
#  ('"Don\'t', 18),
#  ('hole', 18),
#  ('ate', 18),
#  ('"Who', 18),
#  ('them."', 18),
#  ('THE', 18),
#  ('chicken', 18),
#  ('blonde', 18),
#  ('daughter', 18),
#  ('legs', 18),
#  ('picture', 18),
#  ('taste', 18),
#  ('short', 18),
#  ('30', 18),
#  ('lived', 18),
#  ('stuck', 18),
#  ('serve', 18),
#  ('won', 18),
#  ('late', 18),
#  ('classical', 18),
#  ('itself', 18),
#  ('country.', 18),
#  ("who's", 18),
#  ('dress', 18),
#  ('houses', 18),
#  ('feed', 18),
#  ('growing', 18),
#  ('present', 18),
#  ('joy', 18),
#  ('died', 18),
#  ('wait', 18),
#  ('cause', 18),
#  ("We're", 18),
#  ('Even', 18),
#  ('supposed', 18),
#  ('built', 18),
#  ('on.', 18),
#  ('entire', 18),
#  ('food', 18),
#  ('radio', 18),
#  ('Then', 18),
#  ('bus', 18),
#  ('speed', 18),
#  ('Nothing', 18),
#  ('sounds', 18),
#  ('powerful', 18),
#  ('turned', 18),
#  ('book', 18),
#  ('fool', 18),
#  ('six', 18),
#  ("man's", 18),
#  ('wearing', 18),
#  ('but,', 18),
#  ('attention', 18),
#  ('proud', 18),
#  ('character', 18),
#  ('fact', 18),
#  ('him.', 18),
#  ('today.', 18),
#  ('ideas', 18),
#  ('known', 18),
#  ('emotional', 18),
#  ('moment', 18),
#  ('soul', 18),
#  ('father', 18),
#  ('secret', 18),
#  ("people's", 18),
#  ('things.', 18),
#  ('Well,', 18),
#  ('rich', 18),
#  ('English', 18),
#  ('community', 18),
#  ('His', 18),
#  ('peace', 18),
#  ('support', 18),
#  ('cool', 18),
#  ('stage', 18),
#  ("God's", 18),
#  ('myself.', 18),
#  ('sing', 18),
#  ('comfortable', 18),
#  ('Only', 18),
#  ('success.', 18),
#  ('mostly', 18),
#  ('hundred', 18),
#  ('""You', 16),
#  ('hot', 16),
#  ('6', 16),
#  ('dude', 16),
#  ('"They', 16),
#  ('Jesus', 16),
#  ('"So', 16),
#  ('replies', 16),
#  ('12', 16),
#  ('fuck', 16),
#  ('cheese', 16),
#  ('online', 16),
#  ('1', 16),
#  ('alone', 16),
#  ('lie', 16),
#  ('notice', 16),
#  ('longer', 16),
#  ('invented', 16),
#  ('successful', 16),
#  ('break', 16),
#  ('Chinese', 16),
#  ('unless', 16),
#  ('question', 16),
#  ('parents', 16),
#  ('teaching', 16),
#  ('harmony', 16),
#  ('decide', 16),
#  ('relationship', 16),
#  ('accept', 16),
#  ('usually', 16),
#  ('inside', 16),
#  ('better.', 16),
#  ('with.', 16),
#  ('reality', 16),
#  ('sound', 16),
#  ('fish', 16),
#  ('single', 16),
#  ('dogs', 16),
#  ('pictures', 16),
#  ('strong', 16),
#  ('older', 16),
#  ('Good', 16),
#  ('home,', 16),
#  ('together.', 16),
#  ('culture', 16),
#  ('common', 16),
#  ('sign', 16),
#  ('blood', 16),
#  ('company', 16),
#  ('day,', 16),
#  ('close', 16),
#  ('After', 16),
#  ('absolutely', 16),
#  ('On', 16),
#  ('up,', 16),
#  ('to.', 16),
#  ('music,', 16),
#  ('voice', 16),
#  ('course,', 16),
#  ('soon', 16),
#  ('10', 16),
#  ('drunk', 16),
#  ('too.', 16),
#  ('animal', 16),
#  ('plenty', 16),
#  ('economy', 16),
#  ('rule', 16),
#  ('simple', 16),
#  ('Who', 16),
#  ('Muslim', 16),
#  ('morning', 16),
#  ('themselves.', 16),
#  ("other's", 16),
#  ('tree', 16),
#  ('other.', 16),
#  ('fire', 16),
#  ('all,', 16),
#  ('fine', 16),
#  ('towards', 16),
#  ('view', 16),
#  ('wish', 16),
#  ('not,', 16),
#  ('believed', 16),
#  ('attitude', 16),
#  ('values', 16),
#  ('Day', 16),
#  ('media', 16),
#  ('spiritual', 16),
#  ('spent', 16),
#  ('creative', 16),
#  ('anybody', 16),
#  ('religious', 16),
#  ('fighting', 16),
#  ('owe', 16),
#  ('nor', 16),
#  ('again', 16),
#  ('vote', 16),
#  ('pass', 16),
#  ('giving', 16),
#  ('God.', 16),
#  ('York', 16),
#  ('private', 16),
#  ('character.', 16),
#  ('aware', 16),
#  ('hard.', 16),
#  ('fear', 16),
#  ('role', 16),
#  ('lives', 16),
#  ('process', 16),
#  ('strength', 16),
#  ('failure', 16),
#  ('courage', 16),
#  ('about.', 16),
#  ('financial', 16),
#  ('popular', 16),
#  ('Never', 16),
#  ('Dog:', 14),
#  ('hell', 14),
#  ('pizza', 14),
#  ('Two', 14),
#  ('"Do', 14),
#  ('joke.', 14),
#  ('up."', 14),
#  ('YOU', 14),
#  ('"Sometimes', 14),
#  ('midget', 14),
#  ('bartender', 14),
#  ('4', 14),
#  ('""Do', 14),
#  ('"Where', 14),
#  ('it"', 14),
#  ('elephants', 14),
#  ('forgot', 14),
#  ('"I\'ve', 14),
#  ('met', 14),
#  ('third', 14),
#  ('dark', 14),
#  ('manager', 14),
#  ('remind', 14),
#  ('fake', 14),
#  ('England', 14),
#  ('click', 14),
#  ...]

# %%
MIN_WORD_FREQUENCY
# Out:
# 12

# %%
ignored_words = set()
for k, v in word_freq.items():
    if word_freq[k] < MIN_WORD_FREQUENCY:
        ignored_words.add(k)

# %%
words
# Out:
# {'hug',
#  'wait,',
#  'bathroom]',
#  'survives.',
#  'Dust"',
#  'Said',
#  'preceding',
#  'bleeds',
#  'control."',
#  'number',
#  'procedure',
#  'astounded',
#  'warring',
#  'cold,',
#  'drug',
#  'shower',
#  'something,',
#  'Deep',
#  'anymore...."""',
#  'use?',
#  'apron',
#  'Vagisil',
#  'hold',
#  'doing,',
#  'being.',
#  'goose',
#  'player.',
#  'somebody.',
#  'Papal',
#  'days.',
#  'Bar.',
#  'corners',
#  'careful.',
#  'frustrated',
#  'camera',
#  'compassion',
#  'spending',
#  'PC"""',
#  '""world',
#  'Largest',
#  '76',
#  'Kum"',
#  'sluts',
#  'despair',
#  'hit.',
#  '"Tom',
#  'Ken.',
#  'revolves',
#  'exhausted',
#  '""oh',
#  'ant',
#  'fuss.',
#  'yourself.',
#  'excellence.',
#  'miss."',
#  '"WHat\'s',
#  'it?"',
#  "day's",
#  "roamin'",
#  'Thanks',
#  'drugs.',
#  'tough-skinned',
#  "actor.'",
#  'objective.',
#  'served',
#  'bought',
#  'fight',
#  'faith,',
#  'They."',
#  'sub',
#  'tenderness,',
#  'guy:',
#  'chance',
#  'Rogue',
#  'spell',
#  'spontaneity.',
#  'jeans?',
#  '"Get',
#  'drama',
#  'slowly?',
#  'adultery',
#  'pull',
#  'gentlemen',
#  'electricity.',
#  'straight,',
#  'Adobe',
#  'Tots',
#  'dog?',
#  'Club',
#  'extra',
#  'acquired',
#  'people?"',
#  'woodland.',
#  'Tournament',
#  'Edward',
#  'SWORE',
#  'Alabama',
#  'situations',
#  'Americans?',
#  'Chips!"',
#  'surrounded',
#  'chainsaw."',
#  'laughed.',
#  'lows',
#  '"Jared',
#  'field."',
#  'gentle',
#  'original.',
#  'Galaxy',
#  'mystery.',
#  'seed',
#  'battle,',
#  'life."""',
#  'closet?',
#  'rid',
#  'first-world',
#  'wandering',
#  '""incorrect""',
#  'lots',
#  'footpath',
#  'Girlfriend',
#  'directs',
#  'ice?',
#  '""We\'ve',
#  'Wandering',
#  'twenty-four',
#  'provide,',
#  'nihilist',
#  'drowning?',
#  'second."',
#  'novel',
#  'Ever',
#  'criticism,',
#  '""Please',
#  'blaming',
#  'trouble.',
#  'Making',
#  'dying.',
#  'magnificent',
#  'mean.',
#  'Were',
#  'bacteria',
#  '"Microsoft',
#  'photo',
#  'Steinway.',
#  'get?',
#  'vender',
#  'blackest',
#  'bastard!"',
#  'tall.',
#  '"technically',
#  'shower""',
#  'symbolism,',
#  'interesting',
#  '""babe',
#  'gracious',
#  'guitar*',
#  'porn',
#  'wallet.',
#  'insult',
#  'lawyers',
#  'Pushing',
#  '"what',
#  'self.',
#  'Porky-Pine"',
#  'Bros',
#  'otherwise',
#  'bullets,',
#  'Going',
#  'hospitality,',
#  'moment',
#  'too,',
#  'passionate',
#  'bum',
#  'retiring.',
#  'that:',
#  'BOTH',
#  "frog's",
#  'tomorrow.',
#  'discovery',
#  'reminiscent',
#  'kingdom',
#  'dramatic',
#  'runt',
#  'buy...',
#  'denying',
#  'kind',
#  'Recreational',
#  'Iraq.',
#  'low.',
#  'tastes',
#  'nor',
#  'parrot',
#  'Tom',
#  'Wrath',
#  'Friends."',
#  'wars?',
#  'gear,',
#  'Animal',
#  'dog...',
#  'posting',
#  'pardon,',
#  'inch.',
#  'restaurant',
#  'god.',
#  'unimportant,',
#  'foment',
#  'followed,',
#  'recovery.',
#  'nations;',
#  'Rush',
#  'sport.',
#  '5."',
#  'carbs."""',
#  'ISIS',
#  '/r/news',
#  '"[describing',
#  "kids.'",
#  'Smokey',
#  'two-income',
#  'scary',
#  'bulk',
#  'fleeting',
#  'please""',
#  'op."',
#  'disguised',
#  'cabin.',
#  'stage,',
#  'celebrity',
#  'captivating',
#  'improve.',
#  'Sunday,',
#  'bored',
#  'mutiny',
#  'potential',
#  'Nobody',
#  'persons',
#  'reminder',
#  'character',
#  'exciting,',
#  'work)"',
#  'Pepsi',
#  '...boy',
#  'forever',
#  'images',
#  '""Because',
#  'small',
#  'p*nis',
#  '9?',
#  'eventually.',
#  'challenging,',
#  'felt',
#  'agree',
#  'paints',
#  'begets',
#  'Music,',
#  'balance.',
#  'strangest',
#  'Grant.',
#  'circumcisions...',
#  'leather.',
#  'revolve',
#  'him."',
#  'Wears',
#  'empowers',
#  "'Look,",
#  'bigot.',
#  'ass."',
#  'VHS',
#  'Knock',
#  'bacon?',
#  'buck',
#  'stealing?',
#  'actors',
#  'option.',
#  'liable',
#  'Nickelback...',
#  '*to',
#  'situations,',
#  'Once',
#  'Style',
#  'airline',
#  'delicious!"',
#  'hand-riven',
#  'Ew."',
#  'too."',
#  '"Right',
#  'peoples.',
#  'Luciferian',
#  'Island,',
#  'waistcoat?',
#  'praise.',
#  'footman',
#  'Chocula',
#  "Scamentine's",
#  'discharged',
#  'Man/Boy',
#  'people:',
#  'problem?',
#  'area,',
#  'boiling,',
#  '2000',
#  'steering',
#  'damn.',
#  'skin,',
#  'clever',
#  'book',
#  'printed.',
#  'infinitely',
#  'nutritionist',
#  'book.',
#  'bathroom',
#  'abuse',
#  '...do',
#  'Several',
#  'Freedom',
#  'latte',
#  'Online',
#  'unhappily',
#  'long-haul',
#  'Warfare:',
#  'tea',
#  'please?',
#  'divorce',
#  'rent',
#  'gluttony',
#  'laws,',
#  'bitch"',
#  'universe',
#  'symptoms',
#  'spin',
#  'accident."',
#  'Alone!',
#  'it.)"',
#  'trapeze',
#  'loan,',
#  'standard,',
#  'crime',
#  'career,',
#  'consisting',
#  'naughty!',
#  'On."',
#  'and,',
#  'We,',
#  'consciousness.',
#  'stems',
#  '"Yes,',
#  'bell',
#  'lips."',
#  'reply',
#  'spheres',
#  'recognise',
#  'Wolf,',
#  'unfree',
#  'fathers',
#  'Vienna,',
#  'Playboy.',
#  'myself"',
#  '[Fill',
#  'crisis"',
#  'dead?"',
#  'front',
#  'light-hearted?',
#  'Zach',
#  'erroneously',
#  'cognac',
#  'ski?',
#  'kinds',
#  'lawyer?',
#  'conveniently',
#  'ho""."',
#  'second.',
#  'nintendo',
#  'occurs.',
#  'Evaporated',
#  'orgasm',
#  'while,',
#  'Mexico',
#  'messages.',
#  'management',
#  'J.G.',
#  'stunts"',
#  'blindly',
#  "other's",
#  'like?""',
#  'penalties',
#  'pricks',
#  'lesbian;',
#  'COP:',
#  'herself.""',
#  'rule."',
#  'general',
#  'gym',
#  'today.....',
#  'post-high',
#  'continentally.',
#  'yelled',
#  'pre-mature',
#  'sealed',
#  '"A',
#  'reply.',
#  'Dog."',
#  'shown',
#  'Normous',
#  "Didn't",
#  'gently',
#  'before?',
#  'hoping',
#  'Live',
#  '""Meow""',
#  'style?',
#  'afterwards.',
#  'qualities,',
#  '5.',
#  'Escher',
#  'City',
#  'skills."',
#  'gay',
#  'groove',
#  "whatever.'",
#  'eliminate',
#  'dead"',
#  'virginity',
#  'sorrow.',
#  'Taliban.',
#  'Ultraconservatism',
#  'god',
#  'dogs...',
#  'recipe',
#  '""Make',
#  'Those',
#  'array',
#  'sorrow,',
#  'decreases',
#  'fans,',
#  'girl',
#  'IN',
#  'movement',
#  'Doing',
#  'Ray.',
#  'orthodox',
#  'fortunate;',
#  'silly',
#  'dance,',
#  '""We\'ll',
#  'smoking',
#  'Pilgrims',
#  'pays',
#  'lacking,',
#  'question',
#  'over.',
#  'fulfillment',
#  'animated',
#  'keys',
#  'multiple',
#  "fuckin'",
#  'service."',
#  'wicked',
#  'asks,',
#  "'head",
#  'someone',
#  'done',
#  'tests',
#  'minutes,',
#  'game.',
#  'Alfred',
#  'that?"',
#  'disease',
#  'hooked',
#  'baptize',
#  'meet."',
#  'increase',
#  'hated',
#  'working;',
#  'quilted',
#  'cheap',
#  'fun,',
#  'deconstruct',
#  'assumptions',
#  'beginning',
#  "one's",
#  'new.',
#  'perceive',
#  'Ace',
#  '""They',
#  '-Can',
#  "who'll",
#  'wanted."',
#  'rebel,',
#  'Guy:',
#  'select',
#  'career?"',
#  'rightly,',
#  'dog,',
#  'grenade',
#  'witherings,',
#  'Rockies',
#  'Cruiser',
#  'delight*"',
#  'religions,',
#  "'Dhoom,'",
#  '5',
#  'dominance.',
#  "'That",
#  'Profile',
#  'car.',
#  '"CNN:',
#  'supposed',
#  'burying',
#  'Republic',
#  'once.',
#  'audience',
#  'Acting',
#  'sear',
#  '"Today',
#  'Four',
#  'enamored',
#  'Apple',
#  '...when',
#  'systems.All',
#  'boxes',
#  'brothers',
#  'assault....',
#  'succeeded',
#  'drama"',
#  'acceptable,',
#  'relationship',
#  'tonight',
#  'ninth',
#  'play,',
#  'Theater',
#  'food,',
#  'debut',
#  'anorexic',
#  '"TIFU',
#  'month??',
#  'Souvlaki',
#  'pictures.',
#  'architecture.',
#  'Jackson,',
#  'warrant',
#  'nation,',
#  'wishy-washy,',
#  'due',
#  'protected.',
#  'Sheep?',
#  'misunderstanding,',
#  '..asks',
#  'multiple,',
#  'Really',
#  'worried.',
#  '*pass',
#  "'Roots'",
#  'heavier',
#  'Ossetra',
#  'culture"',
#  'desert',
#  'Ivana',
#  'Olive',
#  '&amp;',
#  'Company',
#  'same.',
#  'illusion',
#  'bulbs.',
#  'cat-ass-trophy."',
#  'lives.',
#  'Whey.',
#  'harness',
#  'What?',
#  'impression.',
#  'crap',
#  'Lisa*',
#  'livid."',
#  "DON'T",
#  'become',
#  'whence',
#  'pants."',
#  'conversely,',
#  'right?',
#  'Mad,',
#  'pigs',
#  'sad?',
#  'more,',
#  'decided',
#  'bodhisattva',
#  'stranger!"""',
#  'clouds',
#  'colonists.',
#  'neighbor',
#  'ladder."',
#  'ones.',
#  '"What',
#  "Newton's",
#  'people',
#  'Old',
#  '*smiles',
#  'elements.',
#  'ADD',
#  '-',
#  'records.',
#  'cakes',
#  'antagonise',
#  'entities',
#  'shirt',
#  'leave',
#  'hire',
#  '$10',
#  "'60s,",
#  'sick!',
#  '...I',
#  'Saw',
#  'laundromat',
#  'Character',
#  'invented',
#  'reaction."',
#  'Fish',
#  'person."',
#  'porcupine?',
#  'birds.',
#  'brexit',
#  'host!"""',
#  'holocaust?""',
#  'title."',
#  'sticks',
#  'children."',
#  'bathroom?',
#  'moss',
#  'neighbors',
#  ".....we're",
#  'Story',
#  'Hitler?',
#  'bar*',
#  'water,',
#  'Sparky"',
#  'permit',
#  'Indians.',
#  '(brother',
#  'meatball',
#  'to,',
#  'sportsman,',
#  'eighteen',
#  'Iran',
#  'Halliburton.',
#  'yeah,',
#  'answering',
#  'hires',
#  'candles',
#  'name.""',
#  'passage',
#  'Dream.',
#  'Juan',
#  '"Girls',
#  'me;',
#  'body.',
#  'letter,',
#  'field"',
#  'Chinese',
#  'camera.',
#  'nun',
#  'Yeah,',
#  'marched',
#  'Could',
#  'trailer',
#  'creates',
#  'satisfy',
#  'Ark-hives."',
#  'stick."',
#  'severe.',
#  'mouthful,',
#  's?uts.',
#  'in',
#  'wishes.',
#  '""He',
#  'buy',
#  'cousins,',
#  'intelligent',
#  'eggs-terminated."',
#  'Florida',
#  'variable."',
#  'great!"',
#  'it!"',
#  'nostalgic',
#  'tickles"',
#  'person)"',
#  'Pronounce',
#  'obedient',
#  'security.',
#  'tuna.',
#  'departments',
#  'circumcise',
#  'format',
#  'personally,',
#  'give.',
#  'weed?',
#  'development.',
#  'workout?',
#  'Hat""',
#  'breakfast.',
#  'snow.',
#  'ruin.',
#  'Service',
#  '*he',
#  'allow',
#  'BATMAN',
#  '"why',
#  'dollars?""',
#  '"',
#  'items.',
#  'nutrigun*',
#  'Hahaha"',
#  'Malayasia',
#  'greed',
#  'power,',
#  'Fortune',
#  'chart,',
#  'solo',
#  'screaming',
#  '"Any',
#  'criminal',
#  'pain.',
#  'analog',
#  'watch.',
#  'soccer,',
#  'holy',
#  'Snipper"',
#  'low."',
#  'Paris,',
#  '""do',
#  '23',
#  'vampire',
#  '"NSFW',
#  'pub',
#  'J.',
#  'shop.',
#  'ago,',
#  'far,',
#  'abs',
#  'discriminate',
#  'subtweeting',
#  'objectives;',
#  'drawn,',
#  'month',
#  'premature',
#  'capture',
#  'futile.',
#  'impacted',
#  'Girl',
#  'password"',
#  'Hitler',
#  'turning',
#  'STIFF',
#  'everything,',
#  'assistants.',
#  'one,',
#  'scan',
#  'follow',
#  'nap',
#  'CHEESE',
#  'doorbell.',
#  'friend?',
#  'radio""."',
#  'walled',
#  'tomorrow."',
#  'not""',
#  'ethnic',
#  'location.',
#  'lifestyle',
#  'toy',
#  'creation.',
#  'serving',
#  'Are',
#  'eggs""',
#  'elevator,',
#  'Success',
#  'rationally,',
#  'nowadays',
#  'Wizard',
#  'genuinely',
#  'design.',
#  'Americanism,',
#  'Honestly,',
#  '"Recently',
#  'hotel."',
#  'olympics?',
#  'Pedophilia?',
#  'happen.',
#  'flour',
#  'minutes."',
#  'idiotic',
#  'decreased',
#  'forgetting',
#  'shuts',
#  'Jamestown,',
#  'ordeal.',
#  'Justice,',
#  'show.',
#  'bore',
#  'musician',
#  'unawakened.',
#  'species',
#  'participation.',
#  'fingernail',
#  '"Follow',
#  'walksies',
#  'type',
#  'obstacles;',
#  'rehearsal',
#  'loaf',
#  'up"',
#  'subreddit',
#  'equate',
#  'Bomb',
#  'seldom',
#  'contentment',
#  'giants',
#  'Mosque',
#  'bit.',
#  "alzheimer's?",
#  'butts...',
#  'pig,',
#  'attempt,',
#  '"INTERVIEWER:',
#  "You'll",
#  'took',
#  'campuses',
#  'encompasses',
#  'without',
#  'fetish',
#  'journey',
#  'Mutton',
#  'marches,',
#  'Trooper',
#  'despair,',
#  'unmarried.',
#  'rooms"',
#  'Man"',
#  'lead.',
#  'evening',
#  'Spit,',
#  'rubbing',
#  'hangout?""',
#  'Facebook."',
#  'loud',
#  'nothing,',
#  'father.',
#  'hyper-cinematic.',
#  'substance',
#  'Thanksgiving..',
#  'matters.',
#  'dictates',
#  'majestic',
#  'roses',
#  'Door"""',
#  'Tulips',
#  'sucks',
#  'da',
#  'Wife',
#  '[slides',
#  'accident.',
#  'Grandmaster',
#  'more?"',
#  'shaman',
#  'quest',
#  'traits,',
#  'Harvey',
#  'membership,',
#  '$15.99',
#  'psychologists',
#  'house?',
#  'happiness;',
#  'wall,',
#  '"Pinocchio',
#  'reader;',
#  'dying,',
#  'worthy',
#  'PILOT,',
#  'series',
#  'Conversation',
#  'gardens,',
#  'slutty',
#  'obscure',
#  'Bacon',
#  'understood',
#  'Frankness',
#  'manager"',
#  'kangaroo',
#  'exciting',
#  'cause',
#  'kicked-in',
#  'collection,',
#  'posing.',
#  'thrown',
#  'Scotsmen',
#  'talk,',
#  'retaining',
#  'synagogue',
#  'adversity.',
#  '*hands',
#  'tips',
#  "model's",
#  'Christmas?',
#  'trash.....',
#  'Road',
#  'grass?',
#  '""happily',
#  "'Bewitched'",
#  'goals.',
#  '5,',
#  'victorious',
#  'Reddit',
#  'mosquito',
#  'poison',
#  'killing',
#  'Positive',
#  'around"',
#  'tank',
#  'Neither',
#  'wet',
#  'margin',
#  'son',
#  'ingredients,',
#  'la',
#  'Indians,',
#  'sad',
#  'criticizing',
#  '"Now',
#  'EW',
#  'teaser,',
#  "Treacher's",
#  'flying',
#  'hip-hop',
#  'divine.',
#  'nation',
#  'beautiful',
#  'costume,',
#  'fundamentalists',
#  '"Anyone',
#  'tendency',
#  'freezer,',
#  'alive',
#  'widely',
#  'arctic*"',
#  'goal.',
#  'younger',
#  'feeling,',
#  'true.',
#  'Rorschach',
#  'punishment.',
#  'momentary',
#  'idiot?\'\'"',
#  'thread."',
#  'smiles',
#  'notes',
#  'co-exist?',
#  'Nuclear',
#  'Place',
#  'exit',
#  'wise',
#  'Netanya',
#  "year's",
#  'others."',
#  '"Whats',
#  'ranch"',
#  '"[commercial]',
#  'real.',
#  't',
#  'kids.',
#  'choose',
#  'Brazil?',
#  'express',
#  'yet."',
#  'pure.',
#  'ditch?',
#  'adj.',
#  'that...."',
#  'sunshine.',
#  'anywhere.""',
#  'needed',
#  'ahead',
#  'hang-ups',
#  'polish,',
#  'arrive',
#  'dance.',
#  '"Kill',
#  'dozen',
#  'CONFUSED',
#  'ultimate',
#  'successfull',
#  'hours',
#  'compromised',
#  'reptile',
#  'teams',
#  'Cat-has-trophy.',
#  'masochist.',
#  'fixed',
#  'minutes!',
#  '75""',
#  '*Snoops',
#  'complexities',
#  "Laden's",
#  ...}

# %%
words = set(text_in_words)
words.add("#@Joke")
words.add("#@Quote")
words.add("#@NoTag")

print('Unique words before ignoring:', len(words))
print('Ignoring words with frequency <', MIN_WORD_FREQUENCY)
#words = sorted(set(words) - ignored_words)
print('Unique words after ignoring:', len(words))
print_vocabulary(vocabulary, words)
word_indices = dict((c, i) for i, c in enumerate(words))
indices_word = dict((i, c) for i, c in enumerate(words))
# Out:
# Unique words before ignoring: 17285
# Ignoring words with frequency < 12
# Unique words after ignoring: 17285

# %%
ignored_words
# Out:
# {'hug',
#  'wait,',
#  'bathroom]',
#  'survives.',
#  'Dust"',
#  'Said',
#  'preceding',
#  'bleeds',
#  'control."',
#  'astounded',
#  'procedure',
#  'warring',
#  'cold,',
#  'drug',
#  'shower',
#  'something,',
#  'Deep',
#  'anymore...."""',
#  'use?',
#  'apron',
#  'Vagisil',
#  'doing,',
#  'being.',
#  'goose',
#  'player.',
#  'somebody.',
#  'Papal',
#  'days.',
#  'Bar.',
#  'corners',
#  'careful.',
#  'frustrated',
#  'camera',
#  'compassion',
#  'spending',
#  'PC"""',
#  '""world',
#  'Largest',
#  '76',
#  'Kum"',
#  'sluts',
#  'despair',
#  'hit.',
#  '"Tom',
#  'Ken.',
#  'revolves',
#  'exhausted',
#  '""oh',
#  'ant',
#  'fuss.',
#  'excellence.',
#  'miss."',
#  '"WHat\'s',
#  'it?"',
#  "day's",
#  "roamin'",
#  'Thanks',
#  'drugs.',
#  'tough-skinned',
#  "actor.'",
#  'objective.',
#  'served',
#  'faith,',
#  'They."',
#  'sub',
#  'tenderness,',
#  'Rogue',
#  'spell',
#  'spontaneity.',
#  'jeans?',
#  '"Get',
#  'drama',
#  'slowly?',
#  'adultery',
#  'gentlemen',
#  'electricity.',
#  'straight,',
#  'Adobe',
#  'Tots',
#  'dog?',
#  'Club',
#  'extra',
#  'acquired',
#  'people?"',
#  'woodland.',
#  'Tournament',
#  'Edward',
#  'SWORE',
#  'Alabama',
#  'situations',
#  'Americans?',
#  'Chips!"',
#  'surrounded',
#  'chainsaw."',
#  'laughed.',
#  'lows',
#  '"Jared',
#  'field."',
#  'gentle',
#  'original.',
#  'Galaxy',
#  'mystery.',
#  'seed',
#  'battle,',
#  'life."""',
#  'closet?',
#  'rid',
#  'first-world',
#  'wandering',
#  '""incorrect""',
#  'lots',
#  'footpath',
#  'Girlfriend',
#  'directs',
#  'ice?',
#  '""We\'ve',
#  'Wandering',
#  'twenty-four',
#  'provide,',
#  'nihilist',
#  'drowning?',
#  'second."',
#  'novel',
#  'Ever',
#  'criticism,',
#  '""Please',
#  'blaming',
#  'trouble.',
#  'Making',
#  'dying.',
#  'magnificent',
#  'mean.',
#  'Were',
#  'bacteria',
#  '"Microsoft',
#  'photo',
#  'Steinway.',
#  'get?',
#  'vender',
#  'blackest',
#  'bastard!"',
#  'tall.',
#  '"technically',
#  'shower""',
#  'symbolism,',
#  '""babe',
#  'gracious',
#  'guitar*',
#  'porn',
#  'wallet.',
#  'insult',
#  'lawyers',
#  'Pushing',
#  '"what',
#  'self.',
#  'Porky-Pine"',
#  'Bros',
#  'otherwise',
#  'bullets,',
#  'Going',
#  'hospitality,',
#  'too,',
#  'passionate',
#  'bum',
#  'retiring.',
#  'that:',
#  'BOTH',
#  "frog's",
#  'tomorrow.',
#  'discovery',
#  'reminiscent',
#  'kingdom',
#  'dramatic',
#  'runt',
#  'buy...',
#  'denying',
#  'Recreational',
#  'Iraq.',
#  'low.',
#  'tastes',
#  'parrot',
#  'Tom',
#  'Wrath',
#  'Friends."',
#  'wars?',
#  'gear,',
#  'Animal',
#  'dog...',
#  'pardon,',
#  'inch.',
#  'god.',
#  'unimportant,',
#  'foment',
#  'followed,',
#  'recovery.',
#  'nations;',
#  'Rush',
#  'sport.',
#  '5."',
#  'carbs."""',
#  'ISIS',
#  '/r/news',
#  '"[describing',
#  "kids.'",
#  'Smokey',
#  'two-income',
#  'bulk',
#  'fleeting',
#  'please""',
#  'op."',
#  'disguised',
#  'cabin.',
#  'stage,',
#  'celebrity',
#  'captivating',
#  'improve.',
#  'Sunday,',
#  'bored',
#  'mutiny',
#  'potential',
#  'persons',
#  'reminder',
#  'exciting,',
#  'work)"',
#  'Pepsi',
#  '...boy',
#  'forever',
#  'images',
#  '""Because',
#  'p*nis',
#  '9?',
#  'eventually.',
#  'challenging,',
#  'agree',
#  'paints',
#  'begets',
#  'Music,',
#  'strangest',
#  'balance.',
#  'Grant.',
#  'circumcisions...',
#  'leather.',
#  'revolve',
#  'him."',
#  'Wears',
#  'empowers',
#  "'Look,",
#  'bigot.',
#  'ass."',
#  'VHS',
#  'Knock',
#  'bacon?',
#  'buck',
#  'stealing?',
#  'Nickelback...',
#  'option.',
#  'liable',
#  '*to',
#  'situations,',
#  'Style',
#  'airline',
#  'delicious!"',
#  'hand-riven',
#  'Ew."',
#  '"Right',
#  'peoples.',
#  'Luciferian',
#  'Island,',
#  'waistcoat?',
#  'praise.',
#  'footman',
#  'Chocula',
#  "Scamentine's",
#  'discharged',
#  'Man/Boy',
#  'people:',
#  'problem?',
#  'area,',
#  'boiling,',
#  '2000',
#  'steering',
#  'damn.',
#  'skin,',
#  'clever',
#  'printed.',
#  'infinitely',
#  'nutritionist',
#  'book.',
#  'bathroom',
#  'abuse',
#  '...do',
#  'Several',
#  'Freedom',
#  'latte',
#  'Online',
#  'unhappily',
#  'long-haul',
#  'Warfare:',
#  'tea',
#  'please?',
#  'divorce',
#  'rent',
#  'gluttony',
#  'laws,',
#  'bitch"',
#  'symptoms',
#  'spin',
#  'accident."',
#  'Alone!',
#  'it.)"',
#  'trapeze',
#  'loan,',
#  'standard,',
#  'crime',
#  'career,',
#  'consisting',
#  'naughty!',
#  'On."',
#  'consciousness.',
#  'We,',
#  'stems',
#  '"Yes,',
#  'lips."',
#  'bell',
#  'reply',
#  'spheres',
#  'recognise',
#  'Wolf,',
#  'unfree',
#  'fathers',
#  'Vienna,',
#  'Playboy.',
#  'myself"',
#  '[Fill',
#  'crisis"',
#  'dead?"',
#  'light-hearted?',
#  'Zach',
#  'erroneously',
#  'cognac',
#  'ski?',
#  'kinds',
#  'lawyer?',
#  'conveniently',
#  'ho""."',
#  'second.',
#  'nintendo',
#  'occurs.',
#  'Evaporated',
#  'orgasm',
#  'while,',
#  'Mexico',
#  'messages.',
#  'management',
#  'J.G.',
#  'stunts"',
#  'blindly',
#  'like?""',
#  'penalties',
#  'pricks',
#  'lesbian;',
#  'COP:',
#  'herself.""',
#  'rule."',
#  'general',
#  'gym',
#  'today.....',
#  'post-high',
#  'continentally.',
#  'yelled',
#  'pre-mature',
#  'sealed',
#  'reply.',
#  'Dog."',
#  'shown',
#  'Normous',
#  "Didn't",
#  'gently',
#  'before?',
#  'hoping',
#  'Live',
#  '""Meow""',
#  'style?',
#  'afterwards.',
#  'qualities,',
#  '5.',
#  'Escher',
#  'City',
#  'skills."',
#  'groove',
#  "whatever.'",
#  'eliminate',
#  'dead"',
#  'virginity',
#  'sorrow.',
#  'Taliban.',
#  'Ultraconservatism',
#  'god',
#  'dogs...',
#  'recipe',
#  '""Make',
#  'array',
#  'sorrow,',
#  'decreases',
#  'fans,',
#  'IN',
#  'movement',
#  'Doing',
#  'Ray.',
#  'orthodox',
#  'fortunate;',
#  'silly',
#  'dance,',
#  '""We\'ll',
#  'smoking',
#  'Pilgrims',
#  'pays',
#  'lacking,',
#  'over.',
#  'fulfillment',
#  'animated',
#  'keys',
#  'multiple',
#  "fuckin'",
#  'service."',
#  'wicked',
#  'asks,',
#  "'head",
#  'tests',
#  'minutes,',
#  'game.',
#  'Alfred',
#  'that?"',
#  'hooked',
#  'meet."',
#  'baptize',
#  'increase',
#  'hated',
#  'working;',
#  'quilted',
#  'cheap',
#  'fun,',
#  'deconstruct',
#  'assumptions',
#  'Ace',
#  'new.',
#  'perceive',
#  '""They',
#  '-Can',
#  "who'll",
#  'wanted."',
#  'rebel,',
#  'Guy:',
#  'select',
#  'career?"',
#  'rightly,',
#  'dog,',
#  'grenade',
#  'witherings,',
#  'Rockies',
#  'Cruiser',
#  'delight*"',
#  'religions,',
#  "'Dhoom,'",
#  'dominance.',
#  "'That",
#  'Profile',
#  'car.',
#  '"CNN:',
#  'burying',
#  'Republic',
#  'once.',
#  'Acting',
#  'sear',
#  '"Today',
#  'Four',
#  'enamored',
#  'Apple',
#  '...when',
#  'systems.All',
#  'boxes',
#  'brothers',
#  'assault....',
#  'succeeded',
#  'drama"',
#  'acceptable,',
#  'ninth',
#  'tonight',
#  'play,',
#  'Theater',
#  'food,',
#  'debut',
#  'anorexic',
#  '"TIFU',
#  'month??',
#  'Souvlaki',
#  'pictures.',
#  'architecture.',
#  'Jackson,',
#  'warrant',
#  'nation,',
#  'wishy-washy,',
#  'due',
#  'protected.',
#  'Sheep?',
#  'misunderstanding,',
#  '..asks',
#  'multiple,',
#  'Really',
#  'worried.',
#  '*pass',
#  "'Roots'",
#  'heavier',
#  'Ossetra',
#  'culture"',
#  'desert',
#  'Ivana',
#  'Olive',
#  '&amp;',
#  'Company',
#  'same.',
#  'illusion',
#  'bulbs.',
#  'cat-ass-trophy."',
#  'Whey.',
#  'What?',
#  'harness',
#  'impression.',
#  'crap',
#  'Lisa*',
#  'livid."',
#  "DON'T",
#  'whence',
#  'conversely,',
#  'right?',
#  'Mad,',
#  'pigs',
#  'sad?',
#  'more,',
#  'bodhisattva',
#  'stranger!"""',
#  'clouds',
#  'colonists.',
#  'neighbor',
#  'ladder."',
#  'ones.',
#  "Newton's",
#  'Old',
#  '*smiles',
#  'elements.',
#  'ADD',
#  'records.',
#  'cakes',
#  'antagonise',
#  'entities',
#  'shirt',
#  'hire',
#  '$10',
#  "'60s,",
#  'sick!',
#  '...I',
#  'Saw',
#  'laundromat',
#  'Character',
#  'reaction."',
#  'Fish',
#  'person."',
#  'porcupine?',
#  'birds.',
#  'brexit',
#  'host!"""',
#  'holocaust?""',
#  'title."',
#  'sticks',
#  'children."',
#  'bathroom?',
#  'moss',
#  'neighbors',
#  ".....we're",
#  'Story',
#  'Hitler?',
#  'bar*',
#  'water,',
#  'Sparky"',
#  'permit',
#  'Indians.',
#  '(brother',
#  'meatball',
#  'to,',
#  'sportsman,',
#  'eighteen',
#  'Iran',
#  'Halliburton.',
#  'yeah,',
#  'answering',
#  'hires',
#  'candles',
#  'name.""',
#  'passage',
#  'Dream.',
#  'Juan',
#  '"Girls',
#  'me;',
#  'body.',
#  'letter,',
#  'field"',
#  'camera.',
#  'nun',
#  'Yeah,',
#  'marched',
#  'Could',
#  'trailer',
#  'creates',
#  'satisfy',
#  'Ark-hives."',
#  'stick."',
#  'severe.',
#  'mouthful,',
#  's?uts.',
#  'wishes.',
#  '""He',
#  'cousins,',
#  'intelligent',
#  'eggs-terminated."',
#  'Florida',
#  'variable."',
#  'great!"',
#  'it!"',
#  'nostalgic',
#  'tickles"',
#  'person)"',
#  'Pronounce',
#  'obedient',
#  'security.',
#  'tuna.',
#  'departments',
#  'circumcise',
#  'format',
#  'personally,',
#  'give.',
#  'weed?',
#  'development.',
#  'workout?',
#  'Hat""',
#  'breakfast.',
#  'snow.',
#  'ruin.',
#  'Service',
#  '*he',
#  'allow',
#  'BATMAN',
#  '"why',
#  'dollars?""',
#  '"',
#  'items.',
#  'nutrigun*',
#  'Hahaha"',
#  'Malayasia',
#  'greed',
#  'power,',
#  'Fortune',
#  'chart,',
#  'solo',
#  'screaming',
#  '"Any',
#  'criminal',
#  'pain.',
#  'analog',
#  'watch.',
#  'soccer,',
#  'Snipper"',
#  'low."',
#  'Paris,',
#  '""do',
#  '23',
#  'vampire',
#  '"NSFW',
#  'pub',
#  'J.',
#  'shop.',
#  'ago,',
#  'far,',
#  'abs',
#  'discriminate',
#  'subtweeting',
#  'objectives;',
#  'drawn,',
#  'month',
#  'premature',
#  'capture',
#  'futile.',
#  'impacted',
#  'Girl',
#  'password"',
#  'Hitler',
#  'turning',
#  'STIFF',
#  'scan',
#  'assistants.',
#  'one,',
#  'nap',
#  'CHEESE',
#  'doorbell.',
#  'friend?',
#  'radio""."',
#  'walled',
#  'tomorrow."',
#  'not""',
#  'ethnic',
#  'location.',
#  'lifestyle',
#  'toy',
#  'creation.',
#  'serving',
#  'Are',
#  'eggs""',
#  'elevator,',
#  'Success',
#  'rationally,',
#  'nowadays',
#  'Wizard',
#  'genuinely',
#  'design.',
#  'Americanism,',
#  'Honestly,',
#  '"Recently',
#  'hotel."',
#  'olympics?',
#  'Pedophilia?',
#  'happen.',
#  'flour',
#  'minutes."',
#  'idiotic',
#  'decreased',
#  'forgetting',
#  'shuts',
#  'Jamestown,',
#  'ordeal.',
#  'Justice,',
#  'show.',
#  'bore',
#  'musician',
#  'unawakened.',
#  'species',
#  'participation.',
#  'fingernail',
#  '"Follow',
#  'walksies',
#  'obstacles;',
#  'loaf',
#  'rehearsal',
#  'up"',
#  'subreddit',
#  'equate',
#  'Bomb',
#  'seldom',
#  'contentment',
#  'giants',
#  'Mosque',
#  'bit.',
#  "alzheimer's?",
#  'butts...',
#  'pig,',
#  'attempt,',
#  '"INTERVIEWER:',
#  "You'll",
#  'campuses',
#  'Mutton',
#  'encompasses',
#  'fetish',
#  'journey',
#  'Trooper',
#  'rooms"',
#  'marches,',
#  'battery."',
#  'despair,',
#  'unmarried.',
#  'Man"',
#  'lead.',
#  'evening',
#  'Spit,',
#  'rubbing',
#  'hangout?""',
#  'Facebook."',
#  'loud',
#  'nothing,',
#  'father.',
#  'hyper-cinematic.',
#  'substance',
#  'Thanksgiving..',
#  'matters.',
#  'dictates',
#  'majestic',
#  'roses',
#  'Door"""',
#  'Tulips',
#  'sucks',
#  'da',
#  'Wife',
#  '[slides',
#  'accident.',
#  'Grandmaster',
#  'more?"',
#  'shaman',
#  'quest',
#  'traits,',
#  'Harvey',
#  'membership,',
#  '$15.99',
#  'psychologists',
#  'house?',
#  'happiness;',
#  'wall,',
#  '"Pinocchio',
#  'reader;',
#  'dying,',
#  'worthy',
#  'PILOT,',
#  'series',
#  'Conversation',
#  'gardens,',
#  'slutty',
#  'obscure',
#  'Bacon',
#  'understood',
#  'Frankness',
#  'manager"',
#  'kangaroo',
#  'kicked-in',
#  'collection,',
#  'posing.',
#  'thrown',
#  'Scotsmen',
#  'talk,',
#  'retaining',
#  'synagogue',
#  'adversity.',
#  '*hands',
#  'tips',
#  "model's",
#  'Christmas?',
#  'trash.....',
#  'Road',
#  'grass?',
#  '""happily',
#  "'Bewitched'",
#  'goals.',
#  '5,',
#  'victorious',
#  'Reddit',
#  'mosquito',
#  'poison',
#  'killing',
#  'Positive',
#  'around"',
#  'tank',
#  'Neither',
#  'margin',
#  'la',
#  'ingredients,',
#  'Indians,',
#  'criticizing',
#  '"Now',
#  'EW',
#  'teaser,',
#  "Treacher's",
#  'flying',
#  'hip-hop',
#  'divine.',
#  'nation',
#  'costume,',
#  '"Anyone',
#  'fundamentalists',
#  'tendency',
#  'freezer,',
#  'alive',
#  'widely',
#  'arctic*"',
#  'goal.',
#  'younger',
#  'feeling,',
#  'Rorschach',
#  'punishment.',
#  'momentary',
#  'idiot?\'\'"',
#  'thread."',
#  'smiles',
#  'notes',
#  'co-exist?',
#  'Nuclear',
#  'Place',
#  'exit',
#  'wise',
#  'Netanya',
#  "year's",
#  'others."',
#  'ranch"',
#  '"[commercial]',
#  'real.',
#  't',
#  'kids.',
#  'Brazil?',
#  'express',
#  'yet."',
#  'pure.',
#  'ditch?',
#  'adj.',
#  'that...."',
#  'sunshine.',
#  'anywhere.""',
#  'ahead',
#  'hang-ups',
#  'polish,',
#  'arrive',
#  'dance.',
#  '"Kill',
#  'dozen',
#  'CONFUSED',
#  'ultimate',
#  'successfull',
#  'compromised',
#  'reptile',
#  'teams',
#  'Cat-has-trophy.',
#  'masochist.',
#  'fixed',
#  'minutes!',
#  '75""',
#  '*Snoops',
#  'complexities',
#  "Laden's",
#  'performed',
#  'hidden',
#  'stole',
#  'bud""!"',
#  'punchline."',
#  'full-length',
#  'chastise',
#  'leaders:',
#  'drugs."',
#  'continuously',
#  'in:',
#  'loudest',
#  'facility',
#  'Art',
#  'field?',
#  'snakes',
#  'date.',
#  "'Forget",
#  'mongol',
#  'edge',
#  'hill',
#  'profound',
#  'altogether.',
#  'tune.',
#  'earnestness.',
#  'worship?',
#  'possesses',
#  'bears',
#  'states,',
#  "name's",
#  'esteem',
#  '*pulls',
#  'wood?',
#  'learned,',
#  'future,',
#  'Drama',
#  'potatoes,',
#  'later',
#  '3D-printed',
#  'Humans:',
#  'model;',
#  'stabs',
#  'trembling',
#  'World.',
#  'Fekkai',
#  'Actually,',
#  'Many,',
#  'roller',
#  'white,',
#  'Dexter',
#  'mine...',
#  'cast',
#  'car?',
#  'cat.',
#  'D."',
#  'quicker',
#  'roof',
#  'Waitress',
#  'him."""',
#  'taken"',
#  "Shakespeare's",
#  'mouth',
#  'OCTOPUS:',
#  'stuffing',
#  'watching.',
#  'master,',
#  '"Horses',
#  'equality,',
#  '""Priceless""',
#  ...}

# %%
len (ignored_words)
# Out:
# 15914

# %%
SEQUENCE_LEN = 10
MY_SEQUENCE_LEN =SEQUENCE_LEN-1
STEP =1
# cut the text in semi-redundant sequences of SEQUENCE_LEN words


def processXandY(myText_in_words,tag=""):
    sentences = []
    next_words = []
    ignored = 0
    for i in range(0, len(myText_in_words) - MY_SEQUENCE_LEN, STEP):
        # Only add the sequences where no word is in ignored_words
        if len(set(text_in_words[i: i+MY_SEQUENCE_LEN+1]).intersection(ignored_words)) == 0:
            mysentences = []
            mysentences.append(tag)
            for myword in myText_in_words[i: i + MY_SEQUENCE_LEN]:
                mysentences.append(myword)
            #sentences.append(myText_in_words[i: i + SEQUENCE_LEN])
            sentences.append(mysentences)
            next_words.append(myText_in_words[i + MY_SEQUENCE_LEN])
        else:
            ignored = ignored + 1
    print('Ignored sequences:', ignored)
    print('Remaining sequences:', len(sentences))
    return sentences,next_words

# %%
Joke_Tag_Sentences,Joke_Tag_Next_Words =processXandY(joke_text_in_words,"#@Joke")
Joke_NoTag_Sentences,Joke_NoTag_Next_Words =processXandY(joke_text_in_words,"#@NoTag")
quote_Tag_Sentences,quote_Tag_Next_Words =processXandY(quote_text_in_words,"#@Quote")
quote_NoTag_Sentences,quote_NoTag_Next_Words =processXandY(quote_text_in_words,"#@NoTag")

sentences = Joke_Tag_Sentences + Joke_NoTag_Sentences + quote_Tag_Sentences + quote_NoTag_Sentences
next_words = Joke_Tag_Next_Words + Joke_NoTag_Next_Words + quote_Tag_Next_Words + quote_NoTag_Next_Words
# Out:
# Ignored sequences: 34076
# Remaining sequences: 2801
# Ignored sequences: 34076
# Remaining sequences: 2801
# Ignored sequences: 45704
# Remaining sequences: 3854
# Ignored sequences: 45704
# Remaining sequences: 3854

# %%
sentences
# Out:
# [['#@Joke',
#   'talking"""',
#   '\n',
#   '"Telling',
#   'my',
#   'daughter',
#   'garlic',
#   'is',
#   'good',
#   'for'],
#  ['#@Joke',
#   '\n',
#   '"Telling',
#   'my',
#   'daughter',
#   'garlic',
#   'is',
#   'good',
#   'for',
#   'you.'],
#  ['#@Joke',
#   'period',
#   'at',
#   'work',
#   'this',
#   'week',
#   "It's",
#   'my',
#   'own',
#   'fault'],
#  ['#@Joke', 'at', 'work', 'this', 'week', "It's", 'my', 'own', 'fault', 'for'],
#  ['#@Joke',
#   'work',
#   'this',
#   'week',
#   "It's",
#   'my',
#   'own',
#   'fault',
#   'for',
#   'swapping'],
#  ['#@Joke',
#   'this',
#   'week',
#   "It's",
#   'my',
#   'own',
#   'fault',
#   'for',
#   'swapping',
#   'my'],
#  ['#@Joke',
#   'week',
#   "It's",
#   'my',
#   'own',
#   'fault',
#   'for',
#   'swapping',
#   'my',
#   'tampax'],
#  ['#@Joke',
#   'or',
#   'alive...',
#   '...I',
#   'would',
#   'choose',
#   'alive.',
#   '-B.J.',
#   'Novak-"',
#   '\n'],
#  ['#@Joke',
#   'guy',
#   'ducks."',
#   '\n',
#   '"Why',
#   "can't",
#   'Barbie',
#   'get',
#   'pregnant?',
#   'Because'],
#  ['#@Joke',
#   'ducks."',
#   '\n',
#   '"Why',
#   "can't",
#   'Barbie',
#   'get',
#   'pregnant?',
#   'Because',
#   'Ken'],
#  ['#@Joke',
#   '\n',
#   '"Why',
#   "can't",
#   'Barbie',
#   'get',
#   'pregnant?',
#   'Because',
#   'Ken',
#   'comes'],
#  ['#@Joke',
#   '"Why',
#   'was',
#   'the',
#   'musician',
#   'arrested?',
#   'He',
#   'got',
#   'in',
#   'treble."'],
#  ['#@Joke',
#   'was',
#   'the',
#   'musician',
#   'arrested?',
#   'He',
#   'got',
#   'in',
#   'treble."',
#   '\n'],
#  ['#@Joke',
#   'the',
#   'musician',
#   'arrested?',
#   'He',
#   'got',
#   'in',
#   'treble."',
#   '\n',
#   '"Did'],
#  ['#@Joke',
#   'who',
#   'blew',
#   'his',
#   'entire',
#   'lottery',
#   'winnings',
#   'on',
#   'a',
#   'limousine?'],
#  ['#@Joke', 'to', 'chauffeur', 'it."', '\n', '"What', 'do', 'you', 'do', 'if'],
#  ['#@Joke',
#   'be',
#   'like',
#   'a',
#   'mini-skirt.',
#   'Long',
#   'enough',
#   'to',
#   'cover',
#   'the'],
#  ['#@Joke',
#   'like',
#   'a',
#   'mini-skirt.',
#   'Long',
#   'enough',
#   'to',
#   'cover',
#   'the',
#   'essentials'],
#  ['#@Joke',
#   'a',
#   'mini-skirt.',
#   'Long',
#   'enough',
#   'to',
#   'cover',
#   'the',
#   'essentials',
#   'but'],
#  ['#@Joke',
#   'mini-skirt.',
#   'Long',
#   'enough',
#   'to',
#   'cover',
#   'the',
#   'essentials',
#   'but',
#   'short'],
#  ['#@Joke',
#   'Long',
#   'enough',
#   'to',
#   'cover',
#   'the',
#   'essentials',
#   'but',
#   'short',
#   'enough'],
#  ['#@Joke',
#   'enough',
#   'to',
#   'cover',
#   'the',
#   'essentials',
#   'but',
#   'short',
#   'enough',
#   'to'],
#  ['#@Joke',
#   'to',
#   'cover',
#   'the',
#   'essentials',
#   'but',
#   'short',
#   'enough',
#   'to',
#   'hold'],
#  ['#@Joke',
#   'cover',
#   'the',
#   'essentials',
#   'but',
#   'short',
#   'enough',
#   'to',
#   'hold',
#   'your'],
#  ['#@Joke',
#   'the',
#   'essentials',
#   'but',
#   'short',
#   'enough',
#   'to',
#   'hold',
#   'your',
#   'attention!"'],
#  ['#@Joke',
#   'essentials',
#   'but',
#   'short',
#   'enough',
#   'to',
#   'hold',
#   'your',
#   'attention!"',
#   '\n'],
#  ['#@Joke',
#   'but',
#   'short',
#   'enough',
#   'to',
#   'hold',
#   'your',
#   'attention!"',
#   '\n',
#   '"Thanksgiving'],
#  ['#@Joke',
#   'short',
#   'enough',
#   'to',
#   'hold',
#   'your',
#   'attention!"',
#   '\n',
#   '"Thanksgiving',
#   'joke'],
#  ['#@Joke',
#   'enough',
#   'to',
#   'hold',
#   'your',
#   'attention!"',
#   '\n',
#   '"Thanksgiving',
#   'joke',
#   'What'],
#  ['#@Joke',
#   'to',
#   'hold',
#   'your',
#   'attention!"',
#   '\n',
#   '"Thanksgiving',
#   'joke',
#   'What',
#   'does'],
#  ['#@Joke',
#   'eat',
#   'for',
#   'Thanksgiving?',
#   'Twerky!',
#   'Just',
#   'kidding...',
#   'Drugs.',
#   'She',
#   'eats'],
#  ['#@Joke',
#   'for',
#   'Thanksgiving?',
#   'Twerky!',
#   'Just',
#   'kidding...',
#   'Drugs.',
#   'She',
#   'eats',
#   'drugs.'],
#  ['#@Joke',
#   'Thanksgiving?',
#   'Twerky!',
#   'Just',
#   'kidding...',
#   'Drugs.',
#   'She',
#   'eats',
#   'drugs.',
#   '-Adam'],
#  ['#@Joke',
#   'a',
#   'club,',
#   'and',
#   'a',
#   'diamond,',
#   'all',
#   'without',
#   'my',
#   'permission.'],
#  ['#@Joke',
#   'club,',
#   'and',
#   'a',
#   'diamond,',
#   'all',
#   'without',
#   'my',
#   'permission.',
#   'I'],
#  ['#@Joke',
#   'and',
#   'a',
#   'diamond,',
#   'all',
#   'without',
#   'my',
#   'permission.',
#   'I',
#   'guess'],
#  ['#@Joke',
#   'a',
#   'diamond,',
#   'all',
#   'without',
#   'my',
#   'permission.',
#   'I',
#   'guess',
#   "I'll"],
#  ['#@Joke',
#   'diamond,',
#   'all',
#   'without',
#   'my',
#   'permission.',
#   'I',
#   'guess',
#   "I'll",
#   'deal'],
#  ['#@Joke', 'it."""', '\n', '"How', 'do', 'you', 'fit', '4', 'gays', 'on'],
#  ['#@Joke', '\n', '"How', 'do', 'you', 'fit', '4', 'gays', 'on', 'one'],
#  ['#@Joke', '"How', 'do', 'you', 'fit', '4', 'gays', 'on', 'one', 'barstool?'],
#  ['#@Joke',
#   'out',
#   'of',
#   'my',
#   'wallet,',
#   'spread',
#   'them',
#   'on',
#   'the',
#   'bed,'],
#  ['#@Joke',
#   'of',
#   'my',
#   'wallet,',
#   'spread',
#   'them',
#   'on',
#   'the',
#   'bed,',
#   'and'],
#  ['#@Joke',
#   'my',
#   'wallet,',
#   'spread',
#   'them',
#   'on',
#   'the',
#   'bed,',
#   'and',
#   'pretend'],
#  ['#@Joke',
#   'wallet,',
#   'spread',
#   'them',
#   'on',
#   'the',
#   'bed,',
#   'and',
#   'pretend',
#   'I'],
#  ['#@Joke',
#   'spread',
#   'them',
#   'on',
#   'the',
#   'bed,',
#   'and',
#   'pretend',
#   'I',
#   'was'],
#  ['#@Joke',
#   'them',
#   'on',
#   'the',
#   'bed,',
#   'and',
#   'pretend',
#   'I',
#   'was',
#   'pretty'],
#  ['#@Joke',
#   'on',
#   'the',
#   'bed,',
#   'and',
#   'pretend',
#   'I',
#   'was',
#   'pretty',
#   'that'],
#  ['#@Joke',
#   'the',
#   'bed,',
#   'and',
#   'pretend',
#   'I',
#   'was',
#   'pretty',
#   'that',
#   'day."'],
#  ['#@Joke',
#   'bed,',
#   'and',
#   'pretend',
#   'I',
#   'was',
#   'pretty',
#   'that',
#   'day."',
#   '\n'],
#  ['#@Joke',
#   'and',
#   'pretend',
#   'I',
#   'was',
#   'pretty',
#   'that',
#   'day."',
#   '\n',
#   '"Which'],
#  ['#@Joke',
#   '"Before',
#   'I',
#   'destroy',
#   'a',
#   "wasp's",
#   'nest',
#   'I',
#   'like',
#   'to'],
#  ['#@Joke',
#   'I',
#   'destroy',
#   'a',
#   "wasp's",
#   'nest',
#   'I',
#   'like',
#   'to',
#   'capture'],
#  ['#@Joke',
#   'was',
#   'just',
#   'walking',
#   'by',
#   'and',
#   'saw',
#   'you',
#   'had',
#   'donuts."'],
#  ['#@Joke',
#   'just',
#   'walking',
#   'by',
#   'and',
#   'saw',
#   'you',
#   'had',
#   'donuts."',
#   '\n'],
#  ['#@Joke',
#   'walking',
#   'by',
#   'and',
#   'saw',
#   'you',
#   'had',
#   'donuts."',
#   '\n',
#   '"Coming'],
#  ['#@Joke',
#   'by',
#   'and',
#   'saw',
#   'you',
#   'had',
#   'donuts."',
#   '\n',
#   '"Coming',
#   'on'],
#  ['#@Joke',
#   'and',
#   'saw',
#   'you',
#   'had',
#   'donuts."',
#   '\n',
#   '"Coming',
#   'on',
#   'valentines'],
#  ['#@Joke',
#   'small',
#   'medium',
#   'at',
#   'large."',
#   '\n',
#   '"Someone',
#   'didnt',
#   'click',
#   'the'],
#  ['#@Joke',
#   'to',
#   'be',
#   'above',
#   'the',
#   'influence...',
#   'But',
#   "I've",
#   'never',
#   'been'],
#  ['#@Joke',
#   'be',
#   'above',
#   'the',
#   'influence...',
#   'But',
#   "I've",
#   'never',
#   'been',
#   'able'],
#  ['#@Joke',
#   'above',
#   'the',
#   'influence...',
#   'But',
#   "I've",
#   'never',
#   'been',
#   'able',
#   'to'],
#  ['#@Joke',
#   'the',
#   'influence...',
#   'But',
#   "I've",
#   'never',
#   'been',
#   'able',
#   'to',
#   'get'],
#  ['#@Joke',
#   'people',
#   'you',
#   'would',
#   'otherwise',
#   'never',
#   'talk',
#   'to,',
#   'but',
#   "that's"],
#  ['#@Joke', 'the', 'world.', 'All', 'of', 'the', 'sex', 'he', 'has,', 'with'],
#  ['#@Joke',
#   'world.',
#   'All',
#   'of',
#   'the',
#   'sex',
#   'he',
#   'has,',
#   'with',
#   'Hillary,'],
#  ['#@Joke',
#   'All',
#   'of',
#   'the',
#   'sex',
#   'he',
#   'has,',
#   'with',
#   'Hillary,',
#   'you'],
#  ['#@Joke',
#   '"yeah',
#   'girl..',
#   'shake',
#   'that',
#   'thing',
#   'where',
#   'poop',
#   'comes',
#   'out'],
#  ['#@Joke',
#   'girl..',
#   'shake',
#   'that',
#   'thing',
#   'where',
#   'poop',
#   'comes',
#   'out',
#   'of.'],
#  ['#@Joke',
#   'shake',
#   'that',
#   'thing',
#   'where',
#   'poop',
#   'comes',
#   'out',
#   'of.',
#   'it'],
#  ['#@Joke',
#   'that',
#   'thing',
#   'where',
#   'poop',
#   'comes',
#   'out',
#   'of.',
#   'it',
#   'really'],
#  ['#@Joke',
#   'thing',
#   'where',
#   'poop',
#   'comes',
#   'out',
#   'of.',
#   'it',
#   'really',
#   'turns'],
#  ['#@Joke',
#   'where',
#   'poop',
#   'comes',
#   'out',
#   'of.',
#   'it',
#   'really',
#   'turns',
#   'me'],
#  ['#@Joke',
#   'poop',
#   'comes',
#   'out',
#   'of.',
#   'it',
#   'really',
#   'turns',
#   'me',
#   'on'],
#  ['#@Joke',
#   'comes',
#   'out',
#   'of.',
#   'it',
#   'really',
#   'turns',
#   'me',
#   'on',
#   'when'],
#  ['#@Joke', 'out', 'of.', 'it', 'really', 'turns', 'me', 'on', 'when', 'your'],
#  ['#@Joke',
#   'there',
#   'are',
#   '4,111,093,0003.666',
#   '""humorists"".',
#   '2/3rds',
#   'of',
#   'a',
#   'person?',
#   'Really?"'],
#  ['#@Joke',
#   'my',
#   'ballet',
#   'recitals,',
#   'and',
#   'always',
#   'see',
#   'that',
#   'one',
#   'empty'],
#  ['#@Joke',
#   'ballet',
#   'recitals,',
#   'and',
#   'always',
#   'see',
#   'that',
#   'one',
#   'empty',
#   'seat."'],
#  ['#@Joke',
#   'recitals,',
#   'and',
#   'always',
#   'see',
#   'that',
#   'one',
#   'empty',
#   'seat."',
#   '\n'],
#  ['#@Joke',
#   'and',
#   'always',
#   'see',
#   'that',
#   'one',
#   'empty',
#   'seat."',
#   '\n',
#   '"What'],
#  ['#@Joke',
#   'always',
#   'see',
#   'that',
#   'one',
#   'empty',
#   'seat."',
#   '\n',
#   '"What',
#   'did'],
#  ['#@Joke',
#   'need',
#   'a',
#   'huge',
#   'spoon',
#   'to',
#   'take',
#   'care',
#   'of',
#   'this""'],
#  ['#@Joke',
#   'a',
#   'huge',
#   'spoon',
#   'to',
#   'take',
#   'care',
#   'of',
#   'this""',
#   '-Guy'],
#  ['#@Joke',
#   'huge',
#   'spoon',
#   'to',
#   'take',
#   'care',
#   'of',
#   'this""',
#   '-Guy',
#   'who'],
#  ['#@Joke',
#   'spoon',
#   'to',
#   'take',
#   'care',
#   'of',
#   'this""',
#   '-Guy',
#   'who',
#   'invented'],
#  ['#@Joke',
#   'to',
#   'take',
#   'care',
#   'of',
#   'this""',
#   '-Guy',
#   'who',
#   'invented',
#   'shovels"'],
#  ['#@Joke',
#   'take',
#   'care',
#   'of',
#   'this""',
#   '-Guy',
#   'who',
#   'invented',
#   'shovels"',
#   '\n'],
#  ['#@Joke',
#   'care',
#   'of',
#   'this""',
#   '-Guy',
#   'who',
#   'invented',
#   'shovels"',
#   '\n',
#   '"How'],
#  ['#@Joke',
#   'of',
#   'this""',
#   '-Guy',
#   'who',
#   'invented',
#   'shovels"',
#   '\n',
#   '"How',
#   'to'],
#  ['#@Joke',
#   'this""',
#   '-Guy',
#   'who',
#   'invented',
#   'shovels"',
#   '\n',
#   '"How',
#   'to',
#   'keep'],
#  ['#@Joke',
#   'from',
#   'the',
#   "1930's",
#   'and',
#   '/r/news',
#   'jokes',
#   'have',
#   'in',
#   'common?'],
#  ['#@Joke',
#   'the',
#   "1930's",
#   'and',
#   '/r/news',
#   'jokes',
#   'have',
#   'in',
#   'common?',
#   "They're"],
#  ['#@Joke', 'Fair', 'Trade."', '\n', '"ME:', 'I', 'fell', 'off', 'a', '50'],
#  ['#@Joke',
#   'you',
#   'call',
#   'a',
#   'blind',
#   'dinosaurs',
#   'dog?',
#   'A',
#   'do-you-think-he-saurus-rex"',
#   '\n'],
#  ['#@Joke',
#   'amphibian',
#   'for',
#   'a',
#   'pet.',
#   "It's",
#   'my-newt!"',
#   '\n',
#   '"This',
#   'may'],
#  ['#@Joke',
#   'for',
#   'a',
#   'pet.',
#   "It's",
#   'my-newt!"',
#   '\n',
#   '"This',
#   'may',
#   'be'],
#  ['#@Joke',
#   'a',
#   'pet.',
#   "It's",
#   'my-newt!"',
#   '\n',
#   '"This',
#   'may',
#   'be',
#   'not'],
#  ['#@Joke',
#   'pet.',
#   "It's",
#   'my-newt!"',
#   '\n',
#   '"This',
#   'may',
#   'be',
#   'not',
#   'be'],
#  ['#@Joke',
#   'after',
#   '20',
#   'years,',
#   'Jared',
#   'Fogle',
#   'is',
#   'still',
#   'getting',
#   'into'],
#  ['#@Joke',
#   '20',
#   'years,',
#   'Jared',
#   'Fogle',
#   'is',
#   'still',
#   'getting',
#   'into',
#   'smaller'],
#  ['#@Joke',
#   'called',
#   '""world',
#   'history"".',
#   '#TRUMP',
#   '2016!',
#   'YOU',
#   "CAN'T",
#   'STUMP',
#   'THE'],
#  ['#@Joke',
#   '""world',
#   'history"".',
#   '#TRUMP',
#   '2016!',
#   'YOU',
#   "CAN'T",
#   'STUMP',
#   'THE',
#   'TRUMP!"'],
#  ['#@Joke',
#   'the',
#   'first',
#   '39',
#   'episodes',
#   'of',
#   'DBZ?',
#   'Its',
#   'pretty',
#   'gay,'],
#  ['#@Joke',
#   'first',
#   '39',
#   'episodes',
#   'of',
#   'DBZ?',
#   'Its',
#   'pretty',
#   'gay,',
#   'just'],
#  ['#@Joke',
#   '39',
#   'episodes',
#   'of',
#   'DBZ?',
#   'Its',
#   'pretty',
#   'gay,',
#   'just',
#   'Saiyan."'],
#  ['#@Joke',
#   'episodes',
#   'of',
#   'DBZ?',
#   'Its',
#   'pretty',
#   'gay,',
#   'just',
#   'Saiyan."',
#   '\n'],
#  ['#@Joke',
#   'of',
#   'DBZ?',
#   'Its',
#   'pretty',
#   'gay,',
#   'just',
#   'Saiyan."',
#   '\n',
#   '"My'],
#  ['#@Joke',
#   'gettin',
#   'better."',
#   '\n',
#   '"This',
#   'doctor',
#   'once',
#   'told',
#   'me',
#   'eating'],
#  ['#@Joke',
#   'better."',
#   '\n',
#   '"This',
#   'doctor',
#   'once',
#   'told',
#   'me',
#   'eating',
#   'a'],
#  ['#@Joke',
#   '\n',
#   '"This',
#   'doctor',
#   'once',
#   'told',
#   'me',
#   'eating',
#   'a',
#   'bagel'],
#  ['#@Joke',
#   '"This',
#   'doctor',
#   'once',
#   'told',
#   'me',
#   'eating',
#   'a',
#   'bagel',
#   'was'],
#  ['#@Joke',
#   'doctor',
#   'once',
#   'told',
#   'me',
#   'eating',
#   'a',
#   'bagel',
#   'was',
#   'like'],
#  ['#@Joke',
#   'once',
#   'told',
#   'me',
#   'eating',
#   'a',
#   'bagel',
#   'was',
#   'like',
#   'eating'],
#  ['#@Joke',
#   'told',
#   'me',
#   'eating',
#   'a',
#   'bagel',
#   'was',
#   'like',
#   'eating',
#   '5'],
#  ['#@Joke',
#   'cool,',
#   'I',
#   'like',
#   'bread"',
#   '\n',
#   '"What',
#   'do',
#   'you',
#   'call'],
#  ['#@Joke', 'I', 'like', 'bread"', '\n', '"What', 'do', 'you', 'call', 'a'],
#  ['#@Joke',
#   "they're",
#   'both',
#   'stuck-up',
#   'cunts."',
#   '\n',
#   '"What',
#   'do',
#   'you',
#   'call'],
#  ['#@Joke',
#   'both',
#   'stuck-up',
#   'cunts."',
#   '\n',
#   '"What',
#   'do',
#   'you',
#   'call',
#   'Jay-Z'],
#  ['#@Joke',
#   'stuck-up',
#   'cunts."',
#   '\n',
#   '"What',
#   'do',
#   'you',
#   'call',
#   'Jay-Z',
#   'having'],
#  ['#@Joke',
#   'cunts."',
#   '\n',
#   '"What',
#   'do',
#   'you',
#   'call',
#   'Jay-Z',
#   'having',
#   'a'],
#  ['#@Joke', '\n', '"What', 'do', 'you', 'call', 'Jay-Z', 'having', 'a', 'leg'],
#  ['#@Joke',
#   '"What',
#   'do',
#   'you',
#   'call',
#   'Jay-Z',
#   'having',
#   'a',
#   'leg',
#   'transplant?'],
#  ['#@Joke',
#   'do',
#   'you',
#   'call',
#   'Jay-Z',
#   'having',
#   'a',
#   'leg',
#   'transplant?',
#   'A'],
#  ['#@Joke',
#   'op."',
#   '\n',
#   '"What',
#   'defies',
#   'the',
#   'law',
#   'of',
#   'gravity?',
#   'Women.'],
#  ['#@Joke',
#   '\n',
#   '"What',
#   'defies',
#   'the',
#   'law',
#   'of',
#   'gravity?',
#   'Women.',
#   'They'],
#  ['#@Joke',
#   '"What',
#   'defies',
#   'the',
#   'law',
#   'of',
#   'gravity?',
#   'Women.',
#   'They',
#   'heavier'],
#  ['#@Joke',
#   'defies',
#   'the',
#   'law',
#   'of',
#   'gravity?',
#   'Women.',
#   'They',
#   'heavier',
#   'they'],
#  ['#@Joke',
#   'the',
#   'law',
#   'of',
#   'gravity?',
#   'Women.',
#   'They',
#   'heavier',
#   'they',
#   'are,'],
#  ['#@Joke',
#   'law',
#   'of',
#   'gravity?',
#   'Women.',
#   'They',
#   'heavier',
#   'they',
#   'are,',
#   'the'],
#  ['#@Joke',
#   'of',
#   'gravity?',
#   'Women.',
#   'They',
#   'heavier',
#   'they',
#   'are,',
#   'the',
#   'easier'],
#  ['#@Joke',
#   'gravity?',
#   'Women.',
#   'They',
#   'heavier',
#   'they',
#   'are,',
#   'the',
#   'easier',
#   'they'],
#  ['#@Joke',
#   'Women.',
#   'They',
#   'heavier',
#   'they',
#   'are,',
#   'the',
#   'easier',
#   'they',
#   'are'],
#  ['#@Joke',
#   'They',
#   'heavier',
#   'they',
#   'are,',
#   'the',
#   'easier',
#   'they',
#   'are',
#   'to'],
#  ['#@Joke',
#   'heavier',
#   'they',
#   'are,',
#   'the',
#   'easier',
#   'they',
#   'are',
#   'to',
#   'pick'],
#  ['#@Joke',
#   'hair?',
#   'Rapunzel."',
#   '\n',
#   '"""I\'m',
#   'so',
#   'pissed',
#   'I',
#   'could',
#   'punch'],
#  ['#@Joke',
#   'Rapunzel."',
#   '\n',
#   '"""I\'m',
#   'so',
#   'pissed',
#   'I',
#   'could',
#   'punch',
#   'a'],
#  ['#@Joke',
#   '\n',
#   '"""I\'m',
#   'so',
#   'pissed',
#   'I',
#   'could',
#   'punch',
#   'a',
#   'ba-""'],
#  ['#@Joke',
#   '"""I\'m',
#   'so',
#   'pissed',
#   'I',
#   'could',
#   'punch',
#   'a',
#   'ba-""',
#   '""A'],
#  ['#@Joke',
#   'so',
#   'pissed',
#   'I',
#   'could',
#   'punch',
#   'a',
#   'ba-""',
#   '""A',
#   'what?""'],
#  ['#@Joke',
#   'pissed',
#   'I',
#   'could',
#   'punch',
#   'a',
#   'ba-""',
#   '""A',
#   'what?""',
#   'Big'],
#  ['#@Joke',
#   'I',
#   'could',
#   'punch',
#   'a',
#   'ba-""',
#   '""A',
#   'what?""',
#   'Big',
#   'Baby'],
#  ['#@Joke',
#   'could',
#   'punch',
#   'a',
#   'ba-""',
#   '""A',
#   'what?""',
#   'Big',
#   'Baby',
#   'from'],
#  ['#@Joke',
#   'punch',
#   'a',
#   'ba-""',
#   '""A',
#   'what?""',
#   'Big',
#   'Baby',
#   'from',
#   'Toy'],
#  ['#@Joke',
#   'a',
#   'ba-""',
#   '""A',
#   'what?""',
#   'Big',
#   'Baby',
#   'from',
#   'Toy',
#   'Story'],
#  ['#@Joke',
#   'ba-""',
#   '""A',
#   'what?""',
#   'Big',
#   'Baby',
#   'from',
#   'Toy',
#   'Story',
#   '3'],
#  ['#@Joke',
#   '""A',
#   'what?""',
#   'Big',
#   'Baby',
#   'from',
#   'Toy',
#   'Story',
#   '3',
#   'hovers'],
#  ['#@Joke',
#   'what?""',
#   'Big',
#   'Baby',
#   'from',
#   'Toy',
#   'Story',
#   '3',
#   'hovers',
#   'over'],
#  ['#@Joke',
#   'Big',
#   'Baby',
#   'from',
#   'Toy',
#   'Story',
#   '3',
#   'hovers',
#   'over',
#   'me,'],
#  ['#@Joke',
#   'Baby',
#   'from',
#   'Toy',
#   'Story',
#   '3',
#   'hovers',
#   'over',
#   'me,',
#   'sawed-off'],
#  ['#@Joke',
#   'from',
#   'Toy',
#   'Story',
#   '3',
#   'hovers',
#   'over',
#   'me,',
#   'sawed-off',
#   'shotgun'],
#  ['#@Joke',
#   'Toy',
#   'Story',
#   '3',
#   'hovers',
#   'over',
#   'me,',
#   'sawed-off',
#   'shotgun',
#   'in'],
#  ['#@Joke',
#   'Story',
#   '3',
#   'hovers',
#   'over',
#   'me,',
#   'sawed-off',
#   'shotgun',
#   'in',
#   'hand.'],
#  ['#@Joke',
#   '3',
#   'hovers',
#   'over',
#   'me,',
#   'sawed-off',
#   'shotgun',
#   'in',
#   'hand.',
#   '""A'],
#  ['#@Joke',
#   'hovers',
#   'over',
#   'me,',
#   'sawed-off',
#   'shotgun',
#   'in',
#   'hand.',
#   '""A',
#   'bagel.'],
#  ['#@Joke',
#   'over',
#   'me,',
#   'sawed-off',
#   'shotgun',
#   'in',
#   'hand.',
#   '""A',
#   'bagel.',
#   'I'],
#  ['#@Joke',
#   'me,',
#   'sawed-off',
#   'shotgun',
#   'in',
#   'hand.',
#   '""A',
#   'bagel.',
#   'I',
#   'HATE'],
#  ['#@Joke',
#   'sawed-off',
#   'shotgun',
#   'in',
#   'hand.',
#   '""A',
#   'bagel.',
#   'I',
#   'HATE',
#   'carbs."""'],
#  ['#@Joke',
#   'shotgun',
#   'in',
#   'hand.',
#   '""A',
#   'bagel.',
#   'I',
#   'HATE',
#   'carbs."""',
#   '\n'],
#  ['#@Joke',
#   'in',
#   'hand.',
#   '""A',
#   'bagel.',
#   'I',
#   'HATE',
#   'carbs."""',
#   '\n',
#   '"What\'s'],
#  ['#@Joke',
#   'hand.',
#   '""A',
#   'bagel.',
#   'I',
#   'HATE',
#   'carbs."""',
#   '\n',
#   '"What\'s',
#   'the'],
#  ['#@Joke',
#   '""A',
#   'bagel.',
#   'I',
#   'HATE',
#   'carbs."""',
#   '\n',
#   '"What\'s',
#   'the',
#   'difference'],
#  ['#@Joke',
#   'bagel.',
#   'I',
#   'HATE',
#   'carbs."""',
#   '\n',
#   '"What\'s',
#   'the',
#   'difference',
#   'Donald'],
#  ['#@Joke', 'a', 'Cunt', 'and', 'the', 'other', 'has', 'nice', 'hair."', '\n'],
#  ['#@Joke',
#   'Cunt',
#   'and',
#   'the',
#   'other',
#   'has',
#   'nice',
#   'hair."',
#   '\n',
#   '"My'],
#  ['#@Joke',
#   'and',
#   'the',
#   'other',
#   'has',
#   'nice',
#   'hair."',
#   '\n',
#   '"My',
#   'doctor'],
#  ['#@Joke',
#   'the',
#   'other',
#   'has',
#   'nice',
#   'hair."',
#   '\n',
#   '"My',
#   'doctor',
#   'had'],
#  ['#@Joke',
#   'other',
#   'has',
#   'nice',
#   'hair."',
#   '\n',
#   '"My',
#   'doctor',
#   'had',
#   'to'],
#  ['#@Joke',
#   'has',
#   'nice',
#   'hair."',
#   '\n',
#   '"My',
#   'doctor',
#   'had',
#   'to',
#   'put'],
#  ['#@Joke', 'nice', 'hair."', '\n', '"My', 'doctor', 'had', 'to', 'put', 'me'],
#  ['#@Joke', 'hair."', '\n', '"My', 'doctor', 'had', 'to', 'put', 'me', 'on'],
#  ['#@Joke', '\n', '"My', 'doctor', 'had', 'to', 'put', 'me', 'on', 'a'],
#  ['#@Joke', '"My', 'doctor', 'had', 'to', 'put', 'me', 'on', 'a', 'new'],
#  ['#@Joke',
#   'doctor',
#   'had',
#   'to',
#   'put',
#   'me',
#   'on',
#   'a',
#   'new',
#   'medication'],
#  ['#@Joke',
#   'had',
#   'to',
#   'put',
#   'me',
#   'on',
#   'a',
#   'new',
#   'medication',
#   "that's"],
#  ['#@Joke',
#   'to',
#   'put',
#   'me',
#   'on',
#   'a',
#   'new',
#   'medication',
#   "that's",
#   'supposed'],
#  ['#@Joke',
#   'put',
#   'me',
#   'on',
#   'a',
#   'new',
#   'medication',
#   "that's",
#   'supposed',
#   'to'],
#  ['#@Joke',
#   'me',
#   'on',
#   'a',
#   'new',
#   'medication',
#   "that's",
#   'supposed',
#   'to',
#   'help'],
#  ['#@Joke',
#   'on',
#   'a',
#   'new',
#   'medication',
#   "that's",
#   'supposed',
#   'to',
#   'help',
#   'lower'],
#  ['#@Joke',
#   'okay',
#   'Me:',
#   '[to',
#   'toilet',
#   'seat]',
#   "you're",
#   'worthless',
#   'and',
#   'nobody'],
#  ['#@Joke',
#   'Me:',
#   '[to',
#   'toilet',
#   'seat]',
#   "you're",
#   'worthless',
#   'and',
#   'nobody',
#   'likes'],
#  ['#@Joke',
#   '[to',
#   'toilet',
#   'seat]',
#   "you're",
#   'worthless',
#   'and',
#   'nobody',
#   'likes',
#   'you"'],
#  ['#@Joke',
#   'toilet',
#   'seat]',
#   "you're",
#   'worthless',
#   'and',
#   'nobody',
#   'likes',
#   'you"',
#   '\n'],
#  ['#@Joke',
#   'seat]',
#   "you're",
#   'worthless',
#   'and',
#   'nobody',
#   'likes',
#   'you"',
#   '\n',
#   '"Q:'],
#  ['#@Joke',
#   "you're",
#   'worthless',
#   'and',
#   'nobody',
#   'likes',
#   'you"',
#   '\n',
#   '"Q:',
#   "What's"],
#  ['#@Joke',
#   'worthless',
#   'and',
#   'nobody',
#   'likes',
#   'you"',
#   '\n',
#   '"Q:',
#   "What's",
#   'the'],
#  ['#@Joke',
#   'and',
#   'nobody',
#   'likes',
#   'you"',
#   '\n',
#   '"Q:',
#   "What's",
#   'the',
#   'difference'],
#  ['#@Joke',
#   'nobody',
#   'likes',
#   'you"',
#   '\n',
#   '"Q:',
#   "What's",
#   'the',
#   'difference',
#   'between'],
#  ['#@Joke',
#   'likes',
#   'you"',
#   '\n',
#   '"Q:',
#   "What's",
#   'the',
#   'difference',
#   'between',
#   'a'],
#  ['#@Joke',
#   'you"',
#   '\n',
#   '"Q:',
#   "What's",
#   'the',
#   'difference',
#   'between',
#   'a',
#   'blonde'],
#  ['#@Joke',
#   '\n',
#   '"Q:',
#   "What's",
#   'the',
#   'difference',
#   'between',
#   'a',
#   'blonde',
#   'and'],
#  ['#@Joke',
#   '"Q:',
#   "What's",
#   'the',
#   'difference',
#   'between',
#   'a',
#   'blonde',
#   'and',
#   'a'],
#  ['#@Joke',
#   "What's",
#   'the',
#   'difference',
#   'between',
#   'a',
#   'blonde',
#   'and',
#   'a',
#   'supermarket'],
#  ['#@Joke',
#   'the',
#   'difference',
#   'between',
#   'a',
#   'blonde',
#   'and',
#   'a',
#   'supermarket',
#   'trolley?'],
#  ['#@Joke',
#   'difference',
#   'between',
#   'a',
#   'blonde',
#   'and',
#   'a',
#   'supermarket',
#   'trolley?',
#   'A:'],
#  ['#@Joke',
#   'between',
#   'a',
#   'blonde',
#   'and',
#   'a',
#   'supermarket',
#   'trolley?',
#   'A:',
#   'The'],
#  ['#@Joke',
#   'a',
#   'blonde',
#   'and',
#   'a',
#   'supermarket',
#   'trolley?',
#   'A:',
#   'The',
#   'supermarket'],
#  ['#@Joke',
#   'blonde',
#   'and',
#   'a',
#   'supermarket',
#   'trolley?',
#   'A:',
#   'The',
#   'supermarket',
#   'trolley'],
#  ['#@Joke',
#   'and',
#   'a',
#   'supermarket',
#   'trolley?',
#   'A:',
#   'The',
#   'supermarket',
#   'trolley',
#   'has'],
#  ['#@Joke',
#   'a',
#   'supermarket',
#   'trolley?',
#   'A:',
#   'The',
#   'supermarket',
#   'trolley',
#   'has',
#   'a'],
#  ['#@Joke',
#   'supermarket',
#   'trolley?',
#   'A:',
#   'The',
#   'supermarket',
#   'trolley',
#   'has',
#   'a',
#   'mind'],
#  ['#@Joke',
#   'to',
#   'you',
#   '""Jesus',
#   'loves',
#   'you.""',
#   "It's",
#   'always',
#   'comforting.',
#   'Unless'],
#  ['#@Joke',
#   'you',
#   '""Jesus',
#   'loves',
#   'you.""',
#   "It's",
#   'always',
#   'comforting.',
#   'Unless',
#   'you'],
#  ['#@Joke',
#   '""Jesus',
#   'loves',
#   'you.""',
#   "It's",
#   'always',
#   'comforting.',
#   'Unless',
#   'you',
#   'are'],
#  ['#@Joke',
#   'loves',
#   'you.""',
#   "It's",
#   'always',
#   'comforting.',
#   'Unless',
#   'you',
#   'are',
#   'in'],
#  ['#@Joke',
#   'you.""',
#   "It's",
#   'always',
#   'comforting.',
#   'Unless',
#   'you',
#   'are',
#   'in',
#   'a'],
#  ['#@Joke',
#   "It's",
#   'always',
#   'comforting.',
#   'Unless',
#   'you',
#   'are',
#   'in',
#   'a',
#   'Mexican'],
#  ['#@Joke',
#   'quality',
#   'assurance""',
#   'I',
#   'think',
#   '""Cool,',
#   "let's",
#   'see',
#   'how',
#   'bad'],
#  ['#@Joke',
#   'assurance""',
#   'I',
#   'think',
#   '""Cool,',
#   "let's",
#   'see',
#   'how',
#   'bad',
#   'this'],
#  ['#@Joke',
#   'their',
#   'job."""',
#   '\n',
#   '"You',
#   'know',
#   'what',
#   'the',
#   'definition',
#   'of'],
#  ['#@Joke',
#   'Finishing',
#   'first',
#   '*and*',
#   'third',
#   'in',
#   'a',
#   'circlejerk."',
#   '\n',
#   '"How'],
#  ['#@Joke',
#   '"[car',
#   'wreck]',
#   '[hand',
#   'reaches',
#   'out]',
#   '""Take',
#   'my',
#   'hand.',
#   "I'm"],
#  ['#@Joke',
#   'flames',
#   'slowly',
#   'bake',
#   'me',
#   'alive]"',
#   '\n',
#   '"Just',
#   'waiting',
#   'for'],
#  ['#@Joke',
#   'slowly',
#   'bake',
#   'me',
#   'alive]"',
#   '\n',
#   '"Just',
#   'waiting',
#   'for',
#   'Steve'],
#  ['#@Joke',
#   '"Chicken',
#   'Why',
#   'did',
#   'the',
#   'chicken',
#   'cross',
#   'the',
#   'road?',
#   'Why?'],
#  ['#@Joke',
#   'Why',
#   'did',
#   'the',
#   'chicken',
#   'cross',
#   'the',
#   'road?',
#   'Why?',
#   'To'],
#  ['#@Joke',
#   'did',
#   'the',
#   'chicken',
#   'cross',
#   'the',
#   'road?',
#   'Why?',
#   'To',
#   'go'],
#  ['#@Joke',
#   'the',
#   'chicken',
#   'cross',
#   'the',
#   'road?',
#   'Why?',
#   'To',
#   'go',
#   'to'],
#  ['#@Joke',
#   'chicken',
#   'cross',
#   'the',
#   'road?',
#   'Why?',
#   'To',
#   'go',
#   'to',
#   'the'],
#  ['#@Joke',
#   "Who's",
#   'there?',
#   'The',
#   'chicken"',
#   '\n',
#   '"Teacher:',
#   'Why',
#   'do',
#   'we'],
#  ['#@Joke',
#   'young',
#   'Skywalker""',
#   'Said',
#   'Adobe',
#   'Wan',
#   'Kenobi."',
#   '\n',
#   '"lookin',
#   'for'],
#  ['#@Joke',
#   'Skywalker""',
#   'Said',
#   'Adobe',
#   'Wan',
#   'Kenobi."',
#   '\n',
#   '"lookin',
#   'for',
#   'a'],
#  ['#@Joke',
#   'Said',
#   'Adobe',
#   'Wan',
#   'Kenobi."',
#   '\n',
#   '"lookin',
#   'for',
#   'a',
#   'quick'],
#  ['#@Joke',
#   'Adobe',
#   'Wan',
#   'Kenobi."',
#   '\n',
#   '"lookin',
#   'for',
#   'a',
#   'quick',
#   'and'],
#  ['#@Joke', 'lake"', '\n', '"TIL', 'A', 'ref', 'can', 'show', 'a', 'player'],
#  ['#@Joke', '\n', '"TIL', 'A', 'ref', 'can', 'show', 'a', 'player', 'the'],
#  ['#@Joke', '"TIL', 'A', 'ref', 'can', 'show', 'a', 'player', 'the', 'red'],
#  ['#@Joke', 'A', 'ref', 'can', 'show', 'a', 'player', 'the', 'red', 'card'],
#  ['#@Joke', 'ref', 'can', 'show', 'a', 'player', 'the', 'red', 'card', 'for'],
#  ['#@Joke', 'can', 'show', 'a', 'player', 'the', 'red', 'card', 'for', 'a'],
#  ['#@Joke', 'show', 'a', 'player', 'the', 'red', 'card', 'for', 'a', 'loud'],
#  ['#@Joke', 'a', 'player', 'the', 'red', 'card', 'for', 'a', 'loud', 'fart'],
#  ['#@Joke', 'player', 'the', 'red', 'card', 'for', 'a', 'loud', 'fart', '...'],
#  ['#@Joke', '\n', '"Guys,', 'I', 'think', 'I', 'found', 'the', 'Cure', 'to'],
#  ['#@Joke',
#   '"Guys,',
#   'I',
#   'think',
#   'I',
#   'found',
#   'the',
#   'Cure',
#   'to',
#   'Aids!'],
#  ['#@Joke', 'I', 'think', 'I', 'found', 'the', 'Cure', 'to', 'Aids!', 'It'],
#  ['#@Joke',
#   'think',
#   'I',
#   'found',
#   'the',
#   'Cure',
#   'to',
#   'Aids!',
#   'It',
#   'requires'],
#  ['#@Joke',
#   'I',
#   'found',
#   'the',
#   'Cure',
#   'to',
#   'Aids!',
#   'It',
#   'requires',
#   'having'],
#  ['#@Joke',
#   'found',
#   'the',
#   'Cure',
#   'to',
#   'Aids!',
#   'It',
#   'requires',
#   'having',
#   'a'],
#  ['#@Joke',
#   '"This',
#   'morning',
#   'I',
#   'had',
#   'a',
#   'swollen',
#   'testicle.',
#   '""I\'d',
#   'have'],
#  ['#@Joke',
#   'morning',
#   'I',
#   'had',
#   'a',
#   'swollen',
#   'testicle.',
#   '""I\'d',
#   'have',
#   'simply'],
#  ['#@Joke',
#   'I',
#   'had',
#   'a',
#   'swollen',
#   'testicle.',
#   '""I\'d',
#   'have',
#   'simply',
#   'preferred'],
#  ['#@Joke',
#   'had',
#   'a',
#   'swollen',
#   'testicle.',
#   '""I\'d',
#   'have',
#   'simply',
#   'preferred',
#   'toast,""'],
#  ['#@Joke',
#   'A',
#   'divorce',
#   'jar.',
#   'Every',
#   'time',
#   'we',
#   'fight',
#   'you',
#   'put'],
#  ['#@Joke',
#   'divorce',
#   'jar.',
#   'Every',
#   'time',
#   'we',
#   'fight',
#   'you',
#   'put',
#   'a'],
#  ['#@Joke',
#   'jar.',
#   'Every',
#   'time',
#   'we',
#   'fight',
#   'you',
#   'put',
#   'a',
#   'dollar'],
#  ['#@Joke', 'Every', 'time', 'we', 'fight', 'you', 'put', 'a', 'dollar', 'in'],
#  ['#@Joke', 'time', 'we', 'fight', 'you', 'put', 'a', 'dollar', 'in', 'and'],
#  ['#@Joke', 'we', 'fight', 'you', 'put', 'a', 'dollar', 'in', 'and', "I'm"],
#  ['#@Joke', 'fight', 'you', 'put', 'a', 'dollar', 'in', 'and', "I'm", 'a'],
#  ['#@Joke', 'you', 'put', 'a', 'dollar', 'in', 'and', "I'm", 'a', 'little'],
#  ['#@Joke', 'put', 'a', 'dollar', 'in', 'and', "I'm", 'a', 'little', 'bit'],
#  ['#@Joke', 'a', 'dollar', 'in', 'and', "I'm", 'a', 'little', 'bit', 'closer'],
#  ['#@Joke',
#   'dollar',
#   'in',
#   'and',
#   "I'm",
#   'a',
#   'little',
#   'bit',
#   'closer',
#   'to'],
#  ['#@Joke',
#   'in',
#   'and',
#   "I'm",
#   'a',
#   'little',
#   'bit',
#   'closer',
#   'to',
#   'freedom.'],
#  ['#@Joke',
#   'and',
#   "I'm",
#   'a',
#   'little',
#   'bit',
#   'closer',
#   'to',
#   'freedom.',
#   '*puts'],
#  ['#@Joke',
#   'and',
#   'you',
#   "don't",
#   'teach',
#   'it',
#   'to',
#   'say,""Help,',
#   "they've",
#   'turned'],
#  ['#@Joke',
#   'you',
#   "don't",
#   'teach',
#   'it',
#   'to',
#   'say,""Help,',
#   "they've",
#   'turned',
#   'me'],
#  ['#@Joke',
#   "don't",
#   'teach',
#   'it',
#   'to',
#   'say,""Help,',
#   "they've",
#   'turned',
#   'me',
#   'into'],
#  ['#@Joke',
#   'teach',
#   'it',
#   'to',
#   'say,""Help,',
#   "they've",
#   'turned',
#   'me',
#   'into',
#   'a'],
#  ['#@Joke',
#   'it',
#   'to',
#   'say,""Help,',
#   "they've",
#   'turned',
#   'me',
#   'into',
#   'a',
#   'parrot.""'],
#  ['#@Joke', 'thing', 'to', 'do', 'to', 'a', 'blind', 'person?', 'Leave', 'a'],
#  ['#@Joke',
#   'to',
#   'do',
#   'to',
#   'a',
#   'blind',
#   'person?',
#   'Leave',
#   'a',
#   'plunger'],
#  ['#@Joke',
#   'do',
#   'to',
#   'a',
#   'blind',
#   'person?',
#   'Leave',
#   'a',
#   'plunger',
#   'in'],
#  ['#@Joke',
#   'want',
#   'to',
#   'hear',
#   'my',
#   'Human',
#   'Centipede',
#   'joke?',
#   'Nah,',
#   'I'],
#  ['#@Joke',
#   'to',
#   'hear',
#   'my',
#   'Human',
#   'Centipede',
#   'joke?',
#   'Nah,',
#   'I',
#   "won't"],
#  ['#@Joke',
#   'sucks',
#   'ass."',
#   '\n',
#   '"My',
#   'dog',
#   'can',
#   'predict',
#   'when',
#   'an'],
#  ['#@Joke',
#   'ass."',
#   '\n',
#   '"My',
#   'dog',
#   'can',
#   'predict',
#   'when',
#   'an',
#   'earthquake'],
#  ['#@Joke',
#   'out."',
#   '\n',
#   '"With',
#   '10K',
#   'characters,',
#   'I',
#   'can',
#   'finally',
#   'get'],
#  ['#@Joke',
#   '\n',
#   '"With',
#   '10K',
#   'characters,',
#   'I',
#   'can',
#   'finally',
#   'get',
#   'into'],
#  ['#@Joke',
#   '"With',
#   '10K',
#   'characters,',
#   'I',
#   'can',
#   'finally',
#   'get',
#   'into',
#   'great'],
#  ['#@Joke',
#   'die?',
#   'He',
#   'ran',
#   'into',
#   'oncoming',
#   'traffic',
#   'after',
#   'walking',
#   'past'],
#  ['#@Joke',
#   'He',
#   'ran',
#   'into',
#   'oncoming',
#   'traffic',
#   'after',
#   'walking',
#   'past',
#   'a'],
#  ['#@Joke',
#   'ran',
#   'into',
#   'oncoming',
#   'traffic',
#   'after',
#   'walking',
#   'past',
#   'a',
#   'group'],
#  ['#@Joke',
#   'into',
#   'oncoming',
#   'traffic',
#   'after',
#   'walking',
#   'past',
#   'a',
#   'group',
#   'of'],
#  ['#@Joke',
#   'oncoming',
#   'traffic',
#   'after',
#   'walking',
#   'past',
#   'a',
#   'group',
#   'of',
#   'adults'],
#  ['#@Joke',
#   'traffic',
#   'after',
#   'walking',
#   'past',
#   'a',
#   'group',
#   'of',
#   'adults',
#   'saying'],
#  ['#@Joke',
#   'after',
#   'walking',
#   'past',
#   'a',
#   'group',
#   'of',
#   'adults',
#   'saying',
#   'the'],
#  ['#@Joke',
#   'walking',
#   'past',
#   'a',
#   'group',
#   'of',
#   'adults',
#   'saying',
#   'the',
#   'word'],
#  ['#@Joke',
#   'past',
#   'a',
#   'group',
#   'of',
#   'adults',
#   'saying',
#   'the',
#   'word',
#   '""bae"""'],
#  ['#@Joke',
#   'a',
#   'group',
#   'of',
#   'adults',
#   'saying',
#   'the',
#   'word',
#   '""bae"""',
#   '\n'],
#  ['#@Joke',
#   'group',
#   'of',
#   'adults',
#   'saying',
#   'the',
#   'word',
#   '""bae"""',
#   '\n',
#   '"Stealing'],
#  ['#@Joke',
#   'of',
#   'adults',
#   'saying',
#   'the',
#   'word',
#   '""bae"""',
#   '\n',
#   '"Stealing',
#   'my'],
#  ['#@Joke',
#   'adults',
#   'saying',
#   'the',
#   'word',
#   '""bae"""',
#   '\n',
#   '"Stealing',
#   'my',
#   'little'],
#  ['#@Joke',
#   'saying',
#   'the',
#   'word',
#   '""bae"""',
#   '\n',
#   '"Stealing',
#   'my',
#   'little',
#   "brother's"],
#  ['#@Joke',
#   'the',
#   'word',
#   '""bae"""',
#   '\n',
#   '"Stealing',
#   'my',
#   'little',
#   "brother's",
#   '(fellow'],
#  ['#@Joke',
#   'A',
#   'Porky-Pine"',
#   '\n',
#   '"What',
#   'do',
#   'you',
#   'call',
#   'a',
#   'frisbee'],
#  ['#@Joke',
#   'Porky-Pine"',
#   '\n',
#   '"What',
#   'do',
#   'you',
#   'call',
#   'a',
#   'frisbee',
#   "that's"],
#  ['#@Joke',
#   '\n',
#   '"What',
#   'do',
#   'you',
#   'call',
#   'a',
#   'frisbee',
#   "that's",
#   'more'],
#  ['#@Joke',
#   '\n',
#   '"What\'s',
#   'the',
#   'best',
#   'part',
#   'of',
#   'a',
#   'pregnancy',
#   'joke?'],
#  ['#@Joke',
#   '"What\'s',
#   'the',
#   'best',
#   'part',
#   'of',
#   'a',
#   'pregnancy',
#   'joke?',
#   'The'],
#  ['#@Joke',
#   'the',
#   'best',
#   'part',
#   'of',
#   'a',
#   'pregnancy',
#   'joke?',
#   'The',
#   'delivery."'],
#  ['#@Joke',
#   'best',
#   'part',
#   'of',
#   'a',
#   'pregnancy',
#   'joke?',
#   'The',
#   'delivery."',
#   '\n'],
#  ['#@Joke',
#   'type',
#   'of',
#   'weaponry?',
#   "It's",
#   'ARRRtillery!',
#   'bonus:',
#   'A',
#   "pirate's",
#   'favourite'],
#  ['#@Joke',
#   'of',
#   'weaponry?',
#   "It's",
#   'ARRRtillery!',
#   'bonus:',
#   'A',
#   "pirate's",
#   'favourite',
#   'melee'],
#  ['#@Joke',
#   'weaponry?',
#   "It's",
#   'ARRRtillery!',
#   'bonus:',
#   'A',
#   "pirate's",
#   'favourite',
#   'melee',
#   'weapon?'],
#  ['#@Joke',
#   '"*Guy',
#   'tries',
#   'giving',
#   'me',
#   'his',
#   'phone',
#   'number*',
#   'Me:',
#   'Oh'],
#  ['#@Joke',
#   'tries',
#   'giving',
#   'me',
#   'his',
#   'phone',
#   'number*',
#   'Me:',
#   'Oh',
#   'no'],
#  ['#@Joke',
#   'giving',
#   'me',
#   'his',
#   'phone',
#   'number*',
#   'Me:',
#   'Oh',
#   'no',
#   'thank'],
#  ['#@Joke',
#   'me',
#   'his',
#   'phone',
#   'number*',
#   'Me:',
#   'Oh',
#   'no',
#   'thank',
#   'you.'],
#  ['#@Joke',
#   'his',
#   'phone',
#   'number*',
#   'Me:',
#   'Oh',
#   'no',
#   'thank',
#   'you.',
#   'I'],
#  ['#@Joke',
#   'phone',
#   'number*',
#   'Me:',
#   'Oh',
#   'no',
#   'thank',
#   'you.',
#   'I',
#   'already'],
#  ['#@Joke',
#   'number*',
#   'Me:',
#   'Oh',
#   'no',
#   'thank',
#   'you.',
#   'I',
#   'already',
#   'have'],
#  ['#@Joke',
#   '"I\'m',
#   'glad',
#   "it's",
#   'the',
#   'thought',
#   'that',
#   'counts',
#   'because',
#   'I'],
#  ['#@Joke',
#   'give',
#   'milk?',
#   'No,',
#   'they',
#   'have',
#   'to',
#   'take',
#   'it',
#   'from'],
#  ['#@Joke',
#   'milk?',
#   'No,',
#   'they',
#   'have',
#   'to',
#   'take',
#   'it',
#   'from',
#   'her"'],
#  ['#@Joke',
#   'my',
#   'four',
#   'leaf',
#   'clover.',
#   'That',
#   "can't",
#   'be',
#   'good......."',
#   '\n'],
#  ['#@Joke',
#   'four',
#   'leaf',
#   'clover.',
#   'That',
#   "can't",
#   'be',
#   'good......."',
#   '\n',
#   '"Why'],
#  ['#@Joke',
#   'leaf',
#   'clover.',
#   'That',
#   "can't",
#   'be',
#   'good......."',
#   '\n',
#   '"Why',
#   "can't"],
#  ['#@Joke',
#   'clover.',
#   'That',
#   "can't",
#   'be',
#   'good......."',
#   '\n',
#   '"Why',
#   "can't",
#   'a'],
#  ['#@Joke',
#   'That',
#   "can't",
#   'be',
#   'good......."',
#   '\n',
#   '"Why',
#   "can't",
#   'a',
#   'bike'],
#  ['#@Joke',
#   "can't",
#   'be',
#   'good......."',
#   '\n',
#   '"Why',
#   "can't",
#   'a',
#   'bike',
#   'stand'],
#  ['#@Joke',
#   'to',
#   'his',
#   'lover',
#   'when',
#   'they',
#   'were',
#   'going',
#   'on',
#   'vacation?'],
#  ['#@Joke',
#   'his',
#   'lover',
#   'when',
#   'they',
#   'were',
#   'going',
#   'on',
#   'vacation?',
#   '""Hey,'],
#  ['#@Joke',
#   'shoes',
#   'while',
#   "he's",
#   'talking',
#   'to',
#   'you',
#   'instead',
#   'of',
#   'his'],
#  ['#@Joke',
#   'while',
#   "he's",
#   'talking',
#   'to',
#   'you',
#   'instead',
#   'of',
#   'his',
#   'own."'],
#  ['#@Joke',
#   "he's",
#   'talking',
#   'to',
#   'you',
#   'instead',
#   'of',
#   'his',
#   'own."',
#   '\n'],
#  ['#@Joke',
#   'talking',
#   'to',
#   'you',
#   'instead',
#   'of',
#   'his',
#   'own."',
#   '\n',
#   '"Why'],
#  ['#@Joke', 'to', 'you', 'instead', 'of', 'his', 'own."', '\n', '"Why', 'are'],
#  ['#@Joke',
#   'you',
#   'instead',
#   'of',
#   'his',
#   'own."',
#   '\n',
#   '"Why',
#   'are',
#   'hillbilly'],
#  ['#@Joke',
#   'instead',
#   'of',
#   'his',
#   'own."',
#   '\n',
#   '"Why',
#   'are',
#   'hillbilly',
#   'murders'],
#  ['#@Joke', 'a', 'joke', 'for', 'you...', 'I', 'texted', 'it', 'to', 'Angela'],
#  ['#@Joke',
#   'bed...',
#   'But',
#   'I',
#   "don't",
#   'know',
#   'how',
#   'my',
#   'best',
#   'friend'],
#  ['#@Joke',
#   'about',
#   'not',
#   'making',
#   'deadlines?',
#   "Panickin'",
#   'Skywalker."',
#   '\n',
#   '"Why',
#   'did'],
#  ['#@Joke',
#   'an',
#   'elephant',
#   'in',
#   'a',
#   'fridge?',
#   'You',
#   'remove',
#   'his',
#   'slippers'],
#  ['#@Joke',
#   'elephant',
#   'in',
#   'a',
#   'fridge?',
#   'You',
#   'remove',
#   'his',
#   'slippers',
#   'and'],
#  ['#@Joke',
#   'gym?',
#   "I'll",
#   're-rack."',
#   '\n',
#   '"You\'re',
#   'shoes',
#   'are',
#   'untied!',
#   'April'],
#  ['#@Joke',
#   "I'll",
#   're-rack."',
#   '\n',
#   '"You\'re',
#   'shoes',
#   'are',
#   'untied!',
#   'April',
#   'fools!'],
#  ['#@Joke',
#   're-rack."',
#   '\n',
#   '"You\'re',
#   'shoes',
#   'are',
#   'untied!',
#   'April',
#   'fools!',
#   'Got'],
#  ['#@Joke',
#   '\n',
#   '"You\'re',
#   'shoes',
#   'are',
#   'untied!',
#   'April',
#   'fools!',
#   'Got',
#   'ya!!"'],
#  ['#@Joke',
#   '"You\'re',
#   'shoes',
#   'are',
#   'untied!',
#   'April',
#   'fools!',
#   'Got',
#   'ya!!"',
#   '\n'],
#  ['#@Joke',
#   'shoes',
#   'are',
#   'untied!',
#   'April',
#   'fools!',
#   'Got',
#   'ya!!"',
#   '\n',
#   '"Right'],
#  ['#@Joke',
#   '"Gentlemen',
#   'test',
#   'At',
#   'least',
#   'most',
#   'tests',
#   'have',
#   'the',
#   'decency'],
#  ['#@Joke',
#   'test',
#   'At',
#   'least',
#   'most',
#   'tests',
#   'have',
#   'the',
#   'decency',
#   'to'],
#  ['#@Joke',
#   'At',
#   'least',
#   'most',
#   'tests',
#   'have',
#   'the',
#   'decency',
#   'to',
#   'ask'],
#  ['#@Joke',
#   'least',
#   'most',
#   'tests',
#   'have',
#   'the',
#   'decency',
#   'to',
#   'ask',
#   'me'],
#  ['#@Joke',
#   'most',
#   'tests',
#   'have',
#   'the',
#   'decency',
#   'to',
#   'ask',
#   'me',
#   'my'],
#  ['#@Joke',
#   'tests',
#   'have',
#   'the',
#   'decency',
#   'to',
#   'ask',
#   'me',
#   'my',
#   'name,'],
#  ['#@Joke',
#   'have',
#   'the',
#   'decency',
#   'to',
#   'ask',
#   'me',
#   'my',
#   'name,',
#   'before'],
#  ['#@Joke',
#   'the',
#   'decency',
#   'to',
#   'ask',
#   'me',
#   'my',
#   'name,',
#   'before',
#   'they'],
#  ['#@Joke',
#   'decency',
#   'to',
#   'ask',
#   'me',
#   'my',
#   'name,',
#   'before',
#   'they',
#   'fuck'],
#  ['#@Joke',
#   'to',
#   'ask',
#   'me',
#   'my',
#   'name,',
#   'before',
#   'they',
#   'fuck',
#   'me."'],
#  ['#@Joke',
#   'ask',
#   'me',
#   'my',
#   'name,',
#   'before',
#   'they',
#   'fuck',
#   'me."',
#   '\n'],
#  ['#@Joke',
#   'me',
#   'my',
#   'name,',
#   'before',
#   'they',
#   'fuck',
#   'me."',
#   '\n',
#   '"What'],
#  ['#@Joke',
#   'my',
#   'name,',
#   'before',
#   'they',
#   'fuck',
#   'me."',
#   '\n',
#   '"What',
#   'do'],
#  ['#@Joke',
#   'a',
#   'cheap',
#   'circumcision?',
#   'A',
#   'rip-off."',
#   '\n',
#   '"I',
#   'went',
#   'in'],
#  ['#@Joke',
#   'cheap',
#   'circumcision?',
#   'A',
#   'rip-off."',
#   '\n',
#   '"I',
#   'went',
#   'in',
#   'to'],
#  ['#@Joke',
#   'circumcision?',
#   'A',
#   'rip-off."',
#   '\n',
#   '"I',
#   'went',
#   'in',
#   'to',
#   'hospital'],
#  ['#@Joke',
#   'operation...',
#   'I',
#   'asked',
#   'the',
#   'anaesthetist',
#   'if',
#   'I',
#   'could',
#   'administer'],
#  ['#@Joke',
#   'I',
#   'asked',
#   'the',
#   'anaesthetist',
#   'if',
#   'I',
#   'could',
#   'administer',
#   'the'],
#  ['#@Joke',
#   'snakes',
#   'favourite',
#   'dance',
#   '?',
#   'The',
#   'mamba',
#   '!"',
#   '\n',
#   '"What'],
#  ['#@Joke',
#   'favourite',
#   'dance',
#   '?',
#   'The',
#   'mamba',
#   '!"',
#   '\n',
#   '"What',
#   'do'],
#  ['#@Joke', 'dance', '?', 'The', 'mamba', '!"', '\n', '"What', 'do', 'you'],
#  ['#@Joke',
#   'microwave',
#   'that',
#   'plays',
#   "Europe's",
#   '""The',
#   'Final',
#   'Countdown""',
#   'during',
#   'the'],
#  ['#@Joke',
#   'that',
#   'plays',
#   "Europe's",
#   '""The',
#   'Final',
#   'Countdown""',
#   'during',
#   'the',
#   'last'],
#  ['#@Joke',
#   'plays',
#   "Europe's",
#   '""The',
#   'Final',
#   'Countdown""',
#   'during',
#   'the',
#   'last',
#   '30'],
#  ['#@Joke',
#   'slowly',
#   'getting',
#   'more',
#   'perverse.',
#   'But',
#   'it',
#   "wasn't",
#   'until',
#   'I'],
#  ['#@Joke',
#   "don't",
#   'have',
#   'a',
#   'cow""',
#   'the',
#   "neighbors'",
#   'cow',
#   'then',
#   '""Their'],
#  ['#@Joke',
#   'have',
#   'a',
#   'cow""',
#   'the',
#   "neighbors'",
#   'cow',
#   'then',
#   '""Their',
#   'cat?""'],
#  ['#@Joke',
#   'a',
#   'cow""',
#   'the',
#   "neighbors'",
#   'cow',
#   'then',
#   '""Their',
#   'cat?""',
#   'Pretty'],
#  ['#@Joke',
#   'cow""',
#   'the',
#   "neighbors'",
#   'cow',
#   'then',
#   '""Their',
#   'cat?""',
#   'Pretty',
#   'sure'],
#  ['#@Joke',
#   'the',
#   "neighbors'",
#   'cow',
#   'then',
#   '""Their',
#   'cat?""',
#   'Pretty',
#   'sure',
#   'it'],
#  ['#@Joke',
#   "neighbors'",
#   'cow',
#   'then',
#   '""Their',
#   'cat?""',
#   'Pretty',
#   'sure',
#   'it',
#   'was'],
#  ['#@Joke',
#   'can',
#   'think',
#   'about',
#   'a',
#   'solution',
#   'in',
#   'silence"',
#   '\n',
#   '"Waiting'],
#  ['#@Joke',
#   'think',
#   'about',
#   'a',
#   'solution',
#   'in',
#   'silence"',
#   '\n',
#   '"Waiting',
#   'for'],
#  ['#@Joke',
#   'about',
#   'a',
#   'solution',
#   'in',
#   'silence"',
#   '\n',
#   '"Waiting',
#   'for',
#   'the'],
#  ['#@Joke',
#   'a',
#   'solution',
#   'in',
#   'silence"',
#   '\n',
#   '"Waiting',
#   'for',
#   'the',
#   'day'],
#  ['#@Joke',
#   'solution',
#   'in',
#   'silence"',
#   '\n',
#   '"Waiting',
#   'for',
#   'the',
#   'day',
#   'when'],
#  ['#@Joke',
#   'finally',
#   'says',
#   'that',
#   "I'm",
#   '""the',
#   'one,""',
#   'but',
#   "isn't",
#   'talking'],
#  ['#@Joke',
#   'says',
#   'that',
#   "I'm",
#   '""the',
#   'one,""',
#   'but',
#   "isn't",
#   'talking',
#   'to'],
#  ['#@Joke',
#   'that',
#   "I'm",
#   '""the',
#   'one,""',
#   'but',
#   "isn't",
#   'talking',
#   'to',
#   'a'],
#  ['#@Joke',
#   "I'm",
#   '""the',
#   'one,""',
#   'but',
#   "isn't",
#   'talking',
#   'to',
#   'a',
#   'police'],
#  ['#@Joke',
#   '""the',
#   'one,""',
#   'but',
#   "isn't",
#   'talking',
#   'to',
#   'a',
#   'police',
#   'officer."'],
#  ['#@Joke',
#   'one,""',
#   'but',
#   "isn't",
#   'talking',
#   'to',
#   'a',
#   'police',
#   'officer."',
#   '\n'],
#  ['#@Joke',
#   'but',
#   "isn't",
#   'talking',
#   'to',
#   'a',
#   'police',
#   'officer."',
#   '\n',
#   '"Some'],
#  ['#@Joke',
#   "isn't",
#   'talking',
#   'to',
#   'a',
#   'police',
#   'officer."',
#   '\n',
#   '"Some',
#   'people'],
#  ['#@Joke',
#   'talking',
#   'to',
#   'a',
#   'police',
#   'officer."',
#   '\n',
#   '"Some',
#   'people',
#   'say'],
#  ['#@Joke',
#   'to',
#   'a',
#   'police',
#   'officer."',
#   '\n',
#   '"Some',
#   'people',
#   'say',
#   'Glenn'],
#  ['#@Joke',
#   'a',
#   'police',
#   'officer."',
#   '\n',
#   '"Some',
#   'people',
#   'say',
#   'Glenn',
#   'Frey'],
#  ['#@Joke',
#   'police',
#   'officer."',
#   '\n',
#   '"Some',
#   'people',
#   'say',
#   'Glenn',
#   'Frey',
#   'got'],
#  ['#@Joke',
#   'is',
#   'it',
#   'that',
#   'the',
#   'more',
#   'numbers',
#   'someone',
#   'has',
#   'in'],
#  ['#@Joke',
#   'it',
#   'that',
#   'the',
#   'more',
#   'numbers',
#   'someone',
#   'has',
#   'in',
#   'their'],
#  ['#@Joke',
#   'that',
#   'the',
#   'more',
#   'numbers',
#   'someone',
#   'has',
#   'in',
#   'their',
#   'e-mail'],
#  ['#@Joke',
#   'the',
#   'more',
#   'numbers',
#   'someone',
#   'has',
#   'in',
#   'their',
#   'e-mail',
#   'address,'],
#  ['#@Joke',
#   'more',
#   'numbers',
#   'someone',
#   'has',
#   'in',
#   'their',
#   'e-mail',
#   'address,',
#   'the'],
#  ['#@Joke',
#   'numbers',
#   'someone',
#   'has',
#   'in',
#   'their',
#   'e-mail',
#   'address,',
#   'the',
#   'less'],
#  ['#@Joke',
#   'someone',
#   'has',
#   'in',
#   'their',
#   'e-mail',
#   'address,',
#   'the',
#   'less',
#   'I'],
#  ['#@Joke',
#   'has',
#   'in',
#   'their',
#   'e-mail',
#   'address,',
#   'the',
#   'less',
#   'I',
#   'respect'],
#  ['#@Joke',
#   'in',
#   'their',
#   'e-mail',
#   'address,',
#   'the',
#   'less',
#   'I',
#   'respect',
#   'them?"'],
#  ['#@Joke',
#   'their',
#   'e-mail',
#   'address,',
#   'the',
#   'less',
#   'I',
#   'respect',
#   'them?"',
#   '\n'],
#  ['#@Joke',
#   'e-mail',
#   'address,',
#   'the',
#   'less',
#   'I',
#   'respect',
#   'them?"',
#   '\n',
#   '"What'],
#  ['#@Joke',
#   'address,',
#   'the',
#   'less',
#   'I',
#   'respect',
#   'them?"',
#   '\n',
#   '"What',
#   'does'],
#  ['#@Joke',
#   'complaining',
#   'when',
#   'you',
#   'try',
#   'to',
#   'watch',
#   'TV',
#   'in',
#   'the'],
#  ['#@Joke', 'when', 'you', 'try', 'to', 'watch', 'TV', 'in', 'the', 'living'],
#  ['#@Joke', 'you', 'try', 'to', 'watch', 'TV', 'in', 'the', 'living', 'room?'],
#  ['#@Joke', 'try', 'to', 'watch', 'TV', 'in', 'the', 'living', 'room?', 'You'],
#  ['#@Joke',
#   'to',
#   'watch',
#   'TV',
#   'in',
#   'the',
#   'living',
#   'room?',
#   'You',
#   'made'],
#  ['#@Joke',
#   '\n',
#   '"How',
#   'are',
#   'doctors',
#   'so',
#   'well',
#   'tempered',
#   'even',
#   'under'],
#  ['#@Joke',
#   '"How',
#   'are',
#   'doctors',
#   'so',
#   'well',
#   'tempered',
#   'even',
#   'under',
#   'heavy'],
#  ['#@Joke',
#   'are',
#   'doctors',
#   'so',
#   'well',
#   'tempered',
#   'even',
#   'under',
#   'heavy',
#   'stress?'],
#  ['#@Joke',
#   'doctors',
#   'so',
#   'well',
#   'tempered',
#   'even',
#   'under',
#   'heavy',
#   'stress?',
#   'They'],
#  ['#@Joke',
#   'so',
#   'well',
#   'tempered',
#   'even',
#   'under',
#   'heavy',
#   'stress?',
#   'They',
#   'have'],
#  ['#@Joke',
#   'well',
#   'tempered',
#   'even',
#   'under',
#   'heavy',
#   'stress?',
#   'They',
#   'have',
#   'a'],
#  ['#@Joke',
#   'put',
#   'our',
#   'picture',
#   'as',
#   'their',
#   'profile',
#   'picture."',
#   '\n',
#   '"Why'],
#  ['#@Joke',
#   'our',
#   'picture',
#   'as',
#   'their',
#   'profile',
#   'picture."',
#   '\n',
#   '"Why',
#   'are'],
#  ['#@Joke',
#   'picture',
#   'as',
#   'their',
#   'profile',
#   'picture."',
#   '\n',
#   '"Why',
#   'are',
#   'Native'],
#  ['#@Joke',
#   'successfull',
#   'strippers?',
#   'Because',
#   'when',
#   'they',
#   'dance,',
#   'they',
#   'make',
#   'it'],
#  ['#@Joke',
#   'strippers?',
#   'Because',
#   'when',
#   'they',
#   'dance,',
#   'they',
#   'make',
#   'it',
#   'rain."'],
#  ['#@Joke',
#   'Because',
#   'when',
#   'they',
#   'dance,',
#   'they',
#   'make',
#   'it',
#   'rain."',
#   '\n'],
#  ['#@Joke',
#   'when',
#   'they',
#   'dance,',
#   'they',
#   'make',
#   'it',
#   'rain."',
#   '\n',
#   '"My'],
#  ['#@Joke',
#   'they',
#   'dance,',
#   'they',
#   'make',
#   'it',
#   'rain."',
#   '\n',
#   '"My',
#   'ex-girlfriend'],
#  ['#@Joke',
#   'dance,',
#   'they',
#   'make',
#   'it',
#   'rain."',
#   '\n',
#   '"My',
#   'ex-girlfriend',
#   'was'],
#  ['#@Joke',
#   'they',
#   'make',
#   'it',
#   'rain."',
#   '\n',
#   '"My',
#   'ex-girlfriend',
#   'was',
#   'a'],
#  ['#@Joke',
#   'make',
#   'it',
#   'rain."',
#   '\n',
#   '"My',
#   'ex-girlfriend',
#   'was',
#   'a',
#   'slut.'],
#  ['#@Joke',
#   'it',
#   'rain."',
#   '\n',
#   '"My',
#   'ex-girlfriend',
#   'was',
#   'a',
#   'slut.',
#   'She'],
#  ['#@Joke',
#   'rain."',
#   '\n',
#   '"My',
#   'ex-girlfriend',
#   'was',
#   'a',
#   'slut.',
#   'She',
#   'bust'],
#  ['#@Joke',
#   'than',
#   'a',
#   'pistachio',
#   'junkie.',
#   'edit:',
#   'Going',
#   'through',
#   'a',
#   'potential'],
#  ['#@Joke',
#   'zoo."',
#   '\n',
#   '"You',
#   'just',
#   'know',
#   'I',
#   'knew',
#   'my',
#   'girlfriend'],
#  ['#@Joke',
#   '\n',
#   '"You',
#   'just',
#   'know',
#   'I',
#   'knew',
#   'my',
#   'girlfriend',
#   'was'],
#  ['#@Joke',
#   '"You',
#   'just',
#   'know',
#   'I',
#   'knew',
#   'my',
#   'girlfriend',
#   'was',
#   'furious'],
#  ['#@Joke',
#   'just',
#   'know',
#   'I',
#   'knew',
#   'my',
#   'girlfriend',
#   'was',
#   'furious',
#   'when'],
#  ['#@Joke',
#   'know',
#   'I',
#   'knew',
#   'my',
#   'girlfriend',
#   'was',
#   'furious',
#   'when',
#   'I'],
#  ['#@Joke',
#   'load',
#   'early',
#   'last',
#   'night....I',
#   'could',
#   'see',
#   'it',
#   'in',
#   'her'],
#  ['#@Joke',
#   'early',
#   'last',
#   'night....I',
#   'could',
#   'see',
#   'it',
#   'in',
#   'her',
#   'eyes"'],
#  ['#@Joke',
#   'last',
#   'night....I',
#   'could',
#   'see',
#   'it',
#   'in',
#   'her',
#   'eyes"',
#   '\n'],
#  ['#@Joke',
#   'night....I',
#   'could',
#   'see',
#   'it',
#   'in',
#   'her',
#   'eyes"',
#   '\n',
#   '"FOR'],
#  ['#@Joke',
#   'a',
#   'vegan,',
#   'and',
#   'a',
#   'crossfit',
#   'fanatic',
#   'walk',
#   'into',
#   'a'],
#  ['#@Joke',
#   'vegan,',
#   'and',
#   'a',
#   'crossfit',
#   'fanatic',
#   'walk',
#   'into',
#   'a',
#   'bar...'],
#  ['#@Joke',
#   'and',
#   'a',
#   'crossfit',
#   'fanatic',
#   'walk',
#   'into',
#   'a',
#   'bar...',
#   'Who'],
#  ['#@Joke',
#   'a',
#   'crossfit',
#   'fanatic',
#   'walk',
#   'into',
#   'a',
#   'bar...',
#   'Who',
#   'talks'],
#  ['#@Joke',
#   'crossfit',
#   'fanatic',
#   'walk',
#   'into',
#   'a',
#   'bar...',
#   'Who',
#   'talks',
#   'more?"'],
#  ['#@Joke',
#   'my',
#   'fault',
#   'they',
#   "don't",
#   'have',
#   'Windows."',
#   '\n',
#   '"I',
#   'left'],
#  ['#@Joke',
#   'messages',
#   'before',
#   'I',
#   'realised',
#   "he'd",
#   'picked',
#   'up',
#   'every',
#   'time."'],
#  ['#@Joke',
#   'before',
#   'I',
#   'realised',
#   "he'd",
#   'picked',
#   'up',
#   'every',
#   'time."',
#   '\n'],
#  ['#@Joke',
#   'I',
#   'realised',
#   "he'd",
#   'picked',
#   'up',
#   'every',
#   'time."',
#   '\n',
#   '"My'],
#  ['#@Joke',
#   'all',
#   'scream',
#   'for',
#   'ice',
#   'cream.',
#   'This',
#   'kid',
#   'working',
#   'at'],
#  ['#@Joke',
#   'windscreen',
#   'wipers',
#   'for',
#   'my',
#   'Trabi',
#   'please.""',
#   'The',
#   'attendant',
#   'replies:'],
#  ['#@Joke',
#   'wipers',
#   'for',
#   'my',
#   'Trabi',
#   'please.""',
#   'The',
#   'attendant',
#   'replies:',
#   '""That'],
#  ['#@Joke',
#   'for',
#   'my',
#   'Trabi',
#   'please.""',
#   'The',
#   'attendant',
#   'replies:',
#   '""That',
#   'sounds'],
#  ['#@Joke',
#   'my',
#   'Trabi',
#   'please.""',
#   'The',
#   'attendant',
#   'replies:',
#   '""That',
#   'sounds',
#   'like'],
#  ['#@Joke',
#   'Trabi',
#   'please.""',
#   'The',
#   'attendant',
#   'replies:',
#   '""That',
#   'sounds',
#   'like',
#   'a'],
#  ['#@Joke',
#   'please.""',
#   'The',
#   'attendant',
#   'replies:',
#   '""That',
#   'sounds',
#   'like',
#   'a',
#   'good'],
#  ['#@Joke',
#   'just',
#   'beat',
#   'the',
#   'room',
#   'for',
#   'being',
#   'black!"',
#   '\n',
#   '"Coffee'],
#  ['#@Joke',
#   'beat',
#   'the',
#   'room',
#   'for',
#   'being',
#   'black!"',
#   '\n',
#   '"Coffee',
#   'so'],
#  ['#@Joke',
#   'the',
#   'room',
#   'for',
#   'being',
#   'black!"',
#   '\n',
#   '"Coffee',
#   'so',
#   'good'],
#  ['#@Joke',
#   'room',
#   'for',
#   'being',
#   'black!"',
#   '\n',
#   '"Coffee',
#   'so',
#   'good',
#   'it'],
#  ['#@Joke',
#   'for',
#   'being',
#   'black!"',
#   '\n',
#   '"Coffee',
#   'so',
#   'good',
#   'it',
#   'helps'],
#  ['#@Joke',
#   'being',
#   'black!"',
#   '\n',
#   '"Coffee',
#   'so',
#   'good',
#   'it',
#   'helps',
#   'a'],
#  ['#@Joke',
#   'black!"',
#   '\n',
#   '"Coffee',
#   'so',
#   'good',
#   'it',
#   'helps',
#   'a',
#   'little'],
#  ['#@Joke',
#   'cross',
#   'the',
#   'street."',
#   '\n',
#   '"Why',
#   'did',
#   'the',
#   'semen',
#   'cross'],
#  ['#@Joke',
#   'this',
#   'morning."',
#   '\n',
#   '"What',
#   'did',
#   'nazi',
#   'pilots',
#   'eat',
#   'for'],
#  ['#@Joke',
#   'morning."',
#   '\n',
#   '"What',
#   'did',
#   'nazi',
#   'pilots',
#   'eat',
#   'for',
#   'breakfast?'],
#  ['#@Joke',
#   'light-hearted?',
#   "They're",
#   'dark',
#   'comedies."',
#   '\n',
#   '"Every',
#   'woman',
#   "I've",
#   'ever'],
#  ['#@Joke',
#   'you',
#   'stop',
#   'a',
#   'baby',
#   'from',
#   'crawling',
#   'in',
#   'circles?',
#   'Nail'],
#  ['#@Joke',
#   'stop',
#   'a',
#   'baby',
#   'from',
#   'crawling',
#   'in',
#   'circles?',
#   'Nail',
#   'its'],
#  ['#@Joke',
#   'a',
#   'baby',
#   'from',
#   'crawling',
#   'in',
#   'circles?',
#   'Nail',
#   'its',
#   'other'],
#  ['#@Joke',
#   'baby',
#   'from',
#   'crawling',
#   'in',
#   'circles?',
#   'Nail',
#   'its',
#   'other',
#   'hand'],
#  ['#@Joke',
#   'from',
# ...
#   'got',
#   'a',
#   '10',
#   'year',
#   'old',
#   'daughter',
#   'I',
#   'could',
#   'introduce'],
#  ['#@Joke',
#   'Stuck',
#   'in',
#   'an',
#   'elaborate',
#   'lie',
#   'after',
#   'putting',
#   'my',
#   'music'],
#  ['#@Joke',
#   'in',
#   'an',
#   'elaborate',
#   'lie',
#   'after',
#   'putting',
#   'my',
#   'music',
#   'on'],
#  ['#@Joke',
#   'money.',
#   'But',
#   "I'm",
#   'pretty',
#   'sure',
#   'my',
#   'landlord',
#   'is',
#   'gona'],
#  ['#@Joke',
#   'But',
#   "I'm",
#   'pretty',
#   'sure',
#   'my',
#   'landlord',
#   'is',
#   'gona',
#   'want'],
#  ['#@Joke',
#   "I'm",
#   'pretty',
#   'sure',
#   'my',
#   'landlord',
#   'is',
#   'gona',
#   'want',
#   'more'],
#  ['#@Joke',
#   'pretty',
#   'sure',
#   'my',
#   'landlord',
#   'is',
#   'gona',
#   'want',
#   'more',
#   'than'],
#  ['#@Joke',
#   'sure',
#   'my',
#   'landlord',
#   'is',
#   'gona',
#   'want',
#   'more',
#   'than',
#   'a'],
#  ['#@Joke',
#   'my',
#   'landlord',
#   'is',
#   'gona',
#   'want',
#   'more',
#   'than',
#   'a',
#   'hug."'],
#  ['#@Joke',
#   'landlord',
#   'is',
#   'gona',
#   'want',
#   'more',
#   'than',
#   'a',
#   'hug."',
#   '\n'],
#  ['#@Joke', 'is', 'gona', 'want', 'more', 'than', 'a', 'hug."', '\n', '"I'],
#  ['#@Joke', 'gona', 'want', 'more', 'than', 'a', 'hug."', '\n', '"I', 'heard'],
#  ['#@Joke', 'want', 'more', 'than', 'a', 'hug."', '\n', '"I', 'heard', 'that'],
#  ['#@Joke',
#   'more',
#   'than',
#   'a',
#   'hug."',
#   '\n',
#   '"I',
#   'heard',
#   'that',
#   'Being'],
#  ['#@Joke', 'than', 'a', 'hug."', '\n', '"I', 'heard', 'that', 'Being', 'the'],
#  ['#@Joke', 'a', 'hug."', '\n', '"I', 'heard', 'that', 'Being', 'the', 'one'],
#  ['#@Joke', 'hug."', '\n', '"I', 'heard', 'that', 'Being', 'the', 'one', 'to'],
#  ['#@Joke',
#   '\n',
#   '"I',
#   'heard',
#   'that',
#   'Being',
#   'the',
#   'one',
#   'to',
#   'circumcise'],
#  ['#@Joke',
#   '"I',
#   'heard',
#   'that',
#   'Being',
#   'the',
#   'one',
#   'to',
#   'circumcise',
#   'elephants'],
#  ['#@Joke',
#   'They',
#   'literally',
#   "can't",
#   'even."',
#   '\n',
#   '"A',
#   'Frenchman',
#   'walks',
#   'into'],
#  ['#@Joke',
#   'literally',
#   "can't",
#   'even."',
#   '\n',
#   '"A',
#   'Frenchman',
#   'walks',
#   'into',
#   'a'],
#  ['#@Joke',
#   "can't",
#   'even."',
#   '\n',
#   '"A',
#   'Frenchman',
#   'walks',
#   'into',
#   'a',
#   'library'],
#  ['#@Joke', 'rest', 'of', 'the', 'boys', 'all', 'agree', 'that', 'he', 'is"'],
#  ['#@Joke',
#   'in',
#   'the',
#   'Enterprise',
#   'Bathroom?',
#   'The',
#   "Captain's",
#   'Log."',
#   '\n',
#   '"PSA:'],
#  ['#@Joke',
#   'the',
#   'Enterprise',
#   'Bathroom?',
#   'The',
#   "Captain's",
#   'Log."',
#   '\n',
#   '"PSA:',
#   'If'],
#  ['#@Joke',
#   'Enterprise',
#   'Bathroom?',
#   'The',
#   "Captain's",
#   'Log."',
#   '\n',
#   '"PSA:',
#   'If',
#   "you've"],
#  ['#@Joke',
#   'Bathroom?',
#   'The',
#   "Captain's",
#   'Log."',
#   '\n',
#   '"PSA:',
#   'If',
#   "you've",
#   'got'],
#  ['#@Joke',
#   'The',
#   "Captain's",
#   'Log."',
#   '\n',
#   '"PSA:',
#   'If',
#   "you've",
#   'got',
#   'an'],
#  ['#@Joke',
#   "Captain's",
#   'Log."',
#   '\n',
#   '"PSA:',
#   'If',
#   "you've",
#   'got',
#   'an',
#   'Islamic'],
#  ['#@Joke', 'work', 'here', 'C:', 'I', 'know', 'ME:', 'It', 'should', 'be'],
#  ['#@Joke', 'here', 'C:', 'I', 'know', 'ME:', 'It', 'should', 'be', 'called'],
#  ['#@Joke',
#   'C:',
#   'I',
#   'know',
#   'ME:',
#   'It',
#   'should',
#   'be',
#   'called',
#   'Babies'],
#  ['#@Joke',
#   'I',
#   'know',
#   'ME:',
#   'It',
#   'should',
#   'be',
#   'called',
#   'Babies',
#   'Were'],
#  ['#@Joke',
#   'know',
#   'ME:',
#   'It',
#   'should',
#   'be',
#   'called',
#   'Babies',
#   'Were',
#   'US'],
#  ['#@Joke',
#   'ME:',
#   'It',
#   'should',
#   'be',
#   'called',
#   'Babies',
#   'Were',
#   'US',
#   'C:'],
#  ['#@Joke',
#   'It',
#   'should',
#   'be',
#   'called',
#   'Babies',
#   'Were',
#   'US',
#   'C:',
#   '...'],
#  ['#@Joke',
#   'should',
#   'be',
#   'called',
#   'Babies',
#   'Were',
#   'US',
#   'C:',
#   '...',
#   'ME:'],
#  ['#@Joke', 'be', 'called', 'Babies', 'Were', 'US', 'C:', '...', 'ME:', 'Get'],
#  ['#@Joke', 'called', 'Babies', 'Were', 'US', 'C:', '...', 'ME:', 'Get', 'me'],
#  ['#@Joke', 'Babies', 'Were', 'US', 'C:', '...', 'ME:', 'Get', 'me', 'your'],
#  ['#@Joke', 'Were', 'US', 'C:', '...', 'ME:', 'Get', 'me', 'your', 'manager"'],
#  ['#@Joke', 'US', 'C:', '...', 'ME:', 'Get', 'me', 'your', 'manager"', '\n'],
#  ['#@Joke', 'C:', '...', 'ME:', 'Get', 'me', 'your', 'manager"', '\n', '"A'],
#  ['#@Joke', '...', 'ME:', 'Get', 'me', 'your', 'manager"', '\n', '"A', 'girl'],
#  ['#@Joke',
#   'ME:',
#   'Get',
#   'me',
#   'your',
#   'manager"',
#   '\n',
#   '"A',
#   'girl',
#   'grabbed'],
#  ['#@Joke',
#   'Get',
#   'me',
#   'your',
#   'manager"',
#   '\n',
#   '"A',
#   'girl',
#   'grabbed',
#   'my'],
#  ['#@Joke',
#   'me',
#   'your',
#   'manager"',
#   '\n',
#   '"A',
#   'girl',
#   'grabbed',
#   'my',
#   'cock'],
#  ['#@Joke',
#   'your',
#   'manager"',
#   '\n',
#   '"A',
#   'girl',
#   'grabbed',
#   'my',
#   'cock',
#   'and'],
#  ['#@Joke',
#   'manager"',
#   '\n',
#   '"A',
#   'girl',
#   'grabbed',
#   'my',
#   'cock',
#   'and',
#   'said,'],
#  ['#@Joke',
#   '\n',
#   '"A',
#   'girl',
#   'grabbed',
#   'my',
#   'cock',
#   'and',
#   'said,',
#   '""Wow!'],
#  ['#@Joke', 'e', 't', 'i', 'c', 'a', 'l', 'l', 'y', '-'],
#  ['#@Joke', 't', 'i', 'c', 'a', 'l', 'l', 'y', '-', 'would'],
#  ['#@Joke', 'i', 'c', 'a', 'l', 'l', 'y', '-', 'would', 'I'],
#  ['#@Joke', 'c', 'a', 'l', 'l', 'y', '-', 'would', 'I', 'still'],
#  ['#@Joke', 'a', 'l', 'l', 'y', '-', 'would', 'I', 'still', 'get'],
#  ['#@Joke', 'l', 'l', 'y', '-', 'would', 'I', 'still', 'get', 'a'],
#  ['#@Joke', 'l', 'y', '-', 'would', 'I', 'still', 'get', 'a', 'carpool'],
#  ['#@Joke', 'y', '-', 'would', 'I', 'still', 'get', 'a', 'carpool', 'lane'],
#  ['#@Joke',
#   '-',
#   'would',
#   'I',
#   'still',
#   'get',
#   'a',
#   'carpool',
#   'lane',
#   'ticket'],
#  ['#@Joke',
#   'would',
#   'I',
#   'still',
#   'get',
#   'a',
#   'carpool',
#   'lane',
#   'ticket',
#   'if'],
#  ['#@Joke', 'a', 'body', 'in', 'the', 'trunk"', '\n', '"An', 'apple', 'a'],
#  ['#@Joke', 'body', 'in', 'the', 'trunk"', '\n', '"An', 'apple', 'a', 'day'],
#  ['#@Joke', 'in', 'the', 'trunk"', '\n', '"An', 'apple', 'a', 'day', 'keeps'],
#  ['#@Joke', 'the', 'trunk"', '\n', '"An', 'apple', 'a', 'day', 'keeps', 'my'],
#  ['#@Joke',
#   'trunk"',
#   '\n',
#   '"An',
#   'apple',
#   'a',
#   'day',
#   'keeps',
#   'my',
#   'fruit-picking'],
#  ['#@Joke',
#   '\n',
#   '"An',
#   'apple',
#   'a',
#   'day',
#   'keeps',
#   'my',
#   'fruit-picking',
#   'business'],
#  ['#@Joke',
#   '"An',
#   'apple',
#   'a',
#   'day',
#   'keeps',
#   'my',
#   'fruit-picking',
#   'business',
#   'trapped'],
#  ['#@Joke',
#   'apple',
#   'a',
#   'day',
#   'keeps',
#   'my',
#   'fruit-picking',
#   'business',
#   'trapped',
#   'in'],
#  ['#@Joke',
#   'a',
#   'day',
#   'keeps',
#   'my',
#   'fruit-picking',
#   'business',
#   'trapped',
#   'in',
#   'bankruptcy."'],
#  ['#@Joke',
#   'day',
#   'keeps',
#   'my',
#   'fruit-picking',
#   'business',
#   'trapped',
#   'in',
#   'bankruptcy."',
#   '\n'],
#  ['#@Joke',
#   'keeps',
#   'my',
#   'fruit-picking',
#   'business',
#   'trapped',
#   'in',
#   'bankruptcy."',
#   '\n',
#   '"What\'s'],
#  ['#@Joke',
#   'my',
#   'fruit-picking',
#   'business',
#   'trapped',
#   'in',
#   'bankruptcy."',
#   '\n',
#   '"What\'s',
#   'a'],
#  ['#@Joke',
#   'fruit-picking',
#   'business',
#   'trapped',
#   'in',
#   'bankruptcy."',
#   '\n',
#   '"What\'s',
#   'a',
#   "dinosaur's"],
#  ['#@Joke',
#   'business',
#   'trapped',
#   'in',
#   'bankruptcy."',
#   '\n',
#   '"What\'s',
#   'a',
#   "dinosaur's",
#   'least'],
#  ['#@Joke',
#   'trapped',
#   'in',
#   'bankruptcy."',
#   '\n',
#   '"What\'s',
#   'a',
#   "dinosaur's",
#   'least',
#   'favorite'],
#  ['#@Joke',
#   'in',
#   'bankruptcy."',
#   '\n',
#   '"What\'s',
#   'a',
#   "dinosaur's",
#   'least',
#   'favorite',
#   'reindeer?'],
#  ['#@Joke',
#   'next',
#   'door,',
#   'but',
#   'eventually',
#   'we',
#   'drifted',
#   'apart."',
#   '\n',
#   '"Donald'],
#  ['#@Joke',
#   'door,',
#   'but',
#   'eventually',
#   'we',
#   'drifted',
#   'apart."',
#   '\n',
#   '"Donald',
#   'Trump'],
#  ['#@Joke',
#   'but',
#   'eventually',
#   'we',
#   'drifted',
#   'apart."',
#   '\n',
#   '"Donald',
#   'Trump',
#   'Does'],
#  ['#@Joke',
#   'eventually',
#   'we',
#   'drifted',
#   'apart."',
#   '\n',
#   '"Donald',
#   'Trump',
#   'Does',
#   'this'],
#  ['#@Joke',
#   'to',
#   'my',
#   'self-aware',
#   'friends,',
#   'you',
#   'know',
#   'who',
#   'you',
#   'are"'],
#  ['#@Joke',
#   'my',
#   'self-aware',
#   'friends,',
#   'you',
#   'know',
#   'who',
#   'you',
#   'are"',
#   '\n'],
#  ['#@Joke',
#   'self-aware',
#   'friends,',
#   'you',
#   'know',
#   'who',
#   'you',
#   'are"',
#   '\n',
#   '"Why'],
#  ['#@Joke',
#   'friends,',
#   'you',
#   'know',
#   'who',
#   'you',
#   'are"',
#   '\n',
#   '"Why',
#   'does'],
#  ['#@Joke',
#   'friend',
#   'say',
#   'when',
#   'he',
#   'comes',
#   'to',
#   'visit?',
#   'Your',
#   'house'],
#  ['#@Joke',
#   'say',
#   'when',
#   'he',
#   'comes',
#   'to',
#   'visit?',
#   'Your',
#   'house',
#   'is'],
#  ['#@Joke',
#   '"There',
#   'are',
#   'two',
#   'types',
#   'of',
#   'people',
#   'in',
#   'life...',
#   'Those'],
#  ['#@Joke',
#   'up',
#   'at',
#   'Disney',
#   'headquarters',
#   'uninvited',
#   'I',
#   'said',
#   'I',
#   'was'],
#  ['#@Joke',
#   'at',
#   'Disney',
#   'headquarters',
#   'uninvited',
#   'I',
#   'said',
#   'I',
#   'was',
#   'there'],
#  ['#@Joke',
#   'Disney',
#   'headquarters',
#   'uninvited',
#   'I',
#   'said',
#   'I',
#   'was',
#   'there',
#   'for'],
#  ['#@Joke',
#   'headquarters',
#   'uninvited',
#   'I',
#   'said',
#   'I',
#   'was',
#   'there',
#   'for',
#   'a'],
#  ['#@Joke',
#   'uninvited',
#   'I',
#   'said',
#   'I',
#   'was',
#   'there',
#   'for',
#   'a',
#   'Rogue'],
#  ['#@Joke', 'I', 'said', 'I', 'was', 'there', 'for', 'a', 'Rogue', 'One'],
#  ['#@Joke',
#   'Jesus!',
#   'Reply',
#   'if',
#   "you'd",
#   'like',
#   'to',
#   'meet',
#   'him!"',
#   '\n'],
#  ['#@Joke',
#   'they',
#   'going',
#   'to',
#   'drug',
#   'test',
#   'the',
#   'audience',
#   'of',
#   '""The'],
#  ['#@Joke',
#   'going',
#   'to',
#   'drug',
#   'test',
#   'the',
#   'audience',
#   'of',
#   '""The',
#   'Price'],
#  ['#@Joke',
#   'to',
#   'drug',
#   'test',
#   'the',
#   'audience',
#   'of',
#   '""The',
#   'Price',
#   'Is'],
#  ['#@Joke',
#   'drug',
#   'test',
#   'the',
#   'audience',
#   'of',
#   '""The',
#   'Price',
#   'Is',
#   'Right.""?'],
#  ['#@Joke',
#   'test',
#   'the',
#   'audience',
#   'of',
#   '""The',
#   'Price',
#   'Is',
#   'Right.""?',
#   'No'],
#  ['#@Joke',
#   'the',
#   'audience',
#   'of',
#   '""The',
#   'Price',
#   'Is',
#   'Right.""?',
#   'No',
#   'one'],
#  ['#@Joke',
#   "doesn't",
#   'Hitler',
#   'go',
#   'ski?',
#   'Cause',
#   "he's",
#   'blown',
#   'his',
#   'fucking'],
#  ['#@Joke',
#   'Hitler',
#   'go',
#   'ski?',
#   'Cause',
#   "he's",
#   'blown',
#   'his',
#   'fucking',
#   'head."'],
#  ['#@Joke',
#   'Because',
#   'their',
#   'hands',
#   'are',
#   'always',
#   'in',
#   'someone',
#   'else\'s!"',
#   '\n'],
#  ['#@Joke',
#   'their',
#   'hands',
#   'are',
#   'always',
#   'in',
#   'someone',
#   'else\'s!"',
#   '\n',
#   '"Why'],
#  ['#@Joke',
#   'hands',
#   'are',
#   'always',
#   'in',
#   'someone',
#   'else\'s!"',
#   '\n',
#   '"Why',
#   'does'],
#  ['#@Joke',
#   'are',
#   'always',
#   'in',
#   'someone',
#   'else\'s!"',
#   '\n',
#   '"Why',
#   'does',
#   'Helen'],
#  ['#@Joke',
#   'always',
#   'in',
#   'someone',
#   'else\'s!"',
#   '\n',
#   '"Why',
#   'does',
#   'Helen',
#   'Keller'],
#  ['#@Joke',
#   'in',
#   'someone',
#   'else\'s!"',
#   '\n',
#   '"Why',
#   'does',
#   'Helen',
#   'Keller',
#   'wear'],
#  ['#@Joke',
#   'someone',
#   'else\'s!"',
#   '\n',
#   '"Why',
#   'does',
#   'Helen',
#   'Keller',
#   'wear',
#   'tight'],
#  ['#@Joke',
#   'else\'s!"',
#   '\n',
#   '"Why',
#   'does',
#   'Helen',
#   'Keller',
#   'wear',
#   'tight',
#   'jeans?'],
#  ['#@Joke',
#   '\n',
#   '"Why',
#   'does',
#   'Helen',
#   'Keller',
#   'wear',
#   'tight',
#   'jeans?',
#   'So'],
#  ['#@Joke',
#   '"Go',
#   'to',
#   'racist',
#   'joke,',
#   "what's",
#   'yours?',
#   'Two',
#   'unemployed',
#   'Irishmen'],
#  ['#@Joke',
#   'to',
#   'racist',
#   'joke,',
#   "what's",
#   'yours?',
#   'Two',
#   'unemployed',
#   'Irishmen',
#   'walk'],
#  ['#@Joke',
#   'bacon?',
#   'Kermit',
#   'the',
#   "frog's",
#   'finger"',
#   '\n',
#   '"Why',
#   'were',
#   'there'],
#  ['#@Joke',
#   'Kermit',
#   'the',
#   "frog's",
#   'finger"',
#   '\n',
#   '"Why',
#   'were',
#   'there',
#   'only'],
#  ['#@Joke',
#   'list-making',
#   'called',
#   'Schindlr"',
#   '\n',
#   '"My',
#   'favorite',
#   'kind',
#   'of',
#   'math'],
#  ['#@Joke',
#   'called',
#   'Schindlr"',
#   '\n',
#   '"My',
#   'favorite',
#   'kind',
#   'of',
#   'math',
#   'is'],
#  ['#@Joke',
#   'Schindlr"',
#   '\n',
#   '"My',
#   'favorite',
#   'kind',
#   'of',
#   'math',
#   'is',
#   'adding'],
#  ['#@Joke',
#   '\n',
#   '"My',
#   'favorite',
#   'kind',
#   'of',
#   'math',
#   'is',
#   'adding',
#   'insult'],
#  ['#@Joke',
#   '"My',
#   'favorite',
#   'kind',
#   'of',
#   'math',
#   'is',
#   'adding',
#   'insult',
#   'to'],
#  ['#@Joke',
#   '"I',
#   'like',
#   'Tuesday',
#   'simply',
#   'because',
#   'it',
#   'is',
#   'literally',
#   'the'],
#  ['#@Joke',
#   'like',
#   'Tuesday',
#   'simply',
#   'because',
#   'it',
#   'is',
#   'literally',
#   'the',
#   'furthest'],
#  ['#@Joke',
#   'Tuesday',
#   'simply',
#   'because',
#   'it',
#   'is',
#   'literally',
#   'the',
#   'furthest',
#   'from'],
#  ['#@Joke',
#   'simply',
#   'because',
#   'it',
#   'is',
#   'literally',
#   'the',
#   'furthest',
#   'from',
#   'next'],
#  ['#@Joke',
#   'because',
#   'it',
#   'is',
#   'literally',
#   'the',
#   'furthest',
#   'from',
#   'next',
#   'Monday'],
#  ['#@Joke',
#   'it',
#   'is',
#   'literally',
#   'the',
#   'furthest',
#   'from',
#   'next',
#   'Monday',
#   'I'],
#  ['#@Joke',
#   'is',
#   'literally',
#   'the',
#   'furthest',
#   'from',
#   'next',
#   'Monday',
#   'I',
#   'can'],
#  ['#@Joke',
#   'literally',
#   'the',
#   'furthest',
#   'from',
#   'next',
#   'Monday',
#   'I',
#   'can',
#   'possibly'],
#  ['#@Joke',
#   '\n',
#   '"I',
#   'tried',
#   'googling',
#   'Wiz',
#   'Khalifa',
#   '...',
#   'But',
#   'all'],
#  ['#@Joke',
#   '"I',
#   'tried',
#   'googling',
#   'Wiz',
#   'Khalifa',
#   '...',
#   'But',
#   'all',
#   'I'],
#  ['#@Joke',
#   'tried',
#   'googling',
#   'Wiz',
#   'Khalifa',
#   '...',
#   'But',
#   'all',
#   'I',
#   'found'],
#  ['#@Joke',
#   'animals.',
#   'May',
#   'I',
#   'interest',
#   'you',
#   'in',
#   'a',
#   'hyphen',
#   'or'],
#  ['#@Joke',
#   '\n',
#   '"Who',
#   'are',
#   'the',
#   '3',
#   'most',
#   'famous',
#   'black',
#   'women?'],
#  ['#@Joke',
#   '"Who',
#   'are',
#   'the',
#   '3',
#   'most',
#   'famous',
#   'black',
#   'women?',
#   '1.'],
#  ['#@Joke',
#   'are',
#   'the',
#   '3',
#   'most',
#   'famous',
#   'black',
#   'women?',
#   '1.',
#   'Oprah'],
#  ['#@Joke',
#   '"Why',
#   'does',
#   'Darkwing',
#   'Duck',
#   'wear',
#   'a',
#   'mask?',
#   'You',
#   'are'],
#  ['#@Joke',
#   'does',
#   'Darkwing',
#   'Duck',
#   'wear',
#   'a',
#   'mask?',
#   'You',
#   'are',
#   'a'],
#  ['#@Joke',
#   'Darkwing',
#   'Duck',
#   'wear',
#   'a',
#   'mask?',
#   'You',
#   'are',
#   'a',
#   'duck.'],
#  ['#@Joke', 'and', 'no', 'legs,', 'lying', 'in', 'a', 'ditch?', 'Phil"', '\n'],
#  ['#@Joke',
#   'no',
#   'legs,',
#   'lying',
#   'in',
#   'a',
#   'ditch?',
#   'Phil"',
#   '\n',
#   '"Get'],
#  ['#@Joke', 'legs,', 'lying', 'in', 'a', 'ditch?', 'Phil"', '\n', '"Get', 'a'],
#  ['#@Joke', 'lying', 'in', 'a', 'ditch?', 'Phil"', '\n', '"Get', 'a', 'big'],
#  ['#@Joke', 'in', 'a', 'ditch?', 'Phil"', '\n', '"Get', 'a', 'big', 'metal'],
#  ['#@Joke', 'a', 'ditch?', 'Phil"', '\n', '"Get', 'a', 'big', 'metal', 'box,'],
#  ['#@Joke',
#   'ditch?',
#   'Phil"',
#   '\n',
#   '"Get',
#   'a',
#   'big',
#   'metal',
#   'box,',
#   'label'],
#  ['#@Joke', 'Phil"', '\n', '"Get', 'a', 'big', 'metal', 'box,', 'label', 'it'],
#  ['#@Joke',
#   '\n',
#   '"Get',
#   'a',
#   'big',
#   'metal',
#   'box,',
#   'label',
#   'it',
#   '""TIME'],
#  ['#@Joke',
#   '"Get',
#   'a',
#   'big',
#   'metal',
#   'box,',
#   'label',
#   'it',
#   '""TIME',
#   'CAPSULE""'],
#  ['#@Joke',
#   'a',
#   'big',
#   'metal',
#   'box,',
#   'label',
#   'it',
#   '""TIME',
#   'CAPSULE""',
#   'and'],
#  ['#@Joke',
#   'big',
#   'metal',
#   'box,',
#   'label',
#   'it',
#   '""TIME',
#   'CAPSULE""',
#   'and',
#   'take'],
#  ['#@Joke',
#   'metal',
#   'box,',
#   'label',
#   'it',
#   '""TIME',
#   'CAPSULE""',
#   'and',
#   'take',
#   'a'],
#  ['#@Joke',
#   'box,',
#   'label',
#   'it',
#   '""TIME',
#   'CAPSULE""',
#   'and',
#   'take',
#   'a',
#   'big'],
#  ['#@Joke',
#   'what',
#   '2011',
#   'was',
#   'like."',
#   '\n',
#   '"I\'m',
#   'a',
#   'terrible',
#   'singer,'],
#  ['#@Joke',
#   '2011',
#   'was',
#   'like."',
#   '\n',
#   '"I\'m',
#   'a',
#   'terrible',
#   'singer,',
#   'I'],
#  ['#@Joke',
#   'was',
#   'like."',
#   '\n',
#   '"I\'m',
#   'a',
#   'terrible',
#   'singer,',
#   'I',
#   'have'],
#  ['#@Joke',
#   'blood"',
#   '\n',
#   '"What',
#   'do',
#   'you',
#   'call',
#   'an',
#   'iPhone',
#   '6S'],
#  ['#@Joke', '\n', '"What', 'do', 'you', 'call', 'an', 'iPhone', '6S', 'that'],
#  ['#@Joke', '"What', 'do', 'you', 'call', 'an', 'iPhone', '6S', 'that', 'ran'],
#  ['#@Joke', 'do', 'you', 'call', 'an', 'iPhone', '6S', 'that', 'ran', 'out'],
#  ['#@Joke',
#   'you',
#   'call',
#   'an',
#   'iPhone',
#   '6S',
#   'that',
#   'ran',
#   'out',
#   'memory'],
#  ...]

# %%
next_words
# Out:
# ['you.',
#  'Good',
#  'for',
#  'swapping',
#  'my',
#  'tampax',
#  'for',
#  '"Two',
#  'Ken',
#  'comes',
#  'in',
#  '\n',
#  '"Did',
#  'you',
#  'He',
#  'a',
#  'essentials',
#  'but',
#  'short',
#  'enough',
#  'to',
#  'hold',
#  'your',
#  'attention!"',
#  '\n',
#  '"Thanksgiving',
#  'joke',
#  'What',
#  'does',
#  'Miley',
#  'drugs.',
#  '-Adam',
#  'Zopf',
#  'I',
#  'guess',
#  "I'll",
#  'deal',
#  'with',
#  'one',
#  'barstool?',
#  'Flip',
#  'and',
#  'pretend',
#  'I',
#  'was',
#  'pretty',
#  'that',
#  'day."',
#  '\n',
#  '"Which',
#  'gospel',
#  'capture',
#  'a',
#  '\n',
#  '"Coming',
#  'on',
#  'valentines',
#  'day.',
#  'button',
#  'able',
#  'to',
#  'get',
#  'that',
#  'only',
#  'Hillary,',
#  'you',
#  'know',
#  'of.',
#  'it',
#  'really',
#  'turns',
#  'me',
#  'on',
#  'when',
#  'your',
#  'poop',
#  '\n',
#  'seat."',
#  '\n',
#  '"What',
#  'did',
#  'the',
#  '-Guy',
#  'who',
#  'invented',
#  'shovels"',
#  '\n',
#  '"How',
#  'to',
#  'keep',
#  'the',
#  "They're",
#  'both',
#  'ft',
#  '"I',
#  'be',
#  'not',
#  'be',
#  'a',
#  'smaller',
#  'and',
#  'TRUMP!"',
#  '\n',
#  'just',
#  'Saiyan."',
#  '\n',
#  '"My',
#  'ex-wife',
#  'a',
#  'bagel',
#  'was',
#  'like',
#  'eating',
#  '5',
#  'slices',
#  'a',
#  'three-humped',
#  'Jay-Z',
#  'having',
#  'a',
#  'leg',
#  'transplant?',
#  'A',
#  'hip-hop',
#  'They',
#  'heavier',
#  'they',
#  'are,',
#  'the',
#  'easier',
#  'they',
#  'are',
#  'to',
#  'pick',
#  'up."',
#  'a',
#  'ba-""',
#  '""A',
#  'what?""',
#  'Big',
#  'Baby',
#  'from',
#  'Toy',
#  'Story',
#  '3',
#  'hovers',
#  'over',
#  'me,',
#  'sawed-off',
#  'shotgun',
#  'in',
#  'hand.',
#  '""A',
#  'bagel.',
#  'I',
#  'HATE',
#  'carbs."""',
#  '\n',
#  '"What\'s',
#  'the',
#  'difference',
#  'Donald',
#  'Trump',
#  '"My',
#  'doctor',
#  'had',
#  'to',
#  'put',
#  'me',
#  'on',
#  'a',
#  'new',
#  'medication',
#  "that's",
#  'supposed',
#  'to',
#  'help',
#  'lower',
#  'the',
#  'likes',
#  'you"',
#  '\n',
#  '"Q:',
#  "What's",
#  'the',
#  'difference',
#  'between',
#  'a',
#  'blonde',
#  'and',
#  'a',
#  'supermarket',
#  'trolley?',
#  'A:',
#  'The',
#  'supermarket',
#  'trolley',
#  'has',
#  'a',
#  'mind',
#  'of',
#  'you',
#  'are',
#  'in',
#  'a',
#  'Mexican',
#  'jail."',
#  'this',
#  'person',
#  '""competitive""',
#  'do',
#  'Chad',
#  'Steve',
#  'Harvey',
#  'To',
#  'go',
#  'to',
#  'the',
#  'gay',
#  'put',
#  'a',
#  'quick',
#  'and',
#  'easy',
#  'the',
#  'red',
#  'card',
#  'for',
#  'a',
#  'loud',
#  'fart',
#  '...',
#  'even',
#  'Aids!',
#  'It',
#  'requires',
#  'having',
#  'a',
#  'Magic',
#  'simply',
#  'preferred',
#  'toast,""',
#  'I',
#  'a',
#  'dollar',
#  'in',
#  'and',
#  "I'm",
#  'a',
#  'little',
#  'bit',
#  'closer',
#  'to',
#  'freedom.',
#  '*puts',
#  'in',
#  'me',
#  'into',
#  'a',
#  'parrot.""',
#  'you',
#  'plunger',
#  'in',
#  'the',
#  "won't",
#  'tell',
#  'earthquake',
#  'is',
#  'into',
#  'great',
#  'detail',
#  'a',
#  'group',
#  'of',
#  'adults',
#  'saying',
#  'the',
#  'word',
#  '""bae"""',
#  '\n',
#  '"Stealing',
#  'my',
#  'little',
#  "brother's",
#  '(fellow',
#  'Redditor)',
#  "that's",
#  'more',
#  'than',
#  'The',
#  'delivery."',
#  '\n',
#  '"I',
#  'melee',
#  'weapon?',
#  'A',
#  'no',
#  'thank',
#  'you.',
#  'I',
#  'already',
#  'have',
#  'one"',
#  'spend',
#  'her"',
#  '\n',
#  '"Why',
#  "can't",
#  'a',
#  'bike',
#  'stand',
#  'on',
#  '""Hey,',
#  'can',
#  'own."',
#  '\n',
#  '"Why',
#  'are',
#  'hillbilly',
#  'murders',
#  'hard',
#  'Merkel.',
#  'would',
#  'the',
#  'and',
#  'open',
#  'fools!',
#  'Got',
#  'ya!!"',
#  '\n',
#  '"Right',
#  'now',
#  'to',
#  'ask',
#  'me',
#  'my',
#  'name,',
#  'before',
#  'they',
#  'fuck',
#  'me."',
#  '\n',
#  '"What',
#  'do',
#  'you',
#  'to',
#  'hospital',
#  'for',
#  'the',
#  'needle',
#  'do',
#  'you',
#  'call',
#  'last',
#  '30',
#  'seconds."',
#  'spanked',
#  'cat?""',
#  'Pretty',
#  'sure',
#  'it',
#  'was',
#  'a',
#  'for',
#  'the',
#  'day',
#  'when',
#  'a',
#  'to',
#  'a',
#  'police',
#  'officer."',
#  '\n',
#  '"Some',
#  'people',
#  'say',
#  'Glenn',
#  'Frey',
#  'got',
#  'pneumonia',
#  'their',
#  'e-mail',
#  'address,',
#  'the',
#  'less',
#  'I',
#  'respect',
#  'them?"',
#  '\n',
#  '"What',
#  'does',
#  'the',
#  'living',
#  'room?',
#  'You',
#  'made',
#  'the',
#  'heavy',
#  'stress?',
#  'They',
#  'have',
#  'a',
#  'lot',
#  'are',
#  'Native',
#  'Americans',
#  'rain."',
#  '\n',
#  '"My',
#  'ex-girlfriend',
#  'was',
#  'a',
#  'slut.',
#  'She',
#  'bust',
#  'more',
#  'breakup,',
#  'was',
#  'furious',
#  'when',
#  'I',
#  'blew',
#  'eyes"',
#  '\n',
#  '"FOR',
#  'SALE:',
#  'bar...',
#  'Who',
#  'talks',
#  'more?"',
#  '\n',
#  'Stephen',
#  '\n',
#  '"My',
#  'terrible',
#  'Baskin',
#  '""That',
#  'sounds',
#  'like',
#  'a',
#  'good',
#  'deal!"""',
#  'so',
#  'good',
#  'it',
#  'helps',
#  'a',
#  'little',
#  'old',
#  'the',
#  'breakfast?',
#  'Luftwaffles"',
#  'been',
#  'its',
#  'other',
#  'hand',
#  'to',
#  'the',
#  'floor."',
#  '\n',
#  '"What',
#  'is',
#  'the',
#  'favorite',
#  'food',
#  'joint',
#  'manning',
#  '^--',
#  'gone,',
#  'without',
#  'a',
#  'tres."',
#  '\n',
#  'thought.',
#  'It',
#  'looks',
#  'exactly',
#  'like',
#  'mine...',
#  'but',
#  'that',
#  "can't",
#  'Well',
#  "it's",
#  'true,',
#  'you',
#  'are',
#  'what',
#  'you',
#  'eat."',
#  '\n',
#  '"They',
#  'just',
#  'was',
#  'premieres',
#  'tonight',
#  '(8/7',
#  'out',
#  'of',
#  'Dan',
#  'Aykroyd."""',
#  '\n',
#  '"I',
#  'complained',
#  'to',
#  'my',
#  'wife',
#  'that',
#  'I',
#  '\n',
#  '"I',
#  'overheard',
#  'two',
#  'female',
#  'coworkers',
#  'say',
#  'there',
#  'was',
#  'a',
#  'creepy',
#  'dude',
#  'listening',
#  'to',
#  'their',
#  'conversation."',
#  '\n',
#  '"What',
#  'do',
#  'you',
#  'call',
#  'what',
#  'the',
#  'opposite',
#  'of',
#  'in',
#  'put',
#  'car',
#  'accident.',
#  'Those',
#  'same',
#  'in.',
#  'Well',
#  'played,',
#  'on',
#  'Pandora',
#  'for',
#  'between',
#  'two',
#  'Rabbis...',
#  'But',
#  'they',
#  'were',
#  'just',
#  'arguing',
#  'semitics."',
#  '\n',
#  '"Pavlov\'s',
#  'doorbell',
#  'my',
#  'dad',
#  'got',
#  'me',
#  '"What',
#  'is',
#  'the',
#  'best',
#  'thing',
#  'about',
#  'a',
#  'clock',
#  'call',
#  'seen',
#  'those',
#  'Oh,,',
#  'I',
#  'think',
#  "she'll",
#  'of',
#  'Twitter',
#  'for',
#  'people',
#  'who',
#  'spell',
#  'things',
#  'like',
#  'rappers.',
#  'They',
#  '*splat',
#  "IT'S",
#  'AWFUL!',
#  '*splat',
#  'SO',
#  '\n',
#  '"Where',
#  'do',
#  'you',
#  'find',
#  'One',
#  'at',
#  'a',
#  'gay',
#  'magazine.',
#  "I'm",
#  'a',
#  'poofreader."',
#  '\n',
#  '"No',
#  'one',
#  'is',
#  'more',
#  'unnecessarily',
#  'confident',
#  'than',
#  'a',
#  'argue',
#  'about',
#  'what',
#  'file',
#  'of',
#  'a',
#  '""Shit,',
#  'some',
#  'asshole',
#  'took',
#  'my',
#  'pen!"""',
#  '\n',
#  '"how',
#  'many',
#  'people',
#  'does',
#  'my',
#  'coffee...',
#  'I',
#  "don't",
#  'fucking',
#  'like',
#  'coffee."',
#  '\n',
#  'more',
#  'about',
#  'SPACE',
#  'than',
#  'we',
#  'geologers',
#  'this',
#  'a',
#  'there?',
#  'Benjamin.',
#  'Benjamin',
#  'Who?',
#  'Yes,',
#  'Benjamin',
#  'Netanya',
#  'that',
#  'Wait,',
#  "Don't",
#  'Tell',
#  'Me)"',
#  '\n',
#  'working.',
#  'I',
#  'call',
#  '\n',
#  '"I',
#  'just',
#  'was',
#  'da',
#  'bomb.',
#  'It',
#  'Kiss',
#  'can',
#  'make',
#  'my',
#  'whole',
#  'day...',
#  'But',
#  'anal',
#  'a',
#  'homeless',
#  'guy',
#  'babbling',
#  'about',
#  'in',
#  'a',
#  'con-artists',
#  'kind',
#  'here"".',
#  'The',
#  'me',
#  '""When',
#  'both',
#  'watch',
#  'does',
#  'little',
#  'sally',
#  '\n',
#  '"""Oh',
#  'smells',
#  'be',
#  'a',
#  'their',
#  'balls"',
#  '\n',
#  'is',
#  'so',
#  'two',
#  'people,',
#  'living',
#  'or',
#  'dead,',
#  'who',
#  'would',
#  'T',
#  'the',
#  'gates',
#  '\n',
#  'find',
#  'their',
#  'way',
#  'out."',
#  '\n',
#  '"[At',
#  'the',
#  "coroners'",
#  'to',
#  'identify',
#  'a',
#  'body]',
#  'Me:',
#  'and',
#  'your',
#  '"I',
#  'can',
#  'see',
#  "you're",
#  'upset.',
#  'Maybe',
#  'you',
#  'should',
#  'post',
#  'more',
#  'of',
#  'you',
#  'guys',
#  'are',
#  'looking',
#  'for',
#  'best',
#  '"What\'s',
#  'the',
#  'vampire?',
#  'Dracowla!"',
#  'that',
#  'masturbation',
#  'is',
#  'life',
#  'threatening',
#  'Many',
#  'men',
#  'have',
#  'died',
#  'after',
#  'having',
#  'a',
#  'stroke"',
#  'blonde',
#  'die',
#  'ice-fishing?',
#  'A.',
#  'She',
#  'those',
#  'Black',
#  'and',
#  'White',
#  'movies',
#  'where',
#  'no',
#  "i'm",
#  'pretty',
#  'hot',
#  'but',
#  'Celebrating',
#  'the',
#  'existence',
#  'of',
#  'their',
#  'mothers.',
#  'Alien',
#  '1:',
#  'I',
#  'ate',
#  'my',
#  'mother.',
#  'Alien',
#  '2:',
#  'As',
#  'did',
#  'Mr.',
#  'Bus',
#  'Driver."',
#  '\n',
#  '"What',
#  'Did',
#  'the',
#  'Upvote',
#  'a',
#  'Upvote"',
#  'My',
#  'friend',
#  'use',
#  'whatever',
#  'printer',
#  'you',
#  'want"',
#  'woman',
#  'that',
#  "you're",
#  'it',
#  'from."',
#  '\n',
#  '"I',
#  'like',
#  'my',
#  'chicken',
#  'his',
#  '\n',
#  '"They',
#  'have',
#  'arrived',
#  '-',
#  'lab',
#  'rat',
#  '"Fun',
#  'serve',
#  'your',
#  'kind',
#  'here.""',
#  'could',
#  'introduce',
#  'as',
#  'on',
#  'shuffle',
#  'want',
#  'more',
#  'than',
#  'a',
#  'hug."',
#  '\n',
#  '"I',
#  'heard',
#  'that',
#  'Being',
#  'the',
#  'one',
#  'to',
#  'circumcise',
#  'elephants',
#  "doesn't",
#  'a',
#  'library',
#  'and',
#  '\n',
#  'If',
#  "you've",
#  'got',
#  'an',
#  'Islamic',
#  'dog...',
#  'called',
#  'Babies',
#  'Were',
#  'US',
#  'C:',
#  '...',
#  'ME:',
#  'Get',
#  'me',
#  'your',
#  'manager"',
#  '\n',
#  '"A',
#  'girl',
#  'grabbed',
#  'my',
#  'cock',
#  'and',
#  'said,',
#  '""Wow!',
#  'Your',
#  'would',
#  'I',
#  'still',
#  'get',
#  'a',
#  'carpool',
#  'lane',
#  'ticket',
#  'if',
#  'I',
#  'day',
#  'keeps',
#  'my',
#  'fruit-picking',
#  'business',
#  'trapped',
#  'in',
#  'bankruptcy."',
#  '\n',
#  '"What\'s',
#  'a',
#  "dinosaur's",
#  'least',
#  'favorite',
#  'reindeer?',
#  'Comet!',
#  'Trump',
#  'Does',
#  'this',
#  'count',
#  '\n',
#  '"Why',
#  'does',
#  'it',
#  'is',
#  'quite',
#  'who',
#  'there',
#  'for',
#  'a',
#  'Rogue',
#  'One',
#  'cameo',
#  '"Prostitutes',
#  'Price',
#  'Is',
#  'Right.""?',
#  'No',
#  'one',
#  'should',
#  'head."',
#  '\n',
#  '"Why',
#  'does',
#  'Helen',
#  'Keller',
#  'wear',
#  'tight',
#  'jeans?',
#  'So',
#  'people',
#  'walk',
#  'past',
#  'only',
#  '49',
#  'is',
#  'adding',
#  'insult',
#  'to',
#  'injury."',
#  'furthest',
#  'from',
#  'next',
#  'Monday',
#  'I',
#  'can',
#  'possibly',
#  'be."',
#  'I',
#  'found',
#  'was',
#  'a',
#  '1.',
#  'Oprah',
#  '2.',
#  'a',
#  'duck.',
#  'No',
#  '"Get',
#  'a',
#  'big',
#  'metal',
#  'box,',
#  'label',
#  'it',
#  '""TIME',
#  'CAPSULE""',
#  'and',
#  'take',
#  'a',
#  'big',
#  'dump',
#  'I',
#  'have',
#  'two',
#  'that',
#  'ran',
#  'out',
#  'memory',
#  'space.',
#  ...]

# %%
#quote_NoTag_Sentences

# %%
# =================end of preprocesing ===============================

# %%
examples = "examples2.txt"
BATCH_SIZE =64
if not os.path.isdir('./checkpoints2/'):
    os.makedirs('./checkpoints2/')

# %%
def shuffle_and_split_training_set(sentences_original, next_original, percentage_test=10):
    # shuffle at unison
    print('Shuffling sentences')
    tmp_sentences = []
    tmp_next_word = []
    for i in np.random.permutation(len(sentences_original)):
        tmp_sentences.append(sentences_original[i])
        tmp_next_word.append(next_original[i])
    cut_index = int(len(sentences_original) * (1.-(percentage_test/100.)))
    x_train, x_test = tmp_sentences[:cut_index], tmp_sentences[cut_index:]
    y_train, y_test = tmp_next_word[:cut_index], tmp_next_word[cut_index:]
    print("Size of training set = %d" % len(x_train))
    print("Size of test set = %d" % len(y_test))
    return (x_train, y_train), (x_test, y_test)

# %%
# Data generator for fit and evaluate
def generator(sentence_list, next_word_list, batch_size):
    index = 0
    while True:
        x = np.zeros((batch_size, SEQUENCE_LEN, len(words)), dtype=np.bool)
        y = np.zeros((batch_size, len(words)), dtype=np.bool)
        for i in range(batch_size):
            for t, w in enumerate(sentence_list[index % len(sentence_list)]):
                x[i, t, word_indices[w]] = 1
            y[i, word_indices[next_word_list[index % len(sentence_list)]]] = 1
            index = index + 1
        yield x, y

# %%
len(words)
# Out:
# 17285

# %%
def get_model(dropout=0.2):
    print('Build model...')
    model = Sequential()
    model.add(Bidirectional(LSTM(128), input_shape=(SEQUENCE_LEN, len(words))))
    if dropout > 0:
        model.add(Dropout(dropout))
    model.add(Dense(len(words)))
    model.add(Activation('softmax'))
    return model

# %%
# Functions from keras-team/keras/blob/master/examples/lstm_text_generation.py
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    examples_file.write('\n----- Generating text after Epoch: %d\n' % epoch)
    # Randomly pick a seed sequence
    seed_index = np.random.randint(len(sentences+sentences_test))
    seed = (sentences+sentences_test)[seed_index]
    for diversity in [0.3, 0.4, 0.5, 0.6, 0.7]:
        sentence = seed
        examples_file.write('----- Diversity:' + str(diversity) + '\n')
        examples_file.write('----- Generating with seed:\n"' + ' '.join(sentence) + '"\n')
        examples_file.write(' '.join(sentence))
        for i in range(50):
            x_pred = np.zeros((1, SEQUENCE_LEN, len(words)))
            for t, word in enumerate(sentence):
                x_pred[0, t, word_indices[word]] = 1.
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_word = indices_word[next_index]
            sentence = sentence[1:]
            sentence.append(next_word)
            examples_file.write(" "+next_word)
        examples_file.write('\n')
    examples_file.write('='*80 + '\n')
    examples_file.flush()

# %%
  # x, y, x_test, y_test
(sentences, next_words), (sentences_test, next_words_test) = shuffle_and_split_training_set(
    sentences, next_words, 10
)
# Out:
# Shuffling sentences
# Size of training set = 11966
# Size of test set = 1330

# %%
model = get_model()
model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=['accuracy'])
print(model.summary())
# Out:
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_6 (Bidirection (None, 256)               17831936
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 17285)             4442245
# _________________________________________________________________
# activation_6 (Activation)    (None, 17285)             0
# =================================================================
# Total params: 22,274,181
# Trainable params: 22,274,181
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
file_path = "./checkpoints2/LSTM_try-epoch{epoch:03d}-words%d-sequence%d-minfreq%d-" \
                "loss{loss:.4f}-acc{acc:.4f}-val_loss{val_loss:.4f}-val_acc{val_acc:.4f}" % \
                (len(words), SEQUENCE_LEN, MIN_WORD_FREQUENCY)

# %%
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', save_best_only=True)
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)
early_stopping = EarlyStopping(monitor='val_acc', patience=5)
callbacks_list = [checkpoint, print_callback, early_stopping]

# %%
examples_file = open(examples, "w")
model.fit_generator(generator(sentences, next_words, BATCH_SIZE),
                    steps_per_epoch=int(len(sentences)/BATCH_SIZE) + 1,
                    epochs=100,
                    callbacks=callbacks_list,
                    validation_data=generator(sentences_test, next_words_test, BATCH_SIZE),
                    validation_steps=int(len(sentences_test)/BATCH_SIZE) + 1)
# Out:
# Epoch 1/100
#  459/1197 [==========>...................] - ETA: 8:07 - loss: 6.9850 - acc: 0.0390
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-8ebb8ac1cb4a> in <module>()
#       5                     callbacks=callbacks_list,
#       6                     validation_data=generator(sentences_test, next_words_test, BATCH_SIZE),
# ----> 7                     validation_steps=int(len(sentences_test)/BATCH_SIZE) + 1)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1413             use_multiprocessing=use_multiprocessing,
#    1414             shuffle=shuffle,
# -> 1415             initial_epoch=initial_epoch)
#    1416
#    1417     @interfaces.legacy_generator_methods_support
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     211                 outs = model.train_on_batch(x, y,
#     212                                             sample_weight=sample_weight,
# --> 213                                             class_weight=class_weight)
#     214
#     215                 outs = to_list(outs)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1213             ins = x + y + sample_weights
#    1214         self._make_train_function()
# -> 1215         outputs = self.train_function(ins)
#    1216         return unpack_singleton(outputs)
#    1217
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
from keras.models import load_model

model.save('my_model.h5')  # creates a HDF5 file 'my_model.h5'
#del model  # deletes the existing model

# returns a compiled model
# identical to the previous one
#model = load_model('my_model.h5')

# %%
def predict_nex(sentence,diversity):
    x_pred = np.zeros((1, SEQUENCE_LEN, len(words)))
    for t, word in enumerate(sentence):
        x_pred[0, t, word_indices[word]] = 1.
    preds = model.predict(x_pred, verbose=0)[0]
    next_index = sample(preds, diversity)
    next_word = indices_word[next_index]
    return next_word
 
#sentence = ["#@Joke", "I","am"]
#predicted =predict_nex(sentence)

def printSentence(sentence):
    fullSentence =""
    for word in sentence:
        fullSentence =fullSentence +" " + word
    print(fullSentence)

# %%
sentence = ["I","am"]
cat ="#@Joke"
def predict_Sentence(sentence,cat):
    for i in range(50):
        threeWords= []
        threeWords.append(cat)
        threeWords.append(sentence[len(sentence)-2])
        threeWords.append(sentence[len(sentence)-1])
        sentence.append(predict_nex(threeWords,0.3))
    printSentence(sentence)

# %%
predict_Sentence(["I","am"],"#@Joke")
# Out:
#  I am a rock. I can't tell you a jar of jelly beans and when you've got to bring sunscreen the border and frisking, it it is to trust this person is mute? When you see a glass of water on lap*"
#  "Fun a beer"
#  "What do you call a

# %%
predict_Sentence(["I","am"],"#@Joke")
# Out:
#  I am a rock. I can't tell you a jar of jelly beans and when you've got to bring sunscreen the year, I'd like to be a real problem in the FDA bank"
#  "What do you call a small, noisy keeps my fruit-picking business trapped in a Mexican restaurant an actor

# %%
predict_Sentence(["I","am"],"#@Quote")
# Out:
#  I am more than you can be a real problem in English football and, in the world to revolve around them."
#  "What do you call a body builder? Jim."
#  "I just met someone as the strength of money as dollars into its own life is still there, but the idea

# %%
predict_Sentence(["I","am"],"#@NoTag")
# Out:
#  I am a rock. I can't wait for the Conservatives."
#  "How do you call a body builder? Jim."
#  "I don't trust anything in the world to revolve around them."
#  "What do you call a small, noisy the cause of success and is the greatest plenty in the world we

# %%
predict_Sentence(["fruit"],"#@NoTag")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-945ed9136e97> in <module>()
# ----> 1 predict_Sentence(["fruit"],"#@NoTag")
#
# NameError: name 'predict_Sentence' is not defined
